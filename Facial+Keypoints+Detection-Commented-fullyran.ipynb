# %%
# In this baseline python notebook, we loaded the dataset from Kaggle and attempted training with
# a simple NN with no hidden layers, 2 and 3 and 4 -convolutional-layers with fully connected layer.
# Also did some work to improve the facial keypoint identification such as blurring the image and 
# movement, and reran through NN to see if accuracy improved

# Reference-https://www.tensorflow.org/get_started/mnist/pros

# Loading required libraries
import numpy as np
import pandas as pd
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.INFO)
import matplotlib.pyplot as plt
import scipy.signal



# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

np.random.seed(0)

# %%
# Some additional work to improve accuracy: blur images, move images
#flips images horizontally
def flip_images(inputdata):
    data=inputdata.copy()
    origcols = list(data.columns)
    newcols = [item for item in origcols]
    
    for col in data.columns.get_level_values(0)[0:30:2]:
            data[col]=data[col].apply(lambda x: 96-x)
    #print data.head()
    
    flip_indices = [
        (0, 2), (1, 3),
        (4, 8), (5, 9), (6, 10), (7, 11),
        (12, 16), (13, 17), (14, 18), (15, 19),
        (22, 24), (23, 25),
        ]
    
    for (a,b) in flip_indices:
        newcols[a],newcols[b] = newcols[b],newcols[a]

    colmap = {}
    for i in range(len(newcols)):
        colmap[origcols[i]]=newcols[i]
    
    data = data[newcols]
    data.rename(columns = colmap,inplace=True)
    #print data.head()

    
    data["Image"] = data["Image"].apply(lambda x: np.fliplr(x.reshape((96,96))).flatten())

    return data


def blur_images(inputdata):
    data=inputdata.copy()
    data["Image"] = data["Image"].apply(lambda x: (scipy.signal.convolve2d(x.reshape((96,96)),np.ones((3,3)), mode='same',boundary="fill")/9.0).ravel() )
    return data

def move_images(inputdata,pixels,orientation):
    #pixels= 5 
    #orientation = 'right'
    data = train.copy()
    (dimx,dimy) = (96,96)
    if orientation == 'right':
        padding = np.zeros((dimx,pixels))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
                
        data["Image"] = data["Image"].apply(lambda x: np.hstack((padding,x.reshape(96,96)))[:,0:96])
    
        for col in data.columns.get_level_values(0)[0:30:2]:
            data[col]=data[col].apply(lambda x: min(96,x+pixels))
    elif orientation == 'left':
        padding = np.zeros((dimx,pixels))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
        data["Image"] = data["Image"].apply(lambda x: np.hstack((x.reshape(96,96),padding))[:,pixels:96+pixels])
    
        for col in data.columns.get_level_values(0)[0:30:2]:
            data[col]=data[col].apply(lambda x: max(0,x-pixels))
    elif orientation == 'up':
        padding = np.zeros((pixels,dimy))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
                
        data["Image"] = data["Image"].apply(lambda x: np.vstack((x.reshape(96,96),padding))[pixels:96+pixels,:])
    
        for col in data.columns.get_level_values(0)[1:30:2]:
            data[col]=data[col].apply(lambda x: max(0,x-pixels))
    elif orientation == 'down':
        padding = np.zeros((pixels,dimy))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
                
        data["Image"] = data["Image"].apply(lambda x: np.vstack((padding,x.reshape(96,96)))[0:96,:])
    
        for col in data.columns.get_level_values(0)[1:30:2]:
            data[col]=data[col].apply(lambda x: min(96,x+pixels))
    
    data["Image"] = data["Image"].apply(lambda x:x.flatten())
    
    return data

# %%
# Create iterator to deliver data & labels in sets of batchSize
def imgs_iterator(data,labels,batchSize):
    startIndex= 0
    totalSize = len(data)
    indices = np.arange(totalSize)
    np.random.shuffle(indices)
    
    for i in range(0,totalSize,batchSize):
            batchIndices = indices[i:i+batchSize]
            yield np.stack(data[batchIndices]),labels[batchIndices],len(batchIndices)

# Same as imgs_iterator but for test data (don't return labels)
def imgs_iterator_predict(data,batchSize):
    startIndex= 0
    totalSize = len(data)
    indices = np.arange(totalSize)
    np.random.shuffle(indices)
    
    for i in range(0,totalSize,batchSize):
        batchIndices = indices[i:i+batchSize]
        
        yield np.stack(data[batchIndices]),len(batchIndices)

# Make predictions according to formula "y = Wx + b" for data set 
# Similar in form to training loop
def make_predictions(data,batch_size):
    predictions_mb=[]
    # Iterate by batch size
    iter_test = imgs_iterator_predict(data,batch_size)
    try:
        next_batch =iter_test.__next__()
        while next_batch!=None:
            
            # Load next batch
            mini_batch,batch_size = next_batch
            
            # Reshape
            mini_batch = np.reshape(mini_batch,(batch_size,9216))
            
            # Make prediction with input data and dropout 
            feed_dict = {x: np.stack(mini_batch), keep_prob: 1.0}
            predictions = y.eval(feed_dict)
            predictions_mb.append(predictions)
            
            next_batch =iter_test.__next__()
    except StopIteration:
        next_batch=None
    results = pd.DataFrame(np.vstack(predictions_mb))
    
    return results

# Generate reports for submission
def generate_results(result):
    submission = pd.read_csv('SampleSubmission.csv')
    IdLookup = pd.read_csv('IdLookupTable.csv')
    IdLookupDict = IdLookup.set_index('RowId').T.to_dict('list')

    
    
    result.columns = dev.columns[0:30]
    output = pd.concat([test["ImageId"],result_test],axis=1)
    
    RowId = np.asarray(submission["RowId"],dtype=int)
    for row in RowId:
        r = IdLookupDict[row][0]-1
        c =IdLookupDict[row][1]
        submission.loc[row-1,"Location"]= min(96,(output.loc[r,c]))
    
    
    submission.to_csv("submission.csv",index=False)

# %%
# Loading the test and raw training datasets
# Raw is 7049X31.  7049 training examples, 30 columns of facial feature x &y locations, 1 column for list of image pixel values
# Test is 1783X2. 1783 test examples, 1 column for image id, 1 column for list of image pixel values
raw = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')


# Converting image data into numpy arrays and scaling the images
raw["Image"] = raw["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)
test["Image"] = test["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)

# %%
# Dropping training & test cases with na values since they will prevent the model from training correctly.
# Possibly revisit this to come up with a better approach
raw.dropna(inplace=True)
test.dropna(inplace=True)


# After removing the cases with 'na', re-shuffle (the training set) and re-do indexing
raw = raw.sample(frac=1)
raw.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

# %%
raw = pd.concat([raw,flip_images(raw)],axis=0)
raw = raw.sample(frac=1)
#,move_images(train,15,"right"),move_images(train,15,"left")
                  #,move_images(train,15,"up"),move_images(train,15,"down")

raw.reset_index(inplace=True,drop=True)

# %%
# Our training data set has 2140 examples at this point.  
# Allocate 1800 for training and 340 for development.
train_size = int(raw.shape[0]*.8)
train = raw.iloc[0:train_size,:]
dev = raw.iloc[train_size:raw.shape[0],:]

# Re-index
train.reset_index(inplace=True,drop=True)
dev.reset_index(inplace=True,drop=True)

# %%
# Visualize 5 example images:
def plot_images(num_images,data, result=None,training=True):
    plt.figure(figsize=(12,4))
    for i in range(num_images):
        
        # Every example has 30 facial features and 1 column with a 9216-length list of pixel values of image
        # take the 9216 list of pixels and reshape into 96X96 image for viewing
        img =  np.reshape(data.ix[i:i,"Image"].values[0],(96,96))
        plt.subplot(1,num_images,i+1)
        plt.axis('off')
        
        # Show the facial image
        plt.imshow(img,cmap='Greys_r')

        # Get x & y values for the facial keypoints and overlay on the face
        x_values = np.asarray(data[data.columns.get_level_values(0)[0:30:2]])
        y_values = np.asarray(data[data.columns.get_level_values(0)[1:30:2]])
        plt.scatter(x_values[i],y_values[i])
        
        # If we are not using training data, then show our predicted facial keypoints with red x's
        if training==False:
            rx_values = np.asarray(result[result.columns.get_level_values(0)[0:30:2]])
            ry_values = np.asarray(result[result.columns.get_level_values(0)[1:30:2]])
            plt.scatter(rx_values[i],ry_values[i],marker="x",color='r')
            

plot_images(5,train)

# %%
# Convert the pixel arrays and facial feature locations in train/dev/test into numpy-array representation
train_data = train["Image"].as_matrix()
train_labels = np.asarray(train[train.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

dev_data = dev["Image"].as_matrix()
dev_labels = np.asarray(dev[dev.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

test_data = test["Image"].as_matrix()

# %%
# Single layer neural network with NO hidden units

# Try running through the entire training data 200 times in batches of 20
batch_size=20
epochs = 200

# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Weights/bias for our simple NN
W = tf.Variable(tf.zeros([9216,30]))
b = tf.Variable(tf.zeros([30]))


# Prediction function "y=Wx+b"
y = tf.matmul(x,W) + b

# Define loss function as RMSE, and minimize by GradientDescent
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(error)

# Initialize all tf.Variable instances
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

for i in range(epochs):
    
    # Move through training data in increments of 20
    iter_ = imgs_iterator(train_data,train_labels,batch_size)
    try:
        next_batch =iter_.__next__()
        while next_batch!=None:
            
            # Load next batch
            train_data_instance,train_label_instance,batch_size = next_batch
            train_instance = np.reshape(train_data_instance,(batch_size,9216))
            train_label_instance = np.reshape(train_label_instance,(batch_size,30))

            # Accuracy (for display)
            train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance})
            
            # Run training with next batch of 20 training examples
            train_step.run(feed_dict={x: train_instance, y_: train_label_instance})
            next_batch =iter_.__next__()
    except StopIteration:
        next_batch=None
    if i%10==0:
        
        # Display our RMSE for every 10th epoch
        print ("RMSE for Epoch "+str(i)+" ="+str(train_accuracy))
# Out:
# RMSE for Epoch 0 =13.0222
# RMSE for Epoch 10 =11.4361
# RMSE for Epoch 20 =7.74401
# RMSE for Epoch 30 =5.43771
# RMSE for Epoch 40 =4.76508
# RMSE for Epoch 50 =6.32513
# RMSE for Epoch 60 =11.3135
# RMSE for Epoch 70 =6.34461
# RMSE for Epoch 80 =13.8872
# RMSE for Epoch 90 =5.63399
# RMSE for Epoch 100 =5.90203
# RMSE for Epoch 110 =7.80247
# RMSE for Epoch 120 =5.50877
# RMSE for Epoch 130 =3.66047
# RMSE for Epoch 140 =5.73251
# RMSE for Epoch 150 =3.72831
# RMSE for Epoch 160 =1.94445
# RMSE for Epoch 170 =3.31269
# RMSE for Epoch 180 =4.9874
# RMSE for Epoch 190 =3.51853

# %%
# Generate predictions
feed_dict = {x: np.stack(train_data)}
predictions = y.eval(feed_dict)
# Plot predictions
result =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))
plot_images(5,data =train,result=result,training=False)

# %%
# Try 2-convolutional-layers, 1 fully connected

mini_batch_size=300
epochs = 40

# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')



# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])


# Weights will be 4D tensor of size 5x5x1x32 from truncated normal, 32-length array bias of constant 0.1
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])


# x_image is in shape [batch, in_height, in_width, in_channels] ~ [-1, 96, 96, 1]
# W_conv1 is in shape [filter_height, filter_width, in_channels, out_channels] ~ [5,5,1,32]
# conv2d flattens the filter to a 2-D matrix with shape [filter_height * filter_width * in_channels, output_channels]
#      ~ [5*5*1, 32] ~ [25, 32]
# Apply rectifier relu function
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)

# Perform reduction.  h_conv1 is [?,96,96,32] with strides [1,2,2,1]
# Returns a 48*48 image with 32 filters
h_pool1 = max_pool_2x2(h_conv1)

# 2nd convolutional layer - will return 24*24 image with 64 filters
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)


# Flatten resulting image to apply relu activation
h_pool2_flat = tf.reshape(h_pool2, [-1, 24*24*64])

# Fully connected layer
W_fc1 = weight_variable([24 * 24 * 64, 1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Apply dropout to prevent overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Determine prediction function "y=Wx+b"
W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])
y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# Define loss function, try minimize with AdamOptimizer (more efficient than gradient descent)
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-3).minimize(error)


with tf.Session() as sess:
    # Initialize global vars
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        
        # Iterate over training data in increments of (mini_batch_size-1)
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape 
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Determine accuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of 20 training examples
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+" ="+str(train_accuracy))
        
    
        # Measure accuracy with trained NN on dev data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
    
        # Get batch of 20 from dev data
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
    
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
    
        # Calculate accuracy
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
    
    

    # Generate predictions for training and dev for plotting
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
# Out:
# RMSE for Epoch 0 =9.66492
# RMSE for dev set =8.00202
# RMSE for Epoch 1 =4.99318
# RMSE for dev set =4.88633
# RMSE for Epoch 2 =4.92476
# RMSE for dev set =3.84223
# RMSE for Epoch 3 =3.94335
# RMSE for dev set =3.8053
# RMSE for Epoch 4 =4.17659
# RMSE for dev set =4.01212
# RMSE for Epoch 5 =3.65842
# RMSE for dev set =3.16863
# RMSE for Epoch 6 =3.79093
# RMSE for dev set =5.91904
# RMSE for Epoch 7 =3.22146
# RMSE for dev set =3.14999
# RMSE for Epoch 8 =3.93856
# RMSE for dev set =3.11002
# RMSE for Epoch 9 =4.64477
# RMSE for dev set =3.58079
# RMSE for Epoch 10 =3.35215
# RMSE for dev set =3.899
# RMSE for Epoch 11 =4.17261
# RMSE for dev set =4.08552
# RMSE for Epoch 12 =2.92078
# RMSE for dev set =3.22882
# RMSE for Epoch 13 =2.65321
# RMSE for dev set =3.71822
# RMSE for Epoch 14 =3.891
# RMSE for dev set =2.64549
# RMSE for Epoch 15 =3.13154
# RMSE for dev set =4.19505
# RMSE for Epoch 16 =3.39849
# RMSE for dev set =3.17361
# RMSE for Epoch 17 =3.43317
# RMSE for dev set =3.03314
# RMSE for Epoch 18 =3.41636
# RMSE for dev set =2.5884
# RMSE for Epoch 19 =2.62161
# RMSE for dev set =2.81411
# RMSE for Epoch 20 =2.51873
# RMSE for dev set =2.51574
# RMSE for Epoch 21 =2.54058
# RMSE for dev set =2.93616
# RMSE for Epoch 22 =2.57977
# RMSE for dev set =2.29047
# RMSE for Epoch 23 =2.5159
# RMSE for dev set =2.82439
# RMSE for Epoch 24 =2.40118
# RMSE for dev set =2.80075
# RMSE for Epoch 25 =2.47407
# RMSE for dev set =2.60336
# RMSE for Epoch 26 =2.36602
# RMSE for dev set =2.63281
# RMSE for Epoch 27 =2.39706
# RMSE for dev set =2.44623
# RMSE for Epoch 28 =2.50893
# RMSE for dev set =2.28438
# RMSE for Epoch 29 =3.00951
# RMSE for dev set =2.48061
# RMSE for Epoch 30 =2.62238
# RMSE for dev set =2.74373
# RMSE for Epoch 31 =2.62768
# RMSE for dev set =2.50084
# RMSE for Epoch 32 =2.55901
# RMSE for dev set =2.87674
# RMSE for Epoch 33 =2.1384
# RMSE for dev set =2.30654
# RMSE for Epoch 34 =2.15931
# RMSE for dev set =3.13816
# RMSE for Epoch 35 =3.05444
# RMSE for dev set =2.33949
# RMSE for Epoch 36 =2.44496
# RMSE for dev set =2.31415
# RMSE for Epoch 37 =2.21931
# RMSE for dev set =2.33064
# RMSE for Epoch 38 =2.1554
# RMSE for dev set =2.64691
# RMSE for Epoch 39 =2.52927
# RMSE for dev set =3.25677

# %%
# Plot our predictions
plot_images(5,data =train,result=result,training=False)

# %%
# Try 3 convolutional layers, 1 fully connected

mini_batch_size=100
epochs = 50

# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')


# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])

# Same as previous exercize, return a 48*48 image with 32 filters
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# Same as previous exercise, next return a 24*24 image with 64 filters
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# Our third convolutional layer, returns a 12*12 image with 128 filters
W_conv3 = weight_variable([5, 5, 64, 128])
b_conv3 = bias_variable([128])
h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)


# Flatten resulting image to apply relu activation
h_pool3_flat = tf.reshape(h_pool3, [-1, 12*12*128])

# Fully connected layer
W_fc1 = weight_variable([12 * 12 * 128, 1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1)

# Dropout to prevent overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)


# Apply error function with prediction function "y= xW+b" as previously
W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])
y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# Define loss function, try minimize with AdamOptimizer
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-4).minimize(error)

epoch=[i for i in range(epochs)]

# Collect magnitudes of the training and dev errors over epochs for visualization
train_error = []
dev_error = []

with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    # Initialize global vars
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        # Iterate over training data in increments of (mini_batch_size-1)
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Calculate accuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of 20 training examples
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+str(" =")+str(train_accuracy))
        train_error.append(train_accuracy)
        
        # Test accuracy on the unseen (dev) data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        
        # Get batch of 20 from dev
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
        
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        
        # Calculate accuracy & error
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
        dev_error.append(dev_accuracy)
    
    
    # Generate predictions for training and dev for plotting
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
# Out:
# RMSE for Epoch 0 =7.37117
# RMSE for dev set =7.96084
# RMSE for Epoch 1 =5.7101
# RMSE for dev set =5.37613
# RMSE for Epoch 2 =4.83478
# RMSE for dev set =5.03267
# RMSE for Epoch 3 =4.5279
# RMSE for dev set =4.2985
# RMSE for Epoch 4 =3.80812
# RMSE for dev set =3.78683
# RMSE for Epoch 5 =4.93831
# RMSE for dev set =4.43367
# RMSE for Epoch 6 =4.27774
# RMSE for dev set =3.72151
# RMSE for Epoch 7 =3.23648
# RMSE for dev set =4.35114
# RMSE for Epoch 8 =3.39901
# RMSE for dev set =3.89557
# RMSE for Epoch 9 =3.78864
# RMSE for dev set =3.9619
# RMSE for Epoch 10 =3.64349
# RMSE for dev set =3.72477
# RMSE for Epoch 11 =3.39897
# RMSE for dev set =3.06292
# RMSE for Epoch 12 =3.00807
# RMSE for dev set =3.26933
# RMSE for Epoch 13 =3.44771
# RMSE for dev set =3.30287
# RMSE for Epoch 14 =2.73398
# RMSE for dev set =2.8258
# RMSE for Epoch 15 =2.67797
# RMSE for dev set =2.83372
# RMSE for Epoch 16 =3.68964
# RMSE for dev set =4.00201
# RMSE for Epoch 17 =2.86477
# RMSE for dev set =3.72174
# RMSE for Epoch 18 =2.87033
# RMSE for dev set =2.90992
# RMSE for Epoch 19 =2.79301
# RMSE for dev set =2.90565
# RMSE for Epoch 20 =2.751
# RMSE for dev set =2.89799
# RMSE for Epoch 21 =3.13213
# RMSE for dev set =2.70612
# RMSE for Epoch 22 =2.56156
# RMSE for dev set =2.64908
# RMSE for Epoch 23 =2.72958
# RMSE for dev set =3.53741
# RMSE for Epoch 24 =2.59484
# RMSE for dev set =2.93429
# RMSE for Epoch 25 =2.48591
# RMSE for dev set =2.59345
# RMSE for Epoch 26 =2.48648
# RMSE for dev set =2.52986
# RMSE for Epoch 27 =2.76149
# RMSE for dev set =2.50032
# RMSE for Epoch 28 =3.01302
# RMSE for dev set =2.74101
# RMSE for Epoch 29 =3.13405
# RMSE for dev set =2.76498
# RMSE for Epoch 30 =3.18588
# RMSE for dev set =2.9061
# RMSE for Epoch 31 =2.50191
# RMSE for dev set =2.26996
# RMSE for Epoch 32 =3.31131
# RMSE for dev set =3.25098
# RMSE for Epoch 33 =2.36463
# RMSE for dev set =2.47167
# RMSE for Epoch 34 =2.39126
# RMSE for dev set =2.43426
# RMSE for Epoch 35 =2.71699
# RMSE for dev set =3.05346
# RMSE for Epoch 36 =3.27876
# RMSE for dev set =2.73225
# RMSE for Epoch 37 =2.69251
# RMSE for dev set =2.52416
# RMSE for Epoch 38 =2.52763
# RMSE for dev set =2.45049
# RMSE for Epoch 39 =2.35916
# RMSE for dev set =2.55854
# RMSE for Epoch 40 =2.1855
# RMSE for dev set =2.31525
# RMSE for Epoch 41 =2.15197
# RMSE for dev set =2.36741
# RMSE for Epoch 42 =2.34671
# RMSE for dev set =2.41453
# RMSE for Epoch 43 =2.82403
# RMSE for dev set =2.6481
# RMSE for Epoch 44 =2.24232
# RMSE for dev set =2.28015
# RMSE for Epoch 45 =2.33906
# RMSE for dev set =1.98877
# RMSE for Epoch 46 =2.85564
# RMSE for dev set =3.33264
# RMSE for Epoch 47 =2.4729
# RMSE for dev set =2.3874
# RMSE for Epoch 48 =2.49426
# RMSE for dev set =2.16508
# RMSE for Epoch 49 =2.24971
# RMSE for dev set =2.6287

# %%
# Plot predictions from training data (better fit than before)
plot_images(5,data =train,result=result,training=False)

# %%
# Plot predictions from dev data
plot_images(5,data =dev,result=result_dev,training=False)

# %%
# Plot the magnitudes of error magnitudes in dev and training set by epoch
plt.figure(figsize=(6,6))
plt.scatter(epoch,train_error)
plt.scatter(epoch,dev_error,color="red")

# %%
# Try 4 convolutional layers, 1 fully connected

mini_batch_size=100
epochs = 400

# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])#-1 because we don't know the batch size yet.

# Same as previous exercize, return a 48*48 image with 32 filters
W_conv1 = weight_variable([3, 3, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# Same as previous exercise, next return a 24*24 image with 64 filters
W_conv2 = weight_variable([3, 3, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# Same as previous exercise, next return a 12*12 image with 128 filters
W_conv3 = weight_variable([3, 3, 64, 128])
b_conv3 = bias_variable([128])
h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)

# Fourth convolutional layer, returns a 6*6 image with 256 filters
W_conv4 = weight_variable([3, 3, 128, 256])
b_conv4 = bias_variable([256])
h_conv4 = tf.nn.relu(conv2d(h_pool3, W_conv4) + b_conv4)
h_pool4 = max_pool_2x2(h_conv4) #returns a 6*6 image with 256 filters

# Flatten resulting image for matrix multiplication
h_pool4_flat = tf.reshape(h_pool4, [-1, 6*6*256])
# Fully connected layer
W_fc1 = weight_variable([6 * 6 * 256, 1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(h_pool4_flat, W_fc1) + b_fc1)

# Dropout to prevent overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Prediction y=xW+b
W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])
y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# Define RMSE loss function, minimize with AdamOptimizer
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-3).minimize(error)


epoch=[i for i in range(epochs)]

# Collect train and dev error magnitudes for visualization
train_error = []
dev_error = []

with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        
        # Iterate over training data in steps of (mini_batch_size-1)
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Calculate accuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of 20 training examples
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+str(" =")+str(train_accuracy))
        train_error.append(train_accuracy)
        
        # Test accuracy on the unseen (dev) data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        
        # Get batch of 20 from dev
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
        
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        
        # Calculate accuracy & error
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
        dev_error.append(dev_accuracy)
    
    

    # Generate predictions for train/dev/test
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
    result_test =make_predictions(test_data, mini_batch_size-1)
# Out:
# RMSE for Epoch 0 =3.70944
# RMSE for dev set =4.32283
# RMSE for Epoch 1 =3.72004
# RMSE for dev set =3.68753
# RMSE for Epoch 2 =3.27357
# RMSE for dev set =3.53359
# RMSE for Epoch 3 =3.48302
# RMSE for dev set =3.02714
# RMSE for Epoch 4 =2.97356
# RMSE for dev set =4.20993
# RMSE for Epoch 5 =2.98366
# RMSE for dev set =2.79178
# RMSE for Epoch 6 =2.81519
# RMSE for dev set =3.13723
# RMSE for Epoch 7 =3.38705
# RMSE for dev set =2.97801
# RMSE for Epoch 8 =2.71793
# RMSE for dev set =3.61007
# RMSE for Epoch 9 =2.83057
# RMSE for dev set =2.56694
# RMSE for Epoch 10 =2.50347
# RMSE for dev set =2.68806
# RMSE for Epoch 11 =3.03374
# RMSE for dev set =2.71805
# RMSE for Epoch 12 =2.31612
# RMSE for dev set =3.03628
# RMSE for Epoch 13 =2.27617
# RMSE for dev set =2.51051
# RMSE for Epoch 14 =2.98457
# RMSE for dev set =2.73704
# RMSE for Epoch 15 =2.82536
# RMSE for dev set =3.77203
# RMSE for Epoch 16 =2.78925
# RMSE for dev set =2.6871
# RMSE for Epoch 17 =2.1409
# RMSE for dev set =2.74516
# RMSE for Epoch 18 =2.73454
# RMSE for dev set =2.72576
# RMSE for Epoch 19 =2.2958
# RMSE for dev set =2.31214
# RMSE for Epoch 20 =2.71192
# RMSE for dev set =3.41766
# RMSE for Epoch 21 =2.6126
# RMSE for dev set =2.38413
# RMSE for Epoch 22 =2.45502
# RMSE for dev set =2.68134
# RMSE for Epoch 23 =2.34393
# RMSE for dev set =2.43246
# RMSE for Epoch 24 =2.10291
# RMSE for dev set =2.42854
# RMSE for Epoch 25 =3.09013
# RMSE for dev set =2.26261
# RMSE for Epoch 26 =2.11786
# RMSE for dev set =2.26687
# RMSE for Epoch 27 =2.4614
# RMSE for dev set =2.42998
# RMSE for Epoch 28 =2.13396
# RMSE for dev set =2.8145
# RMSE for Epoch 29 =2.36873
# RMSE for dev set =2.63267
# RMSE for Epoch 30 =2.52059
# RMSE for dev set =2.21987
# RMSE for Epoch 31 =2.68373
# RMSE for dev set =2.03928
# RMSE for Epoch 32 =2.68479
# RMSE for dev set =2.36505
# RMSE for Epoch 33 =2.11562
# RMSE for dev set =2.45215
# RMSE for Epoch 34 =2.6782
# RMSE for dev set =2.32501
# RMSE for Epoch 35 =2.17711
# RMSE for dev set =2.23803
# RMSE for Epoch 36 =2.66276
# RMSE for dev set =1.98341
# RMSE for Epoch 37 =3.22536
# RMSE for dev set =2.8928
# RMSE for Epoch 38 =2.14038
# RMSE for dev set =2.46337
# RMSE for Epoch 39 =2.20063
# RMSE for dev set =2.25697
# RMSE for Epoch 40 =2.37876
# RMSE for dev set =2.35944
# RMSE for Epoch 41 =1.6887
# RMSE for dev set =2.66928
# RMSE for Epoch 42 =2.23211
# RMSE for dev set =2.50988
# RMSE for Epoch 43 =1.90729
# RMSE for dev set =2.08704
# RMSE for Epoch 44 =2.65214
# RMSE for dev set =2.45652
# RMSE for Epoch 45 =2.27656
# RMSE for dev set =2.30122
# RMSE for Epoch 46 =2.11608
# RMSE for dev set =2.49798
# RMSE for Epoch 47 =2.12396
# RMSE for dev set =2.36102
# RMSE for Epoch 48 =2.08305
# RMSE for dev set =1.8933
# RMSE for Epoch 49 =2.76692
# RMSE for dev set =2.64662
# RMSE for Epoch 50 =1.86321
# RMSE for dev set =2.10031
# RMSE for Epoch 51 =1.94283
# RMSE for dev set =2.24858
# RMSE for Epoch 52 =2.09338
# RMSE for dev set =2.45292
# RMSE for Epoch 53 =1.92528
# RMSE for dev set =2.4649
# RMSE for Epoch 54 =2.01525
# RMSE for dev set =2.3674
# RMSE for Epoch 55 =2.13057
# RMSE for dev set =2.09904
# RMSE for Epoch 56 =2.56364
# RMSE for dev set =2.12118
# RMSE for Epoch 57 =1.98169
# RMSE for dev set =2.18287
# RMSE for Epoch 58 =1.77426
# RMSE for dev set =2.00704
# RMSE for Epoch 59 =2.1142
# RMSE for dev set =1.84998
# RMSE for Epoch 60 =1.97621
# RMSE for dev set =3.00446
# RMSE for Epoch 61 =1.84215
# RMSE for dev set =1.97323
# RMSE for Epoch 62 =1.94983
# RMSE for dev set =2.09433
# RMSE for Epoch 63 =1.91795
# RMSE for dev set =2.23557
# RMSE for Epoch 64 =1.77483
# RMSE for dev set =2.34138
# RMSE for Epoch 65 =1.73492
# RMSE for dev set =2.11051
# RMSE for Epoch 66 =2.31892
# RMSE for dev set =2.54757
# RMSE for Epoch 67 =1.83302
# RMSE for dev set =2.37072
# RMSE for Epoch 68 =2.01697
# RMSE for dev set =2.45915
# RMSE for Epoch 69 =2.25147
# RMSE for dev set =1.75315
# RMSE for Epoch 70 =2.53015
# RMSE for dev set =2.16685
# RMSE for Epoch 71 =1.96018
# RMSE for dev set =1.73332
# RMSE for Epoch 72 =2.15025
# RMSE for dev set =1.82197
# RMSE for Epoch 73 =2.00606
# RMSE for dev set =2.67326
# RMSE for Epoch 74 =2.75245
# RMSE for dev set =2.04088
# RMSE for Epoch 75 =1.79633
# RMSE for dev set =2.19279
# RMSE for Epoch 76 =2.29943
# RMSE for dev set =2.05441
# RMSE for Epoch 77 =2.07895
# RMSE for dev set =2.56105
# RMSE for Epoch 78 =1.87165
# RMSE for dev set =1.8813
# RMSE for Epoch 79 =1.87586
# RMSE for dev set =1.84847
# RMSE for Epoch 80 =1.91868
# RMSE for dev set =1.95587
# RMSE for Epoch 81 =1.65117
# RMSE for dev set =1.93119
# RMSE for Epoch 82 =1.87149
# RMSE for dev set =1.82094
# RMSE for Epoch 83 =1.72266
# RMSE for dev set =2.02381
# RMSE for Epoch 84 =1.83855
# RMSE for dev set =1.92589
# RMSE for Epoch 85 =1.9084
# RMSE for dev set =1.81766
# RMSE for Epoch 86 =1.66844
# RMSE for dev set =2.19024
# RMSE for Epoch 87 =1.69623
# RMSE for dev set =2.04744
# RMSE for Epoch 88 =1.62191
# RMSE for dev set =2.03483
# RMSE for Epoch 89 =1.90572
# RMSE for dev set =2.05675
# RMSE for Epoch 90 =1.84947
# RMSE for dev set =2.26859
# RMSE for Epoch 91 =1.99329
# RMSE for dev set =1.95767
# RMSE for Epoch 92 =1.71654
# RMSE for dev set =1.73087
# RMSE for Epoch 93 =2.27158
# RMSE for dev set =1.7413
# RMSE for Epoch 94 =1.75277
# RMSE for dev set =2.05395
# RMSE for Epoch 95 =1.83241
# RMSE for dev set =2.54396
# RMSE for Epoch 96 =1.9437
# RMSE for dev set =1.8903
# RMSE for Epoch 97 =1.89698
# RMSE for dev set =1.80342
# RMSE for Epoch 98 =1.70103
# RMSE for dev set =1.90957
# RMSE for Epoch 99 =1.81044
# RMSE for dev set =2.10281
# RMSE for Epoch 100 =1.60156
# RMSE for dev set =2.06089
# RMSE for Epoch 101 =1.83274
# RMSE for dev set =1.75799
# RMSE for Epoch 102 =1.63032
# RMSE for dev set =1.80456
# RMSE for Epoch 103 =1.73112
# RMSE for dev set =1.93346
# RMSE for Epoch 104 =1.9192
# RMSE for dev set =2.0467
# RMSE for Epoch 105 =1.80437
# RMSE for dev set =2.26566
# RMSE for Epoch 106 =1.91191
# RMSE for dev set =1.89338
# RMSE for Epoch 107 =1.65288
# RMSE for dev set =2.07565
# RMSE for Epoch 108 =1.67062
# RMSE for dev set =1.79543
# RMSE for Epoch 109 =1.86714
# RMSE for dev set =2.09026
# RMSE for Epoch 110 =1.78737
# RMSE for dev set =1.81721
# RMSE for Epoch 111 =1.63663
# RMSE for dev set =2.00718
# RMSE for Epoch 112 =1.76755
# RMSE for dev set =1.7429
# RMSE for Epoch 113 =2.03397
# RMSE for dev set =1.65691
# RMSE for Epoch 114 =1.69988
# RMSE for dev set =1.98214
# RMSE for Epoch 115 =1.93725
# RMSE for dev set =1.86398
# RMSE for Epoch 116 =1.79755
# RMSE for dev set =1.85327
# RMSE for Epoch 117 =1.47176
# RMSE for dev set =1.88856
# RMSE for Epoch 118 =1.60135
# RMSE for dev set =1.92265
# RMSE for Epoch 119 =2.06295
# RMSE for dev set =1.88224
# RMSE for Epoch 120 =1.7026
# RMSE for dev set =2.4074
# RMSE for Epoch 121 =1.58169
# RMSE for dev set =1.70672
# RMSE for Epoch 122 =1.47716
# RMSE for dev set =1.90261
# RMSE for Epoch 123 =1.61391
# RMSE for dev set =1.67706
# RMSE for Epoch 124 =1.63238
# RMSE for dev set =2.03277
# RMSE for Epoch 125 =1.62435
# RMSE for dev set =1.80831
# RMSE for Epoch 126 =1.56303
# RMSE for dev set =1.83143
# RMSE for Epoch 127 =1.69048
# RMSE for dev set =2.17213
# RMSE for Epoch 128 =1.46491
# RMSE for dev set =1.55012
# RMSE for Epoch 129 =1.7772
# RMSE for dev set =1.77331
# RMSE for Epoch 130 =1.61298
# RMSE for dev set =1.91461
# RMSE for Epoch 131 =1.81868
# RMSE for dev set =1.70177
# RMSE for Epoch 132 =1.85373
# RMSE for dev set =2.26603
# RMSE for Epoch 133 =1.55076
# RMSE for dev set =1.59252
# RMSE for Epoch 134 =2.36179
# RMSE for dev set =2.54767
# RMSE for Epoch 135 =1.56359
# RMSE for dev set =1.59001
# RMSE for Epoch 136 =1.67627
# RMSE for dev set =1.87746
# RMSE for Epoch 137 =1.80864
# RMSE for dev set =1.53173
# RMSE for Epoch 138 =1.45179
# RMSE for dev set =1.71456
# RMSE for Epoch 139 =1.79465
# RMSE for dev set =1.85426
# RMSE for Epoch 140 =1.84942
# RMSE for dev set =1.72992
# RMSE for Epoch 141 =1.56977
# RMSE for dev set =1.96559
# RMSE for Epoch 142 =1.49146
# RMSE for dev set =1.88863
# RMSE for Epoch 143 =2.42733
# RMSE for dev set =1.94587
# RMSE for Epoch 144 =1.97133
# RMSE for dev set =2.04133
# RMSE for Epoch 145 =1.93142
# RMSE for dev set =1.87334
# RMSE for Epoch 146 =1.72306
# RMSE for dev set =1.49251
# RMSE for Epoch 147 =1.58402
# RMSE for dev set =1.73804
# RMSE for Epoch 148 =1.63144
# RMSE for dev set =2.11579
# RMSE for Epoch 149 =1.55338
# RMSE for dev set =1.70932
# RMSE for Epoch 150 =1.60308
# RMSE for dev set =1.95081
# RMSE for Epoch 151 =1.77777
# RMSE for dev set =2.1438
# RMSE for Epoch 152 =1.53144
# RMSE for dev set =1.773
# RMSE for Epoch 153 =1.41434
# RMSE for dev set =1.75146
# RMSE for Epoch 154 =1.83083
# RMSE for dev set =1.98265
# RMSE for Epoch 155 =1.92042
# RMSE for dev set =1.7379
# RMSE for Epoch 156 =1.5166
# RMSE for dev set =1.69824
# RMSE for Epoch 157 =1.68508
# RMSE for dev set =2.61992
# RMSE for Epoch 158 =1.74066
# RMSE for dev set =2.0122
# RMSE for Epoch 159 =1.67827
# RMSE for dev set =2.08764
# RMSE for Epoch 160 =1.81437
# RMSE for dev set =1.74447
# RMSE for Epoch 161 =1.69416
# RMSE for dev set =1.68582
# RMSE for Epoch 162 =1.58927
# RMSE for dev set =1.55727
# RMSE for Epoch 163 =1.72912
# RMSE for dev set =1.5533
# RMSE for Epoch 164 =1.50654
# RMSE for dev set =1.6597
# RMSE for Epoch 165 =1.46342
# RMSE for dev set =1.74543
# RMSE for Epoch 166 =2.03317
# RMSE for dev set =2.04361
# RMSE for Epoch 167 =1.47577
# RMSE for dev set =1.54427
# RMSE for Epoch 168 =1.74513
# RMSE for dev set =1.76437
# RMSE for Epoch 169 =1.89085
# RMSE for dev set =2.24585
# RMSE for Epoch 170 =1.55749
# RMSE for dev set =1.68638
# RMSE for Epoch 171 =1.40841
# RMSE for dev set =1.64095
# RMSE for Epoch 172 =1.4098
# RMSE for dev set =1.95705
# RMSE for Epoch 173 =1.70075
# RMSE for dev set =1.9293
# RMSE for Epoch 174 =1.51389
# RMSE for dev set =1.65113
# RMSE for Epoch 175 =1.41109
# RMSE for dev set =1.80129
# RMSE for Epoch 176 =1.72632
# RMSE for dev set =1.78827
# RMSE for Epoch 177 =1.55575
# RMSE for dev set =1.56914
# RMSE for Epoch 178 =1.46209
# RMSE for dev set =1.59055
# RMSE for Epoch 179 =1.5968
# RMSE for dev set =1.7334
# RMSE for Epoch 180 =1.63867
# RMSE for dev set =1.66921
# RMSE for Epoch 181 =1.48634
# RMSE for dev set =1.57679
# RMSE for Epoch 182 =1.50745
# RMSE for dev set =1.6147
# RMSE for Epoch 183 =1.41377
# RMSE for dev set =1.87807
# RMSE for Epoch 184 =2.02454
# RMSE for dev set =2.06
# RMSE for Epoch 185 =1.44585
# RMSE for dev set =1.58361
# RMSE for Epoch 186 =1.4213
# RMSE for dev set =1.49899
# RMSE for Epoch 187 =1.75652
# RMSE for dev set =1.69899
# RMSE for Epoch 188 =1.44418
# RMSE for dev set =1.60923
# RMSE for Epoch 189 =1.68622
# RMSE for dev set =1.73361
# RMSE for Epoch 190 =1.60549
# RMSE for dev set =2.2109
# RMSE for Epoch 191 =1.50762
# RMSE for dev set =1.67092
# RMSE for Epoch 192 =1.60801
# RMSE for dev set =1.71415
# RMSE for Epoch 193 =1.65696
# RMSE for dev set =2.0264
# RMSE for Epoch 194 =1.52457
# RMSE for dev set =1.50501
# RMSE for Epoch 195 =1.46942
# RMSE for dev set =1.77508
# RMSE for Epoch 196 =1.56074
# RMSE for dev set =1.44662
# RMSE for Epoch 197 =1.62873
# RMSE for dev set =1.64364
# RMSE for Epoch 198 =1.56768
# RMSE for dev set =2.00209
# RMSE for Epoch 199 =1.62521
# RMSE for dev set =1.85921
# RMSE for Epoch 200 =1.54368
# RMSE for dev set =1.63865
# RMSE for Epoch 201 =1.35917
# RMSE for dev set =1.76534
# RMSE for Epoch 202 =1.36455
# RMSE for dev set =1.64358
# RMSE for Epoch 203 =1.52862
# RMSE for dev set =1.69433
# RMSE for Epoch 204 =1.52106
# RMSE for dev set =1.65664
# RMSE for Epoch 205 =1.41374
# RMSE for dev set =2.19382
# RMSE for Epoch 206 =1.67259
# RMSE for dev set =2.14053
# RMSE for Epoch 207 =1.29196
# RMSE for dev set =1.753
# RMSE for Epoch 208 =1.90872
# RMSE for dev set =1.56706
# RMSE for Epoch 209 =1.45169
# RMSE for dev set =1.83806
# RMSE for Epoch 210 =1.50203
# RMSE for dev set =1.79179
# RMSE for Epoch 211 =1.53481
# RMSE for dev set =1.55059
# RMSE for Epoch 212 =1.67333
# RMSE for dev set =1.92183
# RMSE for Epoch 213 =1.38718
# RMSE for dev set =1.62529
# RMSE for Epoch 214 =1.68723
# RMSE for dev set =2.43908
# RMSE for Epoch 215 =1.54012
# RMSE for dev set =1.8297
# RMSE for Epoch 216 =1.35279
# RMSE for dev set =1.69447
# RMSE for Epoch 217 =1.43546
# RMSE for dev set =2.09771
# RMSE for Epoch 218 =1.54562
# RMSE for dev set =1.52377
# RMSE for Epoch 219 =1.41304
# RMSE for dev set =1.5947
# RMSE for Epoch 220 =1.56721
# RMSE for dev set =1.77908
# RMSE for Epoch 221 =1.65719
# RMSE for dev set =1.69751
# RMSE for Epoch 222 =1.4751
# RMSE for dev set =1.76526
# RMSE for Epoch 223 =1.55805
# RMSE for dev set =1.72656
# RMSE for Epoch 224 =1.64411
# RMSE for dev set =1.81414
# RMSE for Epoch 225 =1.42432
# RMSE for dev set =1.66853
# RMSE for Epoch 226 =1.56689
# RMSE for dev set =1.97329
# RMSE for Epoch 227 =1.51598
# RMSE for dev set =1.45348
# RMSE for Epoch 228 =1.39604
# RMSE for dev set =1.71014
# RMSE for Epoch 229 =1.69255
# RMSE for dev set =1.74382
# RMSE for Epoch 230 =1.39309
# RMSE for dev set =1.6084
# RMSE for Epoch 231 =1.59455
# RMSE for dev set =1.51264
# RMSE for Epoch 232 =1.7422
# RMSE for dev set =1.7107
# RMSE for Epoch 233 =1.69354
# RMSE for dev set =1.72926
# RMSE for Epoch 234 =1.49545
# RMSE for dev set =1.61946
# RMSE for Epoch 235 =2.12817
# RMSE for dev set =2.33514
# RMSE for Epoch 236 =1.84894
# RMSE for dev set =1.81895
# RMSE for Epoch 237 =1.45927
# RMSE for dev set =1.83234
# RMSE for Epoch 238 =1.51705
# RMSE for dev set =1.60813
# RMSE for Epoch 239 =2.0705
# RMSE for dev set =2.23599
# RMSE for Epoch 240 =1.70876
# RMSE for dev set =1.8033
# RMSE for Epoch 241 =1.5195
# RMSE for dev set =1.60956
# RMSE for Epoch 242 =1.61507
# RMSE for dev set =1.66132
# RMSE for Epoch 243 =1.31833
# RMSE for dev set =1.62796
# RMSE for Epoch 244 =1.4945
# RMSE for dev set =1.64102
# RMSE for Epoch 245 =1.53443
# RMSE for dev set =1.52052
# RMSE for Epoch 246 =1.85417
# RMSE for dev set =2.29557
# RMSE for Epoch 247 =1.57255
# RMSE for dev set =1.43548
# RMSE for Epoch 248 =2.06449
# RMSE for dev set =1.79469
# RMSE for Epoch 249 =1.65607
# RMSE for dev set =2.0356
# RMSE for Epoch 250 =1.42132
# RMSE for dev set =1.73885
# RMSE for Epoch 251 =1.41579
# RMSE for dev set =1.75575
# RMSE for Epoch 252 =1.68493
# RMSE for dev set =1.7757
# RMSE for Epoch 253 =1.72987
# RMSE for dev set =1.68306
# RMSE for Epoch 254 =1.48081
# RMSE for dev set =1.77705
# RMSE for Epoch 255 =1.6146
# RMSE for dev set =1.67914
# RMSE for Epoch 256 =1.5131
# RMSE for dev set =1.74429
# RMSE for Epoch 257 =1.35881
# RMSE for dev set =1.7632
# RMSE for Epoch 258 =1.3598
# RMSE for dev set =1.68507
# RMSE for Epoch 259 =1.54687
# RMSE for dev set =1.51417
# RMSE for Epoch 260 =1.6928
# RMSE for dev set =1.59201
# RMSE for Epoch 261 =1.5956
# RMSE for dev set =1.90435
# RMSE for Epoch 262 =1.65693
# RMSE for dev set =1.70546
# RMSE for Epoch 263 =1.46477
# RMSE for dev set =1.61799
# RMSE for Epoch 264 =1.58117
# RMSE for dev set =1.46206
# RMSE for Epoch 265 =1.54877
# RMSE for dev set =1.47574
# RMSE for Epoch 266 =1.48436
# RMSE for dev set =2.11955
# RMSE for Epoch 267 =1.83475
# RMSE for dev set =1.80063
# RMSE for Epoch 268 =1.47996
# RMSE for dev set =1.67641
# RMSE for Epoch 269 =1.57014
# RMSE for dev set =1.82172
# RMSE for Epoch 270 =1.47569
# RMSE for dev set =1.92938
# RMSE for Epoch 271 =1.57472
# RMSE for dev set =1.67951
# RMSE for Epoch 272 =1.40234
# RMSE for dev set =1.61713
# RMSE for Epoch 273 =1.4996
# RMSE for dev set =1.75041
# RMSE for Epoch 274 =1.54001
# RMSE for dev set =1.87364
# RMSE for Epoch 275 =1.52737
# RMSE for dev set =1.50476
# RMSE for Epoch 276 =1.73452
# RMSE for dev set =1.64592
# RMSE for Epoch 277 =1.50559
# RMSE for dev set =1.517
# RMSE for Epoch 278 =1.59098
# RMSE for dev set =1.54091
# RMSE for Epoch 279 =1.36595
# RMSE for dev set =2.27027
# RMSE for Epoch 280 =1.51013
# RMSE for dev set =1.91662
# RMSE for Epoch 281 =1.62683
# RMSE for dev set =1.93398
# RMSE for Epoch 282 =1.47527
# RMSE for dev set =1.5666
# RMSE for Epoch 283 =1.62177
# RMSE for dev set =1.49535
# RMSE for Epoch 284 =1.45784
# RMSE for dev set =1.5073
# RMSE for Epoch 285 =1.46777
# RMSE for dev set =1.57335
# RMSE for Epoch 286 =1.52928
# RMSE for dev set =1.75979
# RMSE for Epoch 287 =1.3782
# RMSE for dev set =1.6364
# RMSE for Epoch 288 =1.58563
# RMSE for dev set =1.51224
# RMSE for Epoch 289 =1.37859
# RMSE for dev set =1.40978
# RMSE for Epoch 290 =1.63883
# RMSE for dev set =1.59609
# RMSE for Epoch 291 =1.30744
# RMSE for dev set =1.73824
# RMSE for Epoch 292 =1.52019
# RMSE for dev set =1.61729
# RMSE for Epoch 293 =1.60543
# RMSE for dev set =1.64692
# RMSE for Epoch 294 =1.42889
# RMSE for dev set =2.08226
# RMSE for Epoch 295 =1.45609
# RMSE for dev set =1.7151
# RMSE for Epoch 296 =1.44191
# RMSE for dev set =1.42835
# RMSE for Epoch 297 =1.63347
# RMSE for dev set =1.64228
# RMSE for Epoch 298 =1.44626
# RMSE for dev set =1.77946
# RMSE for Epoch 299 =1.50514
# RMSE for dev set =1.52736
# RMSE for Epoch 300 =1.41678
# RMSE for dev set =1.66744
# RMSE for Epoch 301 =1.46327
# RMSE for dev set =1.83397
# RMSE for Epoch 302 =1.43062
# RMSE for dev set =1.59181
# RMSE for Epoch 303 =1.43352
# RMSE for dev set =1.5817
# RMSE for Epoch 304 =1.78264
# RMSE for dev set =1.83971
# RMSE for Epoch 305 =1.33116
# RMSE for dev set =1.83353
# RMSE for Epoch 306 =1.69829
# RMSE for dev set =1.69843
# RMSE for Epoch 307 =1.4245
# RMSE for dev set =1.51751
# RMSE for Epoch 308 =1.42318
# RMSE for dev set =1.42736
# RMSE for Epoch 309 =1.30162
# RMSE for dev set =1.78413
# RMSE for Epoch 310 =1.94177
# RMSE for dev set =1.69185
# RMSE for Epoch 311 =1.36108
# RMSE for dev set =1.70001
# RMSE for Epoch 312 =1.77245
# RMSE for dev set =1.83038
# RMSE for Epoch 313 =1.4384
# RMSE for dev set =1.48055
# RMSE for Epoch 314 =1.6465
# RMSE for dev set =1.7606
# RMSE for Epoch 315 =1.51388
# RMSE for dev set =1.69019
# RMSE for Epoch 316 =1.42824
# RMSE for dev set =2.4804
# RMSE for Epoch 317 =1.53353
# RMSE for dev set =1.6142
# RMSE for Epoch 318 =1.47863
# RMSE for dev set =1.70094
# RMSE for Epoch 319 =1.42476
# RMSE for dev set =1.83272
# RMSE for Epoch 320 =1.29512
# RMSE for dev set =2.28934
# RMSE for Epoch 321 =1.41665
# RMSE for dev set =1.82738
# RMSE for Epoch 322 =1.45727
# RMSE for dev set =1.8951
# RMSE for Epoch 323 =1.40257
# RMSE for dev set =1.46963
# RMSE for Epoch 324 =1.39238
# RMSE for dev set =1.60406
# RMSE for Epoch 325 =1.45444
# RMSE for dev set =1.84837
# RMSE for Epoch 326 =1.55499
# RMSE for dev set =1.88121
# RMSE for Epoch 327 =1.43055
# RMSE for dev set =1.61536
# RMSE for Epoch 328 =1.66131
# RMSE for dev set =1.61921
# RMSE for Epoch 329 =1.56899
# RMSE for dev set =1.65539
# RMSE for Epoch 330 =1.38088
# RMSE for dev set =1.69043
# RMSE for Epoch 331 =1.33632
# RMSE for dev set =1.62472
# RMSE for Epoch 332 =1.73816
# RMSE for dev set =1.6493
# RMSE for Epoch 333 =1.27255
# RMSE for dev set =1.65127
# RMSE for Epoch 334 =1.40952
# RMSE for dev set =1.48653
# RMSE for Epoch 335 =1.43758
# RMSE for dev set =1.66683
# RMSE for Epoch 336 =1.37227
# RMSE for dev set =2.00126
# RMSE for Epoch 337 =1.41992
# RMSE for dev set =1.51911
# RMSE for Epoch 338 =1.48528
# RMSE for dev set =1.53175
# RMSE for Epoch 339 =1.45019
# RMSE for dev set =1.63912
# RMSE for Epoch 340 =1.31825
# RMSE for dev set =1.5611
# RMSE for Epoch 341 =1.54772
# RMSE for dev set =1.85679
# RMSE for Epoch 342 =1.88162
# RMSE for dev set =1.99227
# RMSE for Epoch 343 =1.30571
# RMSE for dev set =1.35531
# RMSE for Epoch 344 =1.43694
# RMSE for dev set =2.07366
# RMSE for Epoch 345 =1.41036
# RMSE for dev set =1.52176
# RMSE for Epoch 346 =1.50361
# RMSE for dev set =1.6351
# RMSE for Epoch 347 =1.40191
# RMSE for dev set =1.63902
# RMSE for Epoch 348 =1.4706
# RMSE for dev set =1.70394
# RMSE for Epoch 349 =1.39414
# RMSE for dev set =1.53466
# RMSE for Epoch 350 =1.43301
# RMSE for dev set =1.4915
# RMSE for Epoch 351 =1.60151
# RMSE for dev set =1.71714
# RMSE for Epoch 352 =1.70323
# RMSE for dev set =1.65249
# RMSE for Epoch 353 =1.40204
# RMSE for dev set =1.87553
# RMSE for Epoch 354 =1.53705
# RMSE for dev set =2.09738
# RMSE for Epoch 355 =1.39146
# RMSE for dev set =2.07371
# RMSE for Epoch 356 =1.8677
# RMSE for dev set =2.38861
# RMSE for Epoch 357 =1.29099
# RMSE for dev set =1.82123
# RMSE for Epoch 358 =1.28113
# RMSE for dev set =1.55769
# RMSE for Epoch 359 =1.61297
# RMSE for dev set =1.58779
# RMSE for Epoch 360 =1.32861
# RMSE for dev set =1.56646
# RMSE for Epoch 361 =1.35309
# RMSE for dev set =1.84125
# RMSE for Epoch 362 =1.49539
# RMSE for dev set =1.82013
# RMSE for Epoch 363 =1.41945
# RMSE for dev set =1.70868
# RMSE for Epoch 364 =1.40741
# RMSE for dev set =1.83319
# RMSE for Epoch 365 =1.33238
# RMSE for dev set =1.77896
# RMSE for Epoch 366 =1.28629
# RMSE for dev set =1.54409
# RMSE for Epoch 367 =1.40338
# RMSE for dev set =1.51629
# RMSE for Epoch 368 =1.44861
# RMSE for dev set =1.39257
# RMSE for Epoch 369 =1.67607
# RMSE for dev set =1.50716
# RMSE for Epoch 370 =1.39472
# RMSE for dev set =1.73374
# RMSE for Epoch 371 =1.22935
# RMSE for dev set =1.89197
# RMSE for Epoch 372 =1.57834
# RMSE for dev set =2.63845
# RMSE for Epoch 373 =1.18317
# RMSE for dev set =1.48989
# RMSE for Epoch 374 =1.41619
# RMSE for dev set =1.95972
# RMSE for Epoch 375 =1.28889
# RMSE for dev set =1.76776
# RMSE for Epoch 376 =1.4821
# RMSE for dev set =1.61987
# RMSE for Epoch 377 =1.67527
# RMSE for dev set =1.49397
# RMSE for Epoch 378 =1.41703
# RMSE for dev set =1.51777
# RMSE for Epoch 379 =1.65876
# RMSE for dev set =1.99882
# RMSE for Epoch 380 =1.40345
# RMSE for dev set =1.48348
# RMSE for Epoch 381 =1.4608
# RMSE for dev set =1.43922
# RMSE for Epoch 382 =1.3027
# RMSE for dev set =1.68103
# RMSE for Epoch 383 =1.34262
# RMSE for dev set =1.90343
# RMSE for Epoch 384 =1.31416
# RMSE for dev set =1.56965
# RMSE for Epoch 385 =1.41185
# RMSE for dev set =1.63144
# RMSE for Epoch 386 =1.42036
# RMSE for dev set =1.56877
# RMSE for Epoch 387 =1.48149
# RMSE for dev set =1.54051
# RMSE for Epoch 388 =1.32249
# RMSE for dev set =1.73115
# RMSE for Epoch 389 =1.20089
# RMSE for dev set =1.54315
# RMSE for Epoch 390 =1.45336
# RMSE for dev set =1.94925
# RMSE for Epoch 391 =1.69888
# RMSE for dev set =1.78261
# RMSE for Epoch 392 =1.58062
# RMSE for dev set =1.65132
# RMSE for Epoch 393 =1.28967
# RMSE for dev set =1.67411
# RMSE for Epoch 394 =1.26932
# RMSE for dev set =1.48816
# RMSE for Epoch 395 =1.32824
# RMSE for dev set =1.39929
# RMSE for Epoch 396 =1.62606
# RMSE for dev set =1.62248
# RMSE for Epoch 397 =1.31179
# RMSE for dev set =1.60126
# RMSE for Epoch 398 =1.37333
# RMSE for dev set =1.58009
# RMSE for Epoch 399 =1.6027
# RMSE for dev set =1.58014

# %%
# Plot predictions from train_data
plot_images(5,data =train,result=result,training=False)

# %%
# Plot predictions from dev data
plot_images(5,data =dev,result=result_dev,training=False)

# %%
# Plot train/dev errors by epoch
plt.figure(figsize=(6,6))
plt.scatter(epoch,train_error)
plt.scatter(epoch,dev_error,color="red")

# %%
# Plot a row of the original image
plot_images(5,train)


# Plot a row of flipped images
plot_images(5,flip_images(train))
'''
# Plot rows moving image to all 4 orientations
plot_images(5,move_images(train,15,"right"))
plot_images(5,move_images(train,15,"left"))
plot_images(5,move_images(train,15,"up"))
plot_images(5,move_images(train,15,"down"))'''
# Out:
# '\n# Plot rows moving image to all 4 orientations\nplot_images(5,move_images(train,15,"right"))\nplot_images(5,move_images(train,15,"left"))\nplot_images(5,move_images(train,15,"up"))\nplot_images(5,move_images(train,15,"down"))'

# %%
# We start from the beginning, loading the original training/dev/test data, for the purpose of appending
#   our blurred/moved images to the original dataset to measure accuracy

# Loading the test and raw training datasets
raw = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')


# Converting image data into numpy arrays and scaling the images
raw["Image"] = raw["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)
test["Image"] = test["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)

# Remove rows with 'na', reshuffle, and re-index
raw.dropna(inplace=True)
test.dropna(inplace=True)
raw = raw.sample(frac=1)
raw.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

# Set first 1800 of the raw data to be training, and the remaining to be dev data
train_size = 1800
train = raw.iloc[0:train_size,:]
dev = raw.iloc[train_size:raw.shape[0],:]
train.reset_index(inplace=True,drop=True)
dev.reset_index(inplace=True,drop=True)

# %%
# Now blur all images in the training set, and append results to our training set
train = pd.concat([train,flip_images(train)],axis=0)

# Re-index
train.reset_index(inplace=True,drop=True)

# %%
# Convert train/dev/test to numpy array representations
train_data = train["Image"].as_matrix()
train_labels = np.asarray(train[train.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

dev_data = dev["Image"].as_matrix()
dev_labels = np.asarray(dev[dev.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

test_data = test["Image"].as_matrix()

# %%
print (train_data.shape)
print (train.shape)
print (dev_data.shape)
print (dev.shape)

# %%
# Try 2 convolutional layers, 2 fully connected layers

mini_batch_size=300
epochs = 25


# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])


# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])

# Same as previous exercize, return a 48*48 image with 32 filters
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)


# Same as previous exercise, next return a 24*24 image with 64 filters
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2) #returns a 24*24 image with 64 filters


# Fully connected layer
W_fc1 = weight_variable([24 * 24 * 64, 1024])
b_fc1 = bias_variable([1024])
h_pool2_flat = tf.reshape(h_pool2, [-1, 24*24*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Dropout to prevent overfit
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Fully connected layer
W_fc2 = weight_variable([1024, 1024])
b_fc2 = bias_variable([1024])
h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)
h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

# Prediction function
W_fc3 = weight_variable([1024, 30])
b_fc3 = bias_variable([30])
y = tf.matmul(h_fc2_drop, W_fc3) + b_fc3

# Define RMSE error, minimize with AdamOptimizer
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-2).minimize(error)

epoch=[i for i in range(epochs)]

# Track train/dev errors for plotting
train_error = []
dev_error = []

# GPU settings
config = tf.ConfigProto()
config.gpu_options.allow_growth=True


with tf.Session(config=config) as sess:
    
    # Initialize global vars
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        
        # Iterate by batch size
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Calculate acccuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of training data
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+str(" =")+str(train_accuracy))
        train_error.append(train_accuracy)
        
    
        # Determine accuracy on our dev data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        
        # Get batch of 20
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
        
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        
        # Calculate accuracy & error
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
        dev_error.append(dev_accuracy)
    
    

    #Predictions on train/dev/test for plotting
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
    result_test =make_predictions(test_data, mini_batch_size-1)
    
    sess.close()
# Out:
# RMSE for Epoch 0 =24.0588
# RMSE for dev set =14.5764
# RMSE for Epoch 1 =13.4813
# RMSE for dev set =19.977
# RMSE for Epoch 2 =11.1735
# RMSE for dev set =11.6924
# RMSE for Epoch 3 =5.43402
# RMSE for dev set =5.98648
# RMSE for Epoch 4 =7.86606
# RMSE for dev set =5.52002
# RMSE for Epoch 5 =5.82749
# RMSE for dev set =3.80948
# RMSE for Epoch 6 =6.95476
# RMSE for dev set =4.55212
# RMSE for Epoch 7 =8.57629
# RMSE for dev set =4.64378
# RMSE for Epoch 8 =4.53579
# RMSE for dev set =5.11631
# RMSE for Epoch 9 =9.21335
# RMSE for dev set =3.5984
# RMSE for Epoch 10 =6.55721
# RMSE for dev set =11.2763
# RMSE for Epoch 11 =5.82668
# RMSE for dev set =9.24065
# RMSE for Epoch 12 =7.42211
# RMSE for dev set =2.99815
# RMSE for Epoch 13 =4.46139
# RMSE for dev set =4.09926
# RMSE for Epoch 14 =3.34299
# RMSE for dev set =3.6872
# RMSE for Epoch 15 =3.86607
# RMSE for dev set =5.53211
# RMSE for Epoch 16 =3.69585
# RMSE for dev set =3.16568
# RMSE for Epoch 17 =3.33183
# RMSE for dev set =3.41013
# RMSE for Epoch 18 =3.73975
# RMSE for dev set =3.59161
# RMSE for Epoch 19 =3.801
# RMSE for dev set =3.34403
# RMSE for Epoch 20 =2.70781
# RMSE for dev set =2.74324
# RMSE for Epoch 21 =3.13085
# RMSE for dev set =3.04768
# RMSE for Epoch 22 =3.56795
# RMSE for dev set =3.25536
# RMSE for Epoch 23 =2.35166
# RMSE for dev set =2.7024
# RMSE for Epoch 24 =2.58307
# RMSE for dev set =2.7717

# %%
# Plot training and dev errors by epoch
plt.figure(figsize=(6,6))
plt.scatter(epoch,train_error)
plt.scatter(epoch,dev_error,color="red")

# %%
# Plot predicted facial keypoints from dev_data
plot_images(5,dev,result_dev,False)

# %%
# Plot predicted facial keypoints from test_data
plot_images(5,train,result,False)

# %%
# Submission
generate_results(result_test)
