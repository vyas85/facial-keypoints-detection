# %%
#Reference-https://www.tensorflow.org/get_started/mnist/pros

#Loading required libraries
import numpy as np
import pandas as pd
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.INFO)
import matplotlib.pyplot as plt



# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

np.random.seed(0)

# %%
#Loading the test and raw training datasets
raw = pd.read_csv('/Users/vyas/Dropbox/Berkeley MIDS/Applied Machine Learning/coursework/Projects/Facial Keypoints Detection/data/training.csv')
test = pd.read_csv('/Users/vyas/Dropbox/Berkeley MIDS/Applied Machine Learning/coursework/Projects/Facial Keypoints Detection/data/test.csv')

#Converting image data into numpy arrays
raw["Image"] = raw["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)
test["Image"] = test["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)

# %%
#dropping columns with na values since they will prevent the model from training correctly.
# Revisit this to come up with a better approach
raw.dropna(inplace=True)
test.dropna(inplace=True)

# %%
train = raw.loc[0:401,:]
dev = raw.loc[399:498,:]
dev.reset_index(inplace=True,drop=True)

# %%
#Visualize 5 example images:
def plot_images(num_images,data=train, result=None,training=True):
    plt.figure(figsize=(12,4))
    for i in range(num_images):
        img =  np.reshape(data.ix[i:i,"Image"].values[0],(96,96))
        plt.subplot(1,num_images,i+1)
        plt.axis('off')
        plt.imshow(img,cmap='Greys_r')
        #Creating a list of x and y values for keypoints for each image
        #These lists will be used to visualize the keypoints on the images below
        x_values = np.asarray(data[data.columns.get_level_values(0)[0:30:2]])
        y_values = np.asarray(data[data.columns.get_level_values(0)[1:30:2]])
        plt.scatter(x_values[i],y_values[i])
        if training==False:
            rx_values = np.asarray(result[result.columns.get_level_values(0)[0:30:2]])
            ry_values = np.asarray(result[result.columns.get_level_values(0)[1:30:2]])
            plt.scatter(rx_values[i],ry_values[i],marker="x",color='r')
            

plot_images(5)

# %%
train_data = train["Image"].as_matrix()
train_labels = np.asarray(train[train.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)
dev_data = dev["Image"].as_matrix()
dev_labels = np.asarray(dev[dev.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)
test_data = test["Image"].as_matrix()

# %%
def imgs_iterator(data,labels,batchSize):
    startIndex= 0
    totalSize = len(data)
    indices = np.arange(totalSize)
    np.random.shuffle(indices)
    
    for i in range(0,totalSize,batchSize):
        if totalSize-i>batchSize:
            batchIndices = indices[i:i+batchSize]
            yield np.stack(data[batchIndices]),labels[batchIndices]

# %%
#Single layer neural network with NO hidden units

batch_size=20
epochs = 1



sess = tf.InteractiveSession()

x = tf.placeholder(tf.float32, shape=[None, 9216])
y_ = tf.placeholder(tf.float32, shape=[None, 30])


W = tf.Variable(tf.zeros([9216,30]))
b = tf.Variable(tf.zeros([30]))

sess.run(tf.global_variables_initializer())

y = tf.matmul(x,W) + b


error = tf.sqrt(tf.reduce_mean(tf.square(tf.sub(y_,y))))


train_step = tf.train.GradientDescentOptimizer(0.01).minimize(error)

#with tf.Session() as sess:
#    sess.run(train_step, feed_dict={x: train_data, y_: train_labels})




for i in range(epochs):
    iter_ = imgs_iterator(train_data,train_labels,batch_size)
    try:
        next_batch =iter_.next()
        while next_batch!=None:
            train_data_instance,train_label_instance = next_batch
            train_instance = np.reshape(train_data_instance,(batch_size,9216))
            train_label_instance = np.reshape(train_label_instance,(batch_size,30))
            train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance})

            train_step.run(feed_dict={x: train_instance, y_: train_label_instance})
            next_batch =iter_.next()
    except StopIteration:
        next_batch=None
    if i%10==0:
        print "RMSE for Epoch "+str(i)+" ="+str(train_accuracy)

#Predictions:
feed_dict = {x: np.stack(train_data)}
predictions = y.eval(feed_dict)
#print predictions
result =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))

#Test- Predictions:
feed_dict = {x: np.stack(test_data)}
predictions = y.eval(feed_dict)
#print predictions
result_test =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))
# Out:
# RMSE for Epoch 0 =38.7451

# %%
plot_images(5,data =train,result=result,training=False)

# %%
#Building an initial model with one convolutional layer:

#Setting initial parameters:
patchSize=5
imageDimension = 96
num_filters_conv1 = 1
num_filters_conv2 = 1
num_hidden_units = 20

# %%
#2-layer convnet

batch_size=99
epochs = 40

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

#sess = tf.InteractiveSession()

#Input
x = tf.placeholder(tf.float32, shape=[None, 9216])
y_ = tf.placeholder(tf.float32, shape=[None, 30])

x_image = tf.reshape(x, [-1,96,96,1])#-1 because we don't know the batch size yet.

#
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1) #returns a 48*48 image with 32 filters

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2) #returns a 24*24 image with 64 filters

W_fc1 = weight_variable([24 * 24 * 64, 1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2, [-1, 24*24*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])



#sess.run(tf.global_variables_initializer())

y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2
#y = tf.matmul(x,W) + b


error = tf.sqrt(tf.reduce_mean(tf.square(tf.sub(y_,y))))


train_step = tf.train.AdamOptimizer(1e-4).minimize(error)

#with tf.Session() as sess:
#    sess.run(train_step, feed_dict={x: train_data, y_: train_labels})



with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        iter_ = imgs_iterator(train_data,train_labels,batch_size)
        try:
            next_batch =iter_.next()
            while next_batch!=None:
                train_data_instance,train_label_instance = next_batch
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.next()
        except StopIteration:
            next_batch=None
        
        print "RMSE for Epoch "+str(i)+" ="+str(train_accuracy)
        
    
    iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
    next_batch =iter_dev.next()
    dev_data_instance,dev_label_instance = next_batch
    dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
    dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
    dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
    print "RMSE for dev set ="+str(dev_accuracy)
    
    

    #Predictions:
    feed_dict = {x: np.stack(train_data), keep_prob: 1.0}
    predictions = y.eval(feed_dict)
    #print predictions
    result =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-aa1f4afd3f92> in <module>()
#      21
#      22 #Input
# ---> 23 x = tf.placeholder(tf.float32, shape=[None, 9216])
#      24 y_ = tf.placeholder(tf.float32, shape=[None, 30])
#      25
#
# NameError: name 'tf' is not defined

# %%
Swaminathanplot_images(5,data =train,result=result,training=False)

# %%
#3 convolutional layers and one fully connected layer

batch_size=99
epochs = 1000

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

#sess = tf.InteractiveSession()

#Input
x = tf.placeholder(tf.float32, shape=[None, 9216])
y_ = tf.placeholder(tf.float32, shape=[None, 30])

x_image = tf.reshape(x, [-1,96,96,1])#-1 because we don't know the batch size yet.

#
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1) #returns a 48*48 image with 32 filters

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2) #returns a 24*24 image with 64 filters

#start
W_conv3 = weight_variable([5, 5, 64, 128])
b_conv3 = bias_variable([128])

h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3) #returns a 12*12 image with 128 filters

#end

W_fc1 = weight_variable([12 * 12 * 128, 1024])
b_fc1 = bias_variable([1024])

h_pool3_flat = tf.reshape(h_pool3, [-1, 12*12*128])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])



#sess.run(tf.global_variables_initializer())

y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2
#y = tf.matmul(x,W) + b


error = tf.sqrt(tf.reduce_mean(tf.square(tf.sub(y_,y))))


train_step = tf.train.AdamOptimizer(1e-4).minimize(error)

#with tf.Session() as sess:
#    sess.run(train_step, feed_dict={x: train_data, y_: train_labels})

epoch=[i for i in range(epochs)]
train_error = []
dev_error = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        iter_ = imgs_iterator(train_data,train_labels,batch_size)
        try:
            next_batch =iter_.next()
            while next_batch!=None:
                train_data_instance,train_label_instance = next_batch
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.next()
        except StopIteration:
            next_batch=None
        
        print "RMSE for Epoch "+str(i)+" ="+str(train_accuracy)
        train_error.append(train_accuracy)
        
    
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        next_batch =iter_dev.next()
        dev_data_instance,dev_label_instance = next_batch
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print "RMSE for dev set ="+str(dev_accuracy)
        dev_error.append(dev_accuracy)
    
    

    #Predictions:
    feed_dict = {x: np.stack(train_data), keep_prob: 1.0}
    predictions = y.eval(feed_dict)
    #print predictions
    result =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))
# Out:
# RMSE for Epoch 0 =23.9826
# RMSE for dev set =15.7147
# RMSE for Epoch 1 =14.7114
# RMSE for dev set =14.3285
# RMSE for Epoch 2 =11.6105
# RMSE for dev set =10.7129
# RMSE for Epoch 3 =13.7518
# RMSE for dev set =12.7015
# RMSE for Epoch 4 =12.8312
# RMSE for dev set =11.5133
# RMSE for Epoch 5 =10.1238
# RMSE for dev set =8.80077
# RMSE for Epoch 6 =7.92582
# RMSE for dev set =7.62339
# RMSE for Epoch 7 =7.67703
# RMSE for dev set =7.69847
# RMSE for Epoch 8 =8.67758
# RMSE for dev set =7.58961
# RMSE for Epoch 9 =7.79745
# RMSE for dev set =7.21145
# RMSE for Epoch 10 =7.91865
# RMSE for dev set =6.66262
# RMSE for Epoch 11 =6.21615
# RMSE for dev set =5.97433
# RMSE for Epoch 12 =6.48974
# RMSE for dev set =6.48071
# RMSE for Epoch 13 =6.64032
# RMSE for dev set =5.36083
# RMSE for Epoch 14 =5.0971
# RMSE for dev set =5.27761
# RMSE for Epoch 15 =6.66572
# RMSE for dev set =6.38704
# RMSE for Epoch 16 =4.64933
# RMSE for dev set =4.62318
# RMSE for Epoch 17 =5.67248
# RMSE for dev set =5.75623
# RMSE for Epoch 18 =4.85433
# RMSE for dev set =4.40109
# RMSE for Epoch 19 =5.24041
# RMSE for dev set =5.79133
# RMSE for Epoch 20 =4.81039
# RMSE for dev set =4.15916
# RMSE for Epoch 21 =4.8159
# RMSE for dev set =5.21914
# RMSE for Epoch 22 =4.68208
# RMSE for dev set =4.21654
# RMSE for Epoch 23 =4.52935
# RMSE for dev set =4.66835
# RMSE for Epoch 24 =5.09285
# RMSE for dev set =4.68759
# RMSE for Epoch 25 =4.12399
# RMSE for dev set =4.09072
# RMSE for Epoch 26 =4.91653
# RMSE for dev set =4.52274
# RMSE for Epoch 27 =4.08245
# RMSE for dev set =4.21421
# RMSE for Epoch 28 =4.66111
# RMSE for dev set =4.47764
# RMSE for Epoch 29 =4.04803
# RMSE for dev set =4.06983
# RMSE for Epoch 30 =4.67043
# RMSE for dev set =4.28659
# RMSE for Epoch 31 =3.81201
# RMSE for dev set =3.93207
# RMSE for Epoch 32 =4.04145
# RMSE for dev set =4.07607
# RMSE for Epoch 33 =4.01766
# RMSE for dev set =3.82154
# RMSE for Epoch 34 =3.86923
# RMSE for dev set =3.98422
# RMSE for Epoch 35 =4.2199
# RMSE for dev set =3.99996
# RMSE for Epoch 36 =4.0873
# RMSE for dev set =3.89287
# RMSE for Epoch 37 =3.67389
# RMSE for dev set =3.8652
# RMSE for Epoch 38 =3.81723
# RMSE for dev set =3.48333
# RMSE for Epoch 39 =3.39828
# RMSE for dev set =4.0579
# RMSE for Epoch 40 =3.97554
# RMSE for dev set =3.33275
# RMSE for Epoch 41 =3.93851
# RMSE for dev set =4.5413
# RMSE for Epoch 42 =3.14419
# RMSE for dev set =3.14618
# RMSE for Epoch 43 =4.58037
# RMSE for dev set =3.87422
# RMSE for Epoch 44 =3.41018
# RMSE for dev set =3.8403
# RMSE for Epoch 45 =3.90058
# RMSE for dev set =3.58632
# RMSE for Epoch 46 =3.5082
# RMSE for dev set =3.38268
# RMSE for Epoch 47 =3.37626
# RMSE for dev set =3.44517
# RMSE for Epoch 48 =3.46935
# RMSE for dev set =3.53034
# RMSE for Epoch 49 =3.65239
# RMSE for dev set =3.51499
# RMSE for Epoch 50 =3.22188
# RMSE for dev set =3.33977
# RMSE for Epoch 51 =3.24388
# RMSE for dev set =3.30184
# RMSE for Epoch 52 =3.29799
# RMSE for dev set =3.27246
# RMSE for Epoch 53 =3.57531
# RMSE for dev set =3.69567
# RMSE for Epoch 54 =3.25274
# RMSE for dev set =3.05175
# RMSE for Epoch 55 =3.93811
# RMSE for dev set =3.37857
# RMSE for Epoch 56 =3.02199
# RMSE for dev set =3.22535
# RMSE for Epoch 57 =3.32553
# RMSE for dev set =3.23718
# RMSE for Epoch 58 =3.03972
# RMSE for dev set =3.3539
# RMSE for Epoch 59 =3.27705
# RMSE for dev set =2.9361
# RMSE for Epoch 60 =3.9271
# RMSE for dev set =3.94223
# RMSE for Epoch 61 =2.89474
# RMSE for dev set =3.11911
# RMSE for Epoch 62 =3.0419
# RMSE for dev set =3.11476
# RMSE for Epoch 63 =2.83495
# RMSE for dev set =3.12277
# RMSE for Epoch 64 =3.37052
# RMSE for dev set =3.03752
# RMSE for Epoch 65 =3.49237
# RMSE for dev set =3.32426
# RMSE for Epoch 66 =2.76955
# RMSE for dev set =2.95182
# RMSE for Epoch 67 =4.26868
# RMSE for dev set =3.27542
# RMSE for Epoch 68 =2.85717
# RMSE for dev set =3.4973
# RMSE for Epoch 69 =2.91728
# RMSE for dev set =2.76638
# RMSE for Epoch 70 =3.64951
# RMSE for dev set =3.76803
# RMSE for Epoch 71 =2.6226
# RMSE for dev set =2.80642
# RMSE for Epoch 72 =3.46153
# RMSE for dev set =3.00993
# RMSE for Epoch 73 =3.14805
# RMSE for dev set =3.33883
# RMSE for Epoch 74 =2.94753
# RMSE for dev set =3.33658
# RMSE for Epoch 75 =2.75132
# RMSE for dev set =2.8529
# RMSE for Epoch 76 =2.73697
# RMSE for dev set =2.8819
# RMSE for Epoch 77 =3.33471
# RMSE for dev set =3.43923
# RMSE for Epoch 78 =2.72778
# RMSE for dev set =2.8185
# RMSE for Epoch 79 =2.87523
# RMSE for dev set =2.90361
# RMSE for Epoch 80 =3.19609
# RMSE for dev set =3.63399
# RMSE for Epoch 81 =2.55673
# RMSE for dev set =3.08973
# RMSE for Epoch 82 =2.68215
# RMSE for dev set =2.70904
# RMSE for Epoch 83 =3.57556
# RMSE for dev set =2.83451
# RMSE for Epoch 84 =3.18167
# RMSE for dev set =3.09043
# RMSE for Epoch 85 =2.8828
# RMSE for dev set =3.11881
# RMSE for Epoch 86 =2.91951
# RMSE for dev set =3.04527
# RMSE for Epoch 87 =2.97156
# RMSE for dev set =2.98578
# RMSE for Epoch 88 =2.63965
# RMSE for dev set =2.85283
# RMSE for Epoch 89 =2.40139
# RMSE for dev set =2.67992
# RMSE for Epoch 90 =2.89679
# RMSE for dev set =2.72512
# RMSE for Epoch 91 =2.56511
# RMSE for dev set =3.49027
# RMSE for Epoch 92 =2.29214
# RMSE for dev set =2.6285
# RMSE for Epoch 93 =2.5136
# RMSE for dev set =2.56032
# RMSE for Epoch 94 =2.63395
# RMSE for dev set =2.52885
# RMSE for Epoch 95 =3.94498
# RMSE for dev set =3.3835
# RMSE for Epoch 96 =2.2674
# RMSE for dev set =3.01902
# RMSE for Epoch 97 =2.47974
# RMSE for dev set =2.55022
# RMSE for Epoch 98 =3.04639
# RMSE for dev set =2.82816
# RMSE for Epoch 99 =2.40115
# RMSE for dev set =3.1061
# RMSE for Epoch 100 =2.22581
# RMSE for dev set =2.58499
# RMSE for Epoch 101 =2.63608
# RMSE for dev set =2.51652
# RMSE for Epoch 102 =3.29964
# RMSE for dev set =3.20466
# RMSE for Epoch 103 =2.41856
# RMSE for dev set =2.57197
# RMSE for Epoch 104 =2.38064
# RMSE for dev set =2.77003
# RMSE for Epoch 105 =2.73581
# RMSE for dev set =3.03952
# RMSE for Epoch 106 =2.54787
# RMSE for dev set =3.32392
# RMSE for Epoch 107 =2.18164
# RMSE for dev set =2.65814
# RMSE for Epoch 108 =2.43752
# RMSE for dev set =2.42476
# RMSE for Epoch 109 =2.85524
# RMSE for dev set =2.89438
# RMSE for Epoch 110 =2.16248
# RMSE for dev set =2.78841
# RMSE for Epoch 111 =2.14577
# RMSE for dev set =2.4039
# RMSE for Epoch 112 =2.22707
# RMSE for dev set =2.40965
# RMSE for Epoch 113 =2.25997
# RMSE for dev set =2.40056
# RMSE for Epoch 114 =2.99427
# RMSE for dev set =2.39168
# RMSE for Epoch 115 =3.58302
# RMSE for dev set =4.12584
# RMSE for Epoch 116 =2.40328
# RMSE for dev set =2.35548
# RMSE for Epoch 117 =2.81404
# RMSE for dev set =2.57901
# RMSE for Epoch 118 =2.26324
# RMSE for dev set =3.54582
# RMSE for Epoch 119 =2.04458
# RMSE for dev set =2.34265
# RMSE for Epoch 120 =2.64578
# RMSE for dev set =2.4446
# RMSE for Epoch 121 =2.14427
# RMSE for dev set =2.93451
# RMSE for Epoch 122 =2.06594
# RMSE for dev set =2.41628
# RMSE for Epoch 123 =3.02042
# RMSE for dev set =2.63711
# RMSE for Epoch 124 =2.1403
# RMSE for dev set =2.51599
# RMSE for Epoch 125 =2.10333
# RMSE for dev set =2.38052
# RMSE for Epoch 126 =2.49434
# RMSE for dev set =2.56253
# RMSE for Epoch 127 =2.19197
# RMSE for dev set =2.55433
# RMSE for Epoch 128 =2.33141
# RMSE for dev set =2.55231
# RMSE for Epoch 129 =2.22017
# RMSE for dev set =2.31984
# RMSE for Epoch 130 =2.65478
# RMSE for dev set =3.43004
# RMSE for Epoch 131 =1.95522
# RMSE for dev set =2.28504
# RMSE for Epoch 132 =2.70948
# RMSE for dev set =2.47083
# RMSE for Epoch 133 =1.96605
# RMSE for dev set =2.51999
# RMSE for Epoch 134 =2.0085
# RMSE for dev set =2.34064
# RMSE for Epoch 135 =2.33469
# RMSE for dev set =2.35342
# RMSE for Epoch 136 =2.44302
# RMSE for dev set =2.69856
# RMSE for Epoch 137 =2.24299
# RMSE for dev set =2.48281
# RMSE for Epoch 138 =2.15394
# RMSE for dev set =2.65202
# RMSE for Epoch 139 =1.97747
# RMSE for dev set =2.51673
# RMSE for Epoch 140 =1.96873
# RMSE for dev set =2.2559
# RMSE for Epoch 141 =2.5061
# RMSE for dev set =2.7312
# RMSE for Epoch 142 =2.05159
# RMSE for dev set =2.35211
# RMSE for Epoch 143 =2.32425
# RMSE for dev set =2.92151
# RMSE for Epoch 144 =1.90813
# RMSE for dev set =2.69776
# RMSE for Epoch 145 =1.90501
# RMSE for dev set =2.20231
# RMSE for Epoch 146 =2.54853
# RMSE for dev set =2.64993
# RMSE for Epoch 147 =2.04784
# RMSE for dev set =2.88902
# RMSE for Epoch 148 =1.78795
# RMSE for dev set =2.31824
# RMSE for Epoch 149 =1.90109
# RMSE for dev set =2.42903
# RMSE for Epoch 150 =3.64286
# RMSE for dev set =2.78859
# RMSE for Epoch 151 =2.16452
# RMSE for dev set =3.08176
# RMSE for Epoch 152 =1.91603
# RMSE for dev set =2.23253
# RMSE for Epoch 153 =2.20381
# RMSE for dev set =2.6227
# RMSE for Epoch 154 =2.12275
# RMSE for dev set =2.43299
# RMSE for Epoch 155 =1.98932
# RMSE for dev set =2.35443
# RMSE for Epoch 156 =2.33055
# RMSE for dev set =3.14216
# RMSE for Epoch 157 =2.12512
# RMSE for dev set =2.28588
# RMSE for Epoch 158 =2.47105
# RMSE for dev set =2.68625
# RMSE for Epoch 159 =2.15413
# RMSE for dev set =2.94719
# RMSE for Epoch 160 =1.94189
# RMSE for dev set =2.37194
# RMSE for Epoch 161 =2.96598
# RMSE for dev set =2.35569
# RMSE for Epoch 162 =2.20435
# RMSE for dev set =2.78648
# RMSE for Epoch 163 =1.83416
# RMSE for dev set =2.34207
# RMSE for Epoch 164 =1.95012
# RMSE for dev set =2.35811
# RMSE for Epoch 165 =1.9087
# RMSE for dev set =2.20126
# RMSE for Epoch 166 =2.3715
# RMSE for dev set =2.23352
# RMSE for Epoch 167 =2.42598
# RMSE for dev set =2.94575
# RMSE for Epoch 168 =1.96623
# RMSE for dev set =2.19073
# RMSE for Epoch 169 =2.76719
# RMSE for dev set =2.28176
# RMSE for Epoch 170 =2.13356
# RMSE for dev set =2.42193
# RMSE for Epoch 171 =1.92841
# RMSE for dev set =2.17992
# RMSE for Epoch 172 =2.38855
# RMSE for dev set =2.54054
# RMSE for Epoch 173 =1.80391
# RMSE for dev set =2.43102
# RMSE for Epoch 174 =1.98058
# RMSE for dev set =2.21582
# RMSE for Epoch 175 =1.98976
# RMSE for dev set =2.29012
# RMSE for Epoch 176 =1.84907
# RMSE for dev set =2.45294
# RMSE for Epoch 177 =2.01259
# RMSE for dev set =2.39805
# RMSE for Epoch 178 =1.74556
# RMSE for dev set =2.14522
# RMSE for Epoch 179 =1.90091
# RMSE for dev set =2.35373
# RMSE for Epoch 180 =1.76182
# RMSE for dev set =2.35487
# RMSE for Epoch 181 =2.56926
# RMSE for dev set =2.52876
# RMSE for Epoch 182 =1.87625
# RMSE for dev set =2.12055
# RMSE for Epoch 183 =1.93122
# RMSE for dev set =2.11599
# RMSE for Epoch 184 =2.21976
# RMSE for dev set =2.53289
# RMSE for Epoch 185 =2.19339
# RMSE for dev set =2.38367
# RMSE for Epoch 186 =1.75797
# RMSE for dev set =2.35595
# RMSE for Epoch 187 =2.10294
# RMSE for dev set =2.13766
# RMSE for Epoch 188 =2.48496
# RMSE for dev set =2.27087
# RMSE for Epoch 189 =2.37463
# RMSE for dev set =2.60335
# RMSE for Epoch 190 =1.873
# RMSE for dev set =2.17123
# RMSE for Epoch 191 =2.16619
# RMSE for dev set =2.16818
# RMSE for Epoch 192 =2.86765
# RMSE for dev set =3.54654
# RMSE for Epoch 193 =2.11129
# RMSE for dev set =2.46923
# RMSE for Epoch 194 =1.81499
# RMSE for dev set =2.34651
# RMSE for Epoch 195 =2.81884
# RMSE for dev set =2.71055
# RMSE for Epoch 196 =1.6077
# RMSE for dev set =2.47522
# RMSE for Epoch 197 =1.70809
# RMSE for dev set =2.18959
# RMSE for Epoch 198 =2.19666
# RMSE for dev set =2.39953
# RMSE for Epoch 199 =1.67427
# RMSE for dev set =2.19387
# RMSE for Epoch 200 =2.4727
# RMSE for dev set =2.64284
# RMSE for Epoch 201 =1.80048
# RMSE for dev set =2.26582
# RMSE for Epoch 202 =1.68967
# RMSE for dev set =2.62961
# RMSE for Epoch 203 =3.95969
# RMSE for dev set =3.62004
# RMSE for Epoch 204 =2.14771
# RMSE for dev set =2.13098
# RMSE for Epoch 205 =2.19367
# RMSE for dev set =2.3912
# RMSE for Epoch 206 =2.74031
# RMSE for dev set =3.60742
# RMSE for Epoch 207 =2.23411
# RMSE for dev set =2.06784
# RMSE for Epoch 208 =2.5794
# RMSE for dev set =2.10635
# RMSE for Epoch 209 =1.95478
# RMSE for dev set =2.18447
# RMSE for Epoch 210 =1.96254
# RMSE for dev set =2.49542
# RMSE for Epoch 211 =1.70925
# RMSE for dev set =2.07944
# RMSE for Epoch 212 =2.11561
# RMSE for dev set =2.30763
# RMSE for Epoch 213 =1.70673
# RMSE for dev set =2.48121
# RMSE for Epoch 214 =1.71224
# RMSE for dev set =2.10221
# RMSE for Epoch 215 =2.70195
# RMSE for dev set =2.07217
# RMSE for Epoch 216 =1.79949
# RMSE for dev set =2.92484
# RMSE for Epoch 217 =1.6503
# RMSE for dev set =2.231
# RMSE for Epoch 218 =2.66306
# RMSE for dev set =2.92245
# RMSE for Epoch 219 =1.58908
# RMSE for dev set =2.24447
# RMSE for Epoch 220 =1.75001
# RMSE for dev set =2.20301
# RMSE for Epoch 221 =2.29215
# RMSE for dev set =2.46331
# RMSE for Epoch 222 =1.74472
# RMSE for dev set =2.08402
# RMSE for Epoch 223 =1.78933
# RMSE for dev set =2.03694
# RMSE for Epoch 224 =2.21035
# RMSE for dev set =2.26085
# RMSE for Epoch 225 =1.76305
# RMSE for dev set =2.02426
# RMSE for Epoch 226 =1.67651
# RMSE for dev set =2.10366
# RMSE for Epoch 227 =2.26809
# RMSE for dev set =2.12429
# RMSE for Epoch 228 =2.11927
# RMSE for dev set =2.36539
# RMSE for Epoch 229 =1.65806
# RMSE for dev set =2.05912
# RMSE for Epoch 230 =1.7895
# RMSE for dev set =2.10619
# RMSE for Epoch 231 =1.63654
# RMSE for dev set =2.02819
# RMSE for Epoch 232 =1.63347
# RMSE for dev set =1.99794
# RMSE for Epoch 233 =1.87885
# RMSE for dev set =2.31197
# RMSE for Epoch 234 =1.54457
# RMSE for dev set =2.11847
# RMSE for Epoch 235 =2.40375
# RMSE for dev set =2.47075
# RMSE for Epoch 236 =1.77611
# RMSE for dev set =2.35432
# RMSE for Epoch 237 =1.61744
# RMSE for dev set =2.01664
# RMSE for Epoch 238 =2.25328
# RMSE for dev set =2.18196
# RMSE for Epoch 239 =1.57654
# RMSE for dev set =2.02939
# RMSE for Epoch 240 =1.97053
# RMSE for dev set =2.02569
# RMSE for Epoch 241 =1.8302
# RMSE for dev set =2.23306
# RMSE for Epoch 242 =2.00515
# RMSE for dev set =2.72858
# RMSE for Epoch 243 =1.61608
# RMSE for dev set =2.01184
# RMSE for Epoch 244 =1.81569
# RMSE for dev set =2.16888
# RMSE for Epoch 245 =2.91776
# RMSE for dev set =2.75203
# RMSE for Epoch 246 =1.74378
# RMSE for dev set =2.09784
# RMSE for Epoch 247 =1.81339
# RMSE for dev set =2.27879
# RMSE for Epoch 248 =2.5231
# RMSE for dev set =3.22055
# RMSE for Epoch 249 =1.92565
# RMSE for dev set =2.11295
# RMSE for Epoch 250 =2.33396
# RMSE for dev set =2.05167
# RMSE for Epoch 251 =1.61308
# RMSE for dev set =2.03142
# RMSE for Epoch 252 =1.70942
# RMSE for dev set =2.0143
# RMSE for Epoch 253 =1.68022
# RMSE for dev set =2.35527
# RMSE for Epoch 254 =1.83663
# RMSE for dev set =1.98145
# RMSE for Epoch 255 =2.56149
# RMSE for dev set =1.96773
# RMSE for Epoch 256 =1.87234
# RMSE for dev set =2.59058
# RMSE for Epoch 257 =1.70762
# RMSE for dev set =2.03073
# RMSE for Epoch 258 =1.57657
# RMSE for dev set =1.9685
# RMSE for Epoch 259 =1.60173
# RMSE for dev set =1.96684
# RMSE for Epoch 260 =1.58458
# RMSE for dev set =2.01181
# RMSE for Epoch 261 =1.69597
# RMSE for dev set =2.0314
# RMSE for Epoch 262 =1.51012
# RMSE for dev set =1.96267
# RMSE for Epoch 263 =2.09863
# RMSE for dev set =2.0458
# RMSE for Epoch 264 =1.61323
# RMSE for dev set =1.98041
# RMSE for Epoch 265 =1.94272
# RMSE for dev set =2.01718
# RMSE for Epoch 266 =1.78876
# RMSE for dev set =2.21474
# RMSE for Epoch 267 =1.5113
# RMSE for dev set =1.99614
# RMSE for Epoch 268 =1.74677
# RMSE for dev set =2.01916
# RMSE for Epoch 269 =1.60675
# RMSE for dev set =2.32925
# RMSE for Epoch 270 =1.58664
# RMSE for dev set =1.9783
# RMSE for Epoch 271 =2.14733
# RMSE for dev set =2.50815
# RMSE for Epoch 272 =1.64636
# RMSE for dev set =1.94255
# RMSE for Epoch 273 =1.7371
# RMSE for dev set =1.94671
# RMSE for Epoch 274 =2.01044
# RMSE for dev set =2.12184
# RMSE for Epoch 275 =1.56208
# RMSE for dev set =2.09937
# RMSE for Epoch 276 =1.56293
# RMSE for dev set =1.98408
# RMSE for Epoch 277 =1.68544
# RMSE for dev set =2.15899
# RMSE for Epoch 278 =1.57264
# RMSE for dev set =2.07151
# RMSE for Epoch 279 =1.52168
# RMSE for dev set =1.93682
# RMSE for Epoch 280 =1.72445
# RMSE for dev set =2.30172
# RMSE for Epoch 281 =1.5332
# RMSE for dev set =1.92416
# RMSE for Epoch 282 =1.60045
# RMSE for dev set =1.96502
# RMSE for Epoch 283 =1.94153
# RMSE for dev set =2.14204
# RMSE for Epoch 284 =1.71683
# RMSE for dev set =1.92919
# RMSE for Epoch 285 =1.61118
# RMSE for dev set =1.93
# RMSE for Epoch 286 =1.91658
# RMSE for dev set =2.26662
# RMSE for Epoch 287 =1.46922
# RMSE for dev set =1.96404
# RMSE for Epoch 288 =1.69681
# RMSE for dev set =1.93614
# RMSE for Epoch 289 =1.56754
# RMSE for dev set =1.98623
# RMSE for Epoch 290 =1.47022
# RMSE for dev set =1.94803
# RMSE for Epoch 291 =1.65273
# RMSE for dev set =1.96351
# RMSE for Epoch 292 =1.57465
# RMSE for dev set =1.95286
# RMSE for Epoch 293 =1.51718
# RMSE for dev set =1.97125
# RMSE for Epoch 294 =1.82142
# RMSE for dev set =2.04991
# RMSE for Epoch 295 =1.54553
# RMSE for dev set =2.37323
# RMSE for Epoch 296 =1.49254
# RMSE for dev set =1.95193
# RMSE for Epoch 297 =1.74551
# RMSE for dev set =2.27119
# RMSE for Epoch 298 =1.47286
# RMSE for dev set =1.92065
# RMSE for Epoch 299 =1.91232
# RMSE for dev set =2.08443
# RMSE for Epoch 300 =1.59836
# RMSE for dev set =2.04232
# RMSE for Epoch 301 =1.53346
# RMSE for dev set =1.94073
# RMSE for Epoch 302 =1.62214
# RMSE for dev set =1.91361
# RMSE for Epoch 303 =1.7477
# RMSE for dev set =2.28995
# RMSE for Epoch 304 =1.456
# RMSE for dev set =1.96186
# RMSE for Epoch 305 =1.72193
# RMSE for dev set =2.09131
# RMSE for Epoch 306 =1.45331
# RMSE for dev set =1.97504
# RMSE for Epoch 307 =1.42513
# RMSE for dev set =2.05199
# RMSE for Epoch 308 =1.44719
# RMSE for dev set =2.02073
# RMSE for Epoch 309 =1.98888
# RMSE for dev set =2.18453
# RMSE for Epoch 310 =1.56845
# RMSE for dev set =2.19379
# RMSE for Epoch 311 =1.55634
# RMSE for dev set =1.9272
# RMSE for Epoch 312 =1.63046
# RMSE for dev set =2.06058
# RMSE for Epoch 313 =1.5357
# RMSE for dev set =1.95253
# RMSE for Epoch 314 =1.49741
# RMSE for dev set =1.94158
# RMSE for Epoch 315 =1.39466
# RMSE for dev set =1.93356
# RMSE for Epoch 316 =1.89853
# RMSE for dev set =2.30879
# RMSE for Epoch 317 =1.53047
# RMSE for dev set =2.09601
# RMSE for Epoch 318 =1.39336
# RMSE for dev set =2.09018
# RMSE for Epoch 319 =2.11451
# RMSE for dev set =1.94004
# RMSE for Epoch 320 =1.64732
# RMSE for dev set =2.87235
# RMSE for Epoch 321 =1.7813
# RMSE for dev set =2.11387
# RMSE for Epoch 322 =2.37341
# RMSE for dev set =2.07343
# RMSE for Epoch 323 =1.45802
# RMSE for dev set =2.51737
# RMSE for Epoch 324 =1.4132
# RMSE for dev set =1.92671
# RMSE for Epoch 325 =1.60406
# RMSE for dev set =1.92805
# RMSE for Epoch 326 =1.54406
# RMSE for dev set =2.12676
# RMSE for Epoch 327 =1.48349
# RMSE for dev set =1.96667
# RMSE for Epoch 328 =1.50003
# RMSE for dev set =1.97285
# RMSE for Epoch 329 =1.65498
# RMSE for dev set =1.94003
# RMSE for Epoch 330 =1.53508
# RMSE for dev set =2.01931
# RMSE for Epoch 331 =1.39406
# RMSE for dev set =2.02271
# RMSE for Epoch 332 =1.46867
# RMSE for dev set =2.04109
# RMSE for Epoch 333 =1.71644
# RMSE for dev set =2.02757
# RMSE for Epoch 334 =1.49344
# RMSE for dev set =2.02904
# RMSE for Epoch 335 =1.49259
# RMSE for dev set =1.92339
# RMSE for Epoch 336 =1.57309
# RMSE for dev set =1.937
# RMSE for Epoch 337 =1.40623
# RMSE for dev set =1.99404
# RMSE for Epoch 338 =1.74258
# RMSE for dev set =2.21555
# RMSE for Epoch 339 =1.38414
# RMSE for dev set =1.86821
# RMSE for Epoch 340 =1.53526
# RMSE for dev set =1.88421
# RMSE for Epoch 341 =2.25851
# RMSE for dev set =2.52176
# RMSE for Epoch 342 =1.43347
# RMSE for dev set =2.07945
# RMSE for Epoch 343 =1.50383
# RMSE for dev set =1.96835
# RMSE for Epoch 344 =2.52008
# RMSE for dev set =2.02302
# RMSE for Epoch 345 =1.3145
# RMSE for dev set =2.11715
# RMSE for Epoch 346 =1.80363
# RMSE for dev set =1.89008
# RMSE for Epoch 347 =1.69162
# RMSE for dev set =2.121
# RMSE for Epoch 348 =1.39631
# RMSE for dev set =1.96676
# RMSE for Epoch 349 =2.02153
# RMSE for dev set =2.36435
# RMSE for Epoch 350 =1.37379
# RMSE for dev set =2.02179
# RMSE for Epoch 351 =1.58684
# RMSE for dev set =2.00339
# RMSE for Epoch 352 =2.14737
# RMSE for dev set =2.3809
# RMSE for Epoch 353 =1.38111
# RMSE for dev set =1.98426
# RMSE for Epoch 354 =1.40783
# RMSE for dev set =1.92745
# RMSE for Epoch 355 =1.39734
# RMSE for dev set =1.91138
# RMSE for Epoch 356 =1.42916
# RMSE for dev set =2.00645
# RMSE for Epoch 357 =1.73189
# RMSE for dev set =2.24514
# RMSE for Epoch 358 =1.36573
# RMSE for dev set =2.08804
# RMSE for Epoch 359 =1.40033
# RMSE for dev set =1.92391
# RMSE for Epoch 360 =1.71439
# RMSE for dev set =1.91385
# RMSE for Epoch 361 =1.63479
# RMSE for dev set =2.293
# RMSE for Epoch 362 =1.42157
# RMSE for dev set =1.83303
# RMSE for Epoch 363 =1.56612
# RMSE for dev set =2.04548
# RMSE for Epoch 364 =1.32465
# RMSE for dev set =1.90185
# RMSE for Epoch 365 =1.57564
# RMSE for dev set =2.06635
# RMSE for Epoch 366 =1.45516
# RMSE for dev set =2.23262
# RMSE for Epoch 367 =1.56864
# RMSE for dev set =1.92968
# RMSE for Epoch 368 =1.73706
# RMSE for dev set =1.86851
# RMSE for Epoch 369 =1.57247
# RMSE for dev set =2.76621
# RMSE for Epoch 370 =2.16786
# RMSE for dev set =2.31103
# RMSE for Epoch 371 =2.45611
# RMSE for dev set =1.9111
# RMSE for Epoch 372 =1.37559
# RMSE for dev set =2.08389
# RMSE for Epoch 373 =1.37099
# RMSE for dev set =1.87865
# RMSE for Epoch 374 =1.51863
# RMSE for dev set =1.90536
# RMSE for Epoch 375 =1.44166
# RMSE for dev set =1.91344
# RMSE for Epoch 376 =1.38425
# RMSE for dev set =1.8831
# RMSE for Epoch 377 =1.7275
# RMSE for dev set =2.20615
# RMSE for Epoch 378 =1.30288
# RMSE for dev set =1.85455
# RMSE for Epoch 379 =1.39508
# RMSE for dev set =1.90676
# RMSE for Epoch 380 =1.91583
# RMSE for dev set =2.14385
# RMSE for Epoch 381 =1.36453
# RMSE for dev set =2.15134
# RMSE for Epoch 382 =1.3787
# RMSE for dev set =2.01033
# RMSE for Epoch 383 =1.47879
# RMSE for dev set =1.90845
# RMSE for Epoch 384 =1.67938
# RMSE for dev set =2.0311
# RMSE for Epoch 385 =1.39835
# RMSE for dev set =1.8925
# RMSE for Epoch 386 =1.45976
# RMSE for dev set =1.88529
# RMSE for Epoch 387 =1.38767
# RMSE for dev set =1.8822
# RMSE for Epoch 388 =1.43863
# RMSE for dev set =1.88222
# RMSE for Epoch 389 =1.83637
# RMSE for dev set =2.10944
# RMSE for Epoch 390 =1.34441
# RMSE for dev set =1.94388
# RMSE for Epoch 391 =1.35052
# RMSE for dev set =2.16931
# RMSE for Epoch 392 =2.24865
# RMSE for dev set =1.97167
# RMSE for Epoch 393 =1.52273
# RMSE for dev set =2.01839
# RMSE for Epoch 394 =1.53696
# RMSE for dev set =2.26549
# RMSE for Epoch 395 =1.70595
# RMSE for dev set =1.88942
# RMSE for Epoch 396 =1.56988
# RMSE for dev set =1.97662
# RMSE for Epoch 397 =1.8332
# RMSE for dev set =1.86531
# RMSE for Epoch 398 =1.76694
# RMSE for dev set =2.0086
# RMSE for Epoch 399 =1.38131
# RMSE for dev set =2.33139
# RMSE for Epoch 400 =1.58317
# RMSE for dev set =1.90206
# RMSE for Epoch 401 =1.55832
# RMSE for dev set =1.97268
# RMSE for Epoch 402 =2.02672
# RMSE for dev set =2.28589
# RMSE for Epoch 403 =1.42007
# RMSE for dev set =2.13597
# RMSE for Epoch 404 =1.34073
# RMSE for dev set =1.86708
# RMSE for Epoch 405 =1.95281
# RMSE for dev set =1.81295
# RMSE for Epoch 406 =1.26235
# RMSE for dev set =2.45325
# RMSE for Epoch 407 =1.40262
# RMSE for dev set =2.02971
# RMSE for Epoch 408 =1.56228
# RMSE for dev set =1.98513
# RMSE for Epoch 409 =1.43696
# RMSE for dev set =1.82813
# RMSE for Epoch 410 =1.4869
# RMSE for dev set =1.87025
# RMSE for Epoch 411 =1.42266
# RMSE for dev set =1.93212
# RMSE for Epoch 412 =1.5706
# RMSE for dev set =1.91086
# RMSE for Epoch 413 =1.36689
# RMSE for dev set =2.52074
# RMSE for Epoch 414 =1.33027
# RMSE for dev set =2.49056
# RMSE for Epoch 415 =2.56054
# RMSE for dev set =2.48293
# RMSE for Epoch 416 =1.43827
# RMSE for dev set =2.0595
# RMSE for Epoch 417 =1.36233
# RMSE for dev set =1.9812
# RMSE for Epoch 418 =1.78024
# RMSE for dev set =1.94357
# RMSE for Epoch 419 =1.37905
# RMSE for dev set =1.97104
# RMSE for Epoch 420 =1.27374
# RMSE for dev set =2.02298
# RMSE for Epoch 421 =1.49866
# RMSE for dev set =1.85585
# RMSE for Epoch 422 =1.52894
# RMSE for dev set =1.91446
# RMSE for Epoch 423 =1.4168
# RMSE for dev set =1.90154
# RMSE for Epoch 424 =1.49561
# RMSE for dev set =1.92211
# RMSE for Epoch 425 =1.3426
# RMSE for dev set =1.90712
# RMSE for Epoch 426 =1.27195
# RMSE for dev set =1.87523
# RMSE for Epoch 427 =1.63397
# RMSE for dev set =2.04023
# RMSE for Epoch 428 =1.71942
# RMSE for dev set =2.38872
# RMSE for Epoch 429 =1.46276
# RMSE for dev set =2.00693
# RMSE for Epoch 430 =1.28753
# RMSE for dev set =1.86433
# RMSE for Epoch 431 =1.41129
# RMSE for dev set =1.85195
# RMSE for Epoch 432 =1.7119
# RMSE for dev set =2.14512
# RMSE for Epoch 433 =1.43897
# RMSE for dev set =1.87648
# RMSE for Epoch 434 =1.94079
# RMSE for dev set =1.87765
# RMSE for Epoch 435 =1.44569
# RMSE for dev set =1.97472
# RMSE for Epoch 436 =1.23095
# RMSE for dev set =1.92037
# RMSE for Epoch 437 =2.04023
# RMSE for dev set =1.8413
# RMSE for Epoch 438 =1.39663
# RMSE for dev set =1.81601
# RMSE for Epoch 439 =2.05554
# RMSE for dev set =1.84571
# RMSE for Epoch 440 =1.56671
# RMSE for dev set =2.22134
# RMSE for Epoch 441 =1.30078
# RMSE for dev set =2.22347
# RMSE for Epoch 442 =2.12776
# RMSE for dev set =2.10296
# RMSE for Epoch 443 =1.29529
# RMSE for dev set =2.1281
# RMSE for Epoch 444 =1.38681
# RMSE for dev set =2.45909
# RMSE for Epoch 445 =1.93667
# RMSE for dev set =2.67615
# RMSE for Epoch 446 =1.61297
# RMSE for dev set =2.02034
# RMSE for Epoch 447 =1.73085
# RMSE for dev set =1.92508
# RMSE for Epoch 448 =1.33355
# RMSE for dev set =2.0031
# RMSE for Epoch 449 =1.67761
# RMSE for dev set =1.87699
# RMSE for Epoch 450 =1.31587
# RMSE for dev set =2.09697
# RMSE for Epoch 451 =1.21896
# RMSE for dev set =1.84427
# RMSE for Epoch 452 =1.56717
# RMSE for dev set =2.1413
# RMSE for Epoch 453 =1.39074
# RMSE for dev set =1.78856
# RMSE for Epoch 454 =1.36543
# RMSE for dev set =1.85335
# RMSE for Epoch 455 =1.34544
# RMSE for dev set =1.98539
# RMSE for Epoch 456 =1.21073
# RMSE for dev set =1.95047
# RMSE for Epoch 457 =1.50947
# RMSE for dev set =1.91699
# RMSE for Epoch 458 =1.30735
# RMSE for dev set =1.9373
# RMSE for Epoch 459 =1.38793
# RMSE for dev set =1.80352
# RMSE for Epoch 460 =1.24072
# RMSE for dev set =1.88157
# RMSE for Epoch 461 =1.2229
# RMSE for dev set =1.794
# RMSE for Epoch 462 =1.27556
# RMSE for dev set =1.76662
# RMSE for Epoch 463 =1.39016
# RMSE for dev set =1.8612
# RMSE for Epoch 464 =1.6859
# RMSE for dev set =2.01242
# RMSE for Epoch 465 =1.28216
# RMSE for dev set =1.77772
# RMSE for Epoch 466 =1.82643
# RMSE for dev set =1.96725
# RMSE for Epoch 467 =1.19474
# RMSE for dev set =1.77815
# RMSE for Epoch 468 =1.49267
# RMSE for dev set =1.82222
# RMSE for Epoch 469 =1.29813
# RMSE for dev set =1.9125
# RMSE for Epoch 470 =1.3914
# RMSE for dev set =1.84267
# RMSE for Epoch 471 =1.24611
# RMSE for dev set =1.83868
# RMSE for Epoch 472 =1.28161
# RMSE for dev set =1.74449
# RMSE for Epoch 473 =1.82939
# RMSE for dev set =1.89123
# RMSE for Epoch 474 =1.4356
# RMSE for dev set =1.79676
# RMSE for Epoch 475 =1.28515
# RMSE for dev set =1.9852
# RMSE for Epoch 476 =1.32986
# RMSE for dev set =2.17642
# RMSE for Epoch 477 =1.30668
# RMSE for dev set =1.85638
# RMSE for Epoch 478 =1.46753
# RMSE for dev set =1.85074
# RMSE for Epoch 479 =1.28347
# RMSE for dev set =1.81604
# RMSE for Epoch 480 =1.31403
# RMSE for dev set =1.80964
# RMSE for Epoch 481 =1.34828
# RMSE for dev set =1.84404
# RMSE for Epoch 482 =1.27828
# RMSE for dev set =1.83566
# RMSE for Epoch 483 =1.24906
# RMSE for dev set =1.78269
# RMSE for Epoch 484 =1.20835
# RMSE for dev set =1.78102
# RMSE for Epoch 485 =1.39619
# RMSE for dev set =1.79742
# RMSE for Epoch 486 =1.25873
# RMSE for dev set =1.85158
# RMSE for Epoch 487 =1.38589
# RMSE for dev set =1.83856
# RMSE for Epoch 488 =1.75188
# RMSE for dev set =2.12737
# RMSE for Epoch 489 =1.31995
# RMSE for dev set =1.87626
# RMSE for Epoch 490 =1.22144
# RMSE for dev set =1.82902
# RMSE for Epoch 491 =1.6199
# RMSE for dev set =1.8316
# RMSE for Epoch 492 =1.33556
# RMSE for dev set =1.81971
# RMSE for Epoch 493 =1.49177
# RMSE for dev set =1.87438
# RMSE for Epoch 494 =1.79365
# RMSE for dev set =2.51055
# RMSE for Epoch 495 =1.97034
# RMSE for dev set =2.06025
# RMSE for Epoch 496 =2.37493
# RMSE for dev set =1.99044
# RMSE for Epoch 497 =1.24277
# RMSE for dev set =1.86606
# RMSE for Epoch 498 =1.32276
# RMSE for dev set =1.80498
# RMSE for Epoch 499 =1.58192
# RMSE for dev set =1.90495
# RMSE for Epoch 500 =1.36379
# RMSE for dev set =1.90276
# RMSE for Epoch 501 =1.67345
# RMSE for dev set =1.91284
# RMSE for Epoch 502 =1.21805
# RMSE for dev set =1.91264
# RMSE for Epoch 503 =1.22354
# RMSE for dev set =2.04616
# RMSE for Epoch 504 =2.09261
# RMSE for dev set =2.14215
# RMSE for Epoch 505 =1.24734
# RMSE for dev set =1.81103
# RMSE for Epoch 506 =1.70796
# RMSE for dev set =1.79054
# RMSE for Epoch 507 =1.38647
# RMSE for dev set =2.02928
# RMSE for Epoch 508 =1.2056
# RMSE for dev set =1.80691
# RMSE for Epoch 509 =1.7338
# RMSE for dev set =1.78224
# RMSE for Epoch 510 =1.32742
# RMSE for dev set =2.54335
# RMSE for Epoch 511 =1.29414
# RMSE for dev set =2.17687
# RMSE for Epoch 512 =1.82867
# RMSE for dev set =2.15558
# RMSE for Epoch 513 =1.46798
# RMSE for dev set =2.10402
# RMSE for Epoch 514 =2.49812
# RMSE for dev set =2.06987
# RMSE for Epoch 515 =1.32919
# RMSE for dev set =1.76905
# RMSE for Epoch 516 =1.71032
# RMSE for dev set =1.99955
# RMSE for Epoch 517 =1.3735
# RMSE for dev set =1.90413
# RMSE for Epoch 518 =1.97195
# RMSE for dev set =1.83417
# RMSE for Epoch 519 =1.28982
# RMSE for dev set =1.81536
# RMSE for Epoch 520 =1.20156
# RMSE for dev set =1.74633
# RMSE for Epoch 521 =1.21982
# RMSE for dev set =1.75274
# RMSE for Epoch 522 =1.25777
# RMSE for dev set =1.78982
# RMSE for Epoch 523 =1.30795
# RMSE for dev set =1.84652
# RMSE for Epoch 524 =1.22398
# RMSE for dev set =1.76959
# RMSE for Epoch 525 =1.51321
# RMSE for dev set =1.85743
# RMSE for Epoch 526 =1.41975
# RMSE for dev set =1.91915
# RMSE for Epoch 527 =1.30937
# RMSE for dev set =1.90581
# RMSE for Epoch 528 =1.81358
# RMSE for dev set =1.95029
# RMSE for Epoch 529 =1.20341
# RMSE for dev set =1.7989
# RMSE for Epoch 530 =1.44279
# RMSE for dev set =1.97943
# RMSE for Epoch 531 =1.27209
# RMSE for dev set =1.83041
# RMSE for Epoch 532 =1.27234
# RMSE for dev set =1.7591
# RMSE for Epoch 533 =1.20249
# RMSE for dev set =1.81089
# RMSE for Epoch 534 =1.41013
# RMSE for dev set =1.82778
# RMSE for Epoch 535 =1.2714
# RMSE for dev set =1.90595
# RMSE for Epoch 536 =1.19069
# RMSE for dev set =1.78955
# RMSE for Epoch 537 =1.90631
# RMSE for dev set =1.91838
# RMSE for Epoch 538 =1.55413
# RMSE for dev set =1.93277
# RMSE for Epoch 539 =1.49598
# RMSE for dev set =1.85521
# RMSE for Epoch 540 =1.30615
# RMSE for dev set =2.25977
# RMSE for Epoch 541 =1.51097
# RMSE for dev set =2.13937
# RMSE for Epoch 542 =1.70897
# RMSE for dev set =1.97565
# RMSE for Epoch 543 =1.19615
# RMSE for dev set =1.82764
# RMSE for Epoch 544 =1.37535
# RMSE for dev set =1.84775
# RMSE for Epoch 545 =1.23074
# RMSE for dev set =1.77783
# RMSE for Epoch 546 =1.39684
# RMSE for dev set =1.83456
# RMSE for Epoch 547 =1.20512
# RMSE for dev set =1.96409
# RMSE for Epoch 548 =1.26367
# RMSE for dev set =1.79902
# RMSE for Epoch 549 =1.49025
# RMSE for dev set =1.81596
# RMSE for Epoch 550 =1.38873
# RMSE for dev set =1.83374
# RMSE for Epoch 551 =1.25264
# RMSE for dev set =1.8132
# RMSE for Epoch 552 =1.25933
# RMSE for dev set =1.78901
# RMSE for Epoch 553 =1.3442
# RMSE for dev set =1.79481
# RMSE for Epoch 554 =1.26975
# RMSE for dev set =1.78671
# RMSE for Epoch 555 =1.32044
# RMSE for dev set =1.83613
# RMSE for Epoch 556 =1.24201
# RMSE for dev set =1.77972
# RMSE for Epoch 557 =2.05789
# RMSE for dev set =1.96915
# RMSE for Epoch 558 =1.22989
# RMSE for dev set =1.87638
# RMSE for Epoch 559 =1.25757
# RMSE for dev set =1.76148
# RMSE for Epoch 560 =1.24141
# RMSE for dev set =1.79396
# RMSE for Epoch 561 =1.3294
# RMSE for dev set =1.77793
# RMSE for Epoch 562 =1.33712
# RMSE for dev set =1.75917
# RMSE for Epoch 563 =1.28102
# RMSE for dev set =1.81096
# RMSE for Epoch 564 =1.15074
# RMSE for dev set =1.78954
# RMSE for Epoch 565 =1.29633
# RMSE for dev set =1.80587
# RMSE for Epoch 566 =1.17197
# RMSE for dev set =1.82383
# RMSE for Epoch 567 =1.8205
# RMSE for dev set =1.7939
# RMSE for Epoch 568 =1.22491
# RMSE for dev set =1.79234
# RMSE for Epoch 569 =1.2182
# RMSE for dev set =1.82745
# RMSE for Epoch 570 =1.19536
# RMSE for dev set =1.77764
# RMSE for Epoch 571 =1.60186
# RMSE for dev set =1.8569
# RMSE for Epoch 572 =1.14085
# RMSE for dev set =1.76436
# RMSE for Epoch 573 =1.44731
# RMSE for dev set =1.78796
# RMSE for Epoch 574 =1.18799
# RMSE for dev set =1.74987
# RMSE for Epoch 575 =1.25239
# RMSE for dev set =1.754
# RMSE for Epoch 576 =1.28222
# RMSE for dev set =1.76687
# RMSE for Epoch 577 =1.13751
# RMSE for dev set =1.7626
# RMSE for Epoch 578 =1.19313
# RMSE for dev set =1.77322
# RMSE for Epoch 579 =1.28723
# RMSE for dev set =1.85451
# RMSE for Epoch 580 =1.20543
# RMSE for dev set =1.81239
# RMSE for Epoch 581 =1.23799
# RMSE for dev set =1.78868
# RMSE for Epoch 582 =1.28692
# RMSE for dev set =1.81324
# RMSE for Epoch 583 =1.14945
# RMSE for dev set =1.80097
# RMSE for Epoch 584 =1.41214
# RMSE for dev set =1.91026
# RMSE for Epoch 585 =1.23629
# RMSE for dev set =2.2621
# RMSE for Epoch 586 =1.16829
# RMSE for dev set =1.95612
# RMSE for Epoch 587 =1.76068
# RMSE for dev set =2.19346
# RMSE for Epoch 588 =1.21656
# RMSE for dev set =1.81616
# RMSE for Epoch 589 =1.26725
# RMSE for dev set =1.8058
# RMSE for Epoch 590 =1.68182
# RMSE for dev set =2.76427
# RMSE for Epoch 591 =1.85818
# RMSE for dev set =2.67007
# RMSE for Epoch 592 =2.79261
# RMSE for dev set =2.86279
# RMSE for Epoch 593 =1.69654
# RMSE for dev set =1.93695
# RMSE for Epoch 594 =1.72716
# RMSE for dev set =1.8063
# RMSE for Epoch 595 =1.23054
# RMSE for dev set =1.97578
# RMSE for Epoch 596 =1.30537
# RMSE for dev set =1.95785
# RMSE for Epoch 597 =1.94403
# RMSE for dev set =1.97339
# RMSE for Epoch 598 =1.2304
# RMSE for dev set =1.81317
# RMSE for Epoch 599 =1.47747
# RMSE for dev set =1.77963
# RMSE for Epoch 600 =1.15907
# RMSE for dev set =1.76694
# RMSE for Epoch 601 =1.3033
# RMSE for dev set =1.79405
# RMSE for Epoch 602 =1.17132
# RMSE for dev set =1.86068
# RMSE for Epoch 603 =1.19877
# RMSE for dev set =1.78782
# RMSE for Epoch 604 =1.50046
# RMSE for dev set =1.99765
# RMSE for Epoch 605 =1.18446
# RMSE for dev set =1.77389
# RMSE for Epoch 606 =1.37441
# RMSE for dev set =1.8188
# RMSE for Epoch 607 =1.34156
# RMSE for dev set =1.79692
# RMSE for Epoch 608 =1.54105
# RMSE for dev set =1.7776
# RMSE for Epoch 609 =1.34374
# RMSE for dev set =1.97684
# RMSE for Epoch 610 =1.19502
# RMSE for dev set =1.7819
# RMSE for Epoch 611 =1.56662
# RMSE for dev set =1.86821
# RMSE for Epoch 612 =1.37461
# RMSE for dev set =1.76114
# RMSE for Epoch 613 =1.1433
# RMSE for dev set =1.91203
# RMSE for Epoch 614 =1.27614
# RMSE for dev set =1.73324
# RMSE for Epoch 615 =1.19037
# RMSE for dev set =1.75219
# RMSE for Epoch 616 =1.32035
# RMSE for dev set =1.91825
# RMSE for Epoch 617 =1.13195
# RMSE for dev set =1.75975
# RMSE for Epoch 618 =1.28033
# RMSE for dev set =1.83961
# RMSE for Epoch 619 =1.39245
# RMSE for dev set =2.07497
# RMSE for Epoch 620 =1.26279
# RMSE for dev set =1.89028
# RMSE for Epoch 621 =1.87712
# RMSE for dev set =2.11921
# RMSE for Epoch 622 =1.20599
# RMSE for dev set =1.77195
# RMSE for Epoch 623 =1.17936
# RMSE for dev set =1.82693
# RMSE for Epoch 624 =1.56098
# RMSE for dev set =2.1367
# RMSE for Epoch 625 =1.37399
# RMSE for dev set =1.76338
# RMSE for Epoch 626 =1.22133
# RMSE for dev set =1.73864
# RMSE for Epoch 627 =1.24069
# RMSE for dev set =1.74746
# RMSE for Epoch 628 =1.20615
# RMSE for dev set =1.84181
# RMSE for Epoch 629 =1.21804
# RMSE for dev set =1.73589
# RMSE for Epoch 630 =1.27861
# RMSE for dev set =1.7334
# RMSE for Epoch 631 =1.15995
# RMSE for dev set =1.77394
# RMSE for Epoch 632 =1.09847
# RMSE for dev set =1.7839
# RMSE for Epoch 633 =1.50229
# RMSE for dev set =1.79734
# RMSE for Epoch 634 =1.32026
# RMSE for dev set =1.84339
# RMSE for Epoch 635 =1.70081
# RMSE for dev set =1.80806
# RMSE for Epoch 636 =1.11958
# RMSE for dev set =2.20152
# RMSE for Epoch 637 =1.15655
# RMSE for dev set =2.02035
# RMSE for Epoch 638 =1.44968
# RMSE for dev set =2.10476
# RMSE for Epoch 639 =1.18996
# RMSE for dev set =1.76324
# RMSE for Epoch 640 =2.01587
# RMSE for dev set =1.84533
# RMSE for Epoch 641 =1.2032
# RMSE for dev set =1.94884
# RMSE for Epoch 642 =1.45375
# RMSE for dev set =1.78269
# RMSE for Epoch 643 =1.13267
# RMSE for dev set =2.31871
# RMSE for Epoch 644 =1.17744
# RMSE for dev set =2.10088
# RMSE for Epoch 645 =1.47829
# RMSE for dev set =1.89754
# RMSE for Epoch 646 =1.15426
# RMSE for dev set =1.72703
# RMSE for Epoch 647 =1.28537
# RMSE for dev set =1.72831
# RMSE for Epoch 648 =1.17902
# RMSE for dev set =2.22819
# RMSE for Epoch 649 =1.15659
# RMSE for dev set =1.86156
# RMSE for Epoch 650 =1.54724
# RMSE for dev set =2.22552
# RMSE for Epoch 651 =1.12235
# RMSE for dev set =1.75533
# RMSE for Epoch 652 =1.32332
# RMSE for dev set =1.80648
# RMSE for Epoch 653 =1.18508
# RMSE for dev set =1.87986
# RMSE for Epoch 654 =1.15701
# RMSE for dev set =1.97031
# RMSE for Epoch 655 =1.77864
# RMSE for dev set =2.70214
# RMSE for Epoch 656 =1.50199
# RMSE for dev set =2.1058
# RMSE for Epoch 657 =1.92084
# RMSE for dev set =2.07925
# RMSE for Epoch 658 =1.41958
# RMSE for dev set =1.80946
# RMSE for Epoch 659 =2.12425
# RMSE for dev set =1.83569
# RMSE for Epoch 660 =1.17641
# RMSE for dev set =2.17122
# RMSE for Epoch 661 =1.18873
# RMSE for dev set =2.12312
# RMSE for Epoch 662 =1.22683
# RMSE for dev set =1.99745
# RMSE for Epoch 663 =1.13085
# RMSE for dev set =1.78594
# RMSE for Epoch 664 =1.53909
# RMSE for dev set =2.07696
# RMSE for Epoch 665 =1.19638
# RMSE for dev set =1.76594
# RMSE for Epoch 666 =1.41901
# RMSE for dev set =1.79022
# RMSE for Epoch 667 =1.24237
# RMSE for dev set =1.93858
# RMSE for Epoch 668 =1.23083
# RMSE for dev set =1.76584
# RMSE for Epoch 669 =1.13438
# RMSE for dev set =1.81566
# RMSE for Epoch 670 =1.70811
# RMSE for dev set =1.90445
# RMSE for Epoch 671 =1.24729
# RMSE for dev set =1.8285
# RMSE for Epoch 672 =1.1589
# RMSE for dev set =1.80406
# RMSE for Epoch 673 =1.16516
# RMSE for dev set =1.79533
# RMSE for Epoch 674 =1.28872
# RMSE for dev set =1.74062
# RMSE for Epoch 675 =1.15619
# RMSE for dev set =1.74911
# RMSE for Epoch 676 =1.06724
# RMSE for dev set =1.74751
# RMSE for Epoch 677 =1.2135
# RMSE for dev set =1.71833
# RMSE for Epoch 678 =1.12778
# RMSE for dev set =1.80621
# RMSE for Epoch 679 =1.29367
# RMSE for dev set =1.74954
# RMSE for Epoch 680 =1.08408
# RMSE for dev set =1.80863
# RMSE for Epoch 681 =1.17286
# RMSE for dev set =1.90804
# RMSE for Epoch 682 =1.46246
# RMSE for dev set =2.47785
# RMSE for Epoch 683 =1.31577
# RMSE for dev set =1.78179
# RMSE for Epoch 684 =1.57606
# RMSE for dev set =1.72482
# RMSE for Epoch 685 =1.25027
# RMSE for dev set =1.81546
# RMSE for Epoch 686 =1.17652
# RMSE for dev set =1.7108
# RMSE for Epoch 687 =1.0822
# RMSE for dev set =1.74857
# RMSE for Epoch 688 =1.1363
# RMSE for dev set =1.71232
# RMSE for Epoch 689 =1.08967
# RMSE for dev set =1.76323
# RMSE for Epoch 690 =1.18608
# RMSE for dev set =1.8502
# RMSE for Epoch 691 =1.55351
# RMSE for dev set =2.16998
# RMSE for Epoch 692 =1.28221
# RMSE for dev set =1.86298
# RMSE for Epoch 693 =1.8457
# RMSE for dev set =1.89307
# RMSE for Epoch 694 =1.26269
# RMSE for dev set =1.72833
# RMSE for Epoch 695 =1.32101
# RMSE for dev set =1.72041
# RMSE for Epoch 696 =1.08698
# RMSE for dev set =1.7116
# RMSE for Epoch 697 =1.24692
# RMSE for dev set =1.91785
# RMSE for Epoch 698 =1.09819
# RMSE for dev set =1.71881
# RMSE for Epoch 699 =1.17352
# RMSE for dev set =1.78206
# RMSE for Epoch 700 =1.30967
# RMSE for dev set =1.79058
# RMSE for Epoch 701 =1.12231
# RMSE for dev set =1.77075
# RMSE for Epoch 702 =1.2588
# RMSE for dev set =1.7425
# RMSE for Epoch 703 =1.35
# RMSE for dev set =2.01211
# RMSE for Epoch 704 =1.16636
# RMSE for dev set =1.74741
# RMSE for Epoch 705 =1.42077
# RMSE for dev set =1.79055
# RMSE for Epoch 706 =1.1955
# RMSE for dev set =1.71306
# RMSE for Epoch 707 =1.43661
# RMSE for dev set =1.71758
# RMSE for Epoch 708 =1.07417
# RMSE for dev set =1.79986
# RMSE for Epoch 709 =1.31471
# RMSE for dev set =1.7751
# RMSE for Epoch 710 =1.23957
# RMSE for dev set =1.90451
# RMSE for Epoch 711 =1.44186
# RMSE for dev set =2.07599
# RMSE for Epoch 712 =1.8299
# RMSE for dev set =1.83023
# RMSE for Epoch 713 =1.36978
# RMSE for dev set =1.78119
# RMSE for Epoch 714 =1.30294
# RMSE for dev set =1.70398
# RMSE for Epoch 715 =1.22961
# RMSE for dev set =1.89643
# RMSE for Epoch 716 =1.15725
# RMSE for dev set =1.76057
# RMSE for Epoch 717 =1.18346
# RMSE for dev set =1.7217
# RMSE for Epoch 718 =1.21804
# RMSE for dev set =1.75617
# RMSE for Epoch 719 =1.09645
# RMSE for dev set =1.70197
# RMSE for Epoch 720 =1.26555
# RMSE for dev set =1.79501
# RMSE for Epoch 721 =1.0605
# RMSE for dev set =1.71505
# RMSE for Epoch 722 =1.05228
# RMSE for dev set =1.719
# RMSE for Epoch 723 =1.09267
# RMSE for dev set =1.71861
# RMSE for Epoch 724 =1.19889
# RMSE for dev set =1.70396
# RMSE for Epoch 725 =1.06648
# RMSE for dev set =1.72543
# RMSE for Epoch 726 =1.16446
# RMSE for dev set =1.71747
# RMSE for Epoch 727 =1.12015
# RMSE for dev set =1.75557
# RMSE for Epoch 728 =1.41314
# RMSE for dev set =1.88274
# RMSE for Epoch 729 =1.16313
# RMSE for dev set =1.75167
# RMSE for Epoch 730 =1.21947
# RMSE for dev set =1.74559
# RMSE for Epoch 731 =1.10524
# RMSE for dev set =1.79317
# RMSE for Epoch 732 =1.33454
# RMSE for dev set =1.84166
# RMSE for Epoch 733 =1.24597
# RMSE for dev set =1.79772
# RMSE for Epoch 734 =1.48099
# RMSE for dev set =1.73193
# RMSE for Epoch 735 =1.10982
# RMSE for dev set =1.74003
# RMSE for Epoch 736 =1.19777
# RMSE for dev set =1.80377
# RMSE for Epoch 737 =1.04673
# RMSE for dev set =1.89773
# RMSE for Epoch 738 =1.34425
# RMSE for dev set =2.0524
# RMSE for Epoch 739 =1.18306
# RMSE for dev set =1.7811
# RMSE for Epoch 740 =1.56386
# RMSE for dev set =1.9711
# RMSE for Epoch 741 =1.17933
# RMSE for dev set =1.6852
# RMSE for Epoch 742 =1.39149
# RMSE for dev set =1.81296
# RMSE for Epoch 743 =1.23249
# RMSE for dev set =2.23183
# RMSE for Epoch 744 =1.34246
# RMSE for dev set =2.19823
# RMSE for Epoch 745 =1.77009
# RMSE for dev set =2.07478
# RMSE for Epoch 746 =1.07802
# RMSE for dev set =1.70791
# RMSE for Epoch 747 =1.67478
# RMSE for dev set =1.90997
# RMSE for Epoch 748 =1.36371
# RMSE for dev set =1.7363
# RMSE for Epoch 749 =1.55526
# RMSE for dev set =1.68016
# RMSE for Epoch 750 =1.18702
# RMSE for dev set =1.90085
# RMSE for Epoch 751 =1.18246
# RMSE for dev set =2.19845
# RMSE for Epoch 752 =1.78377
# RMSE for dev set =2.52376
# RMSE for Epoch 753 =1.32264
# RMSE for dev set =1.85903
# RMSE for Epoch 754 =1.42904
# RMSE for dev set =1.72026
# RMSE for Epoch 755 =1.07359
# RMSE for dev set =1.80586
# RMSE for Epoch 756 =1.02108
# RMSE for dev set =1.69134
# RMSE for Epoch 757 =1.10782
# RMSE for dev set =1.77244
# RMSE for Epoch 758 =1.03609
# RMSE for dev set =1.82456
# RMSE for Epoch 759 =1.60137
# RMSE for dev set =2.01971
# RMSE for Epoch 760 =1.14593
# RMSE for dev set =1.72649
# RMSE for Epoch 761 =1.24796
# RMSE for dev set =1.74379
# RMSE for Epoch 762 =1.0893
# RMSE for dev set =1.75807
# RMSE for Epoch 763 =1.673
# RMSE for dev set =1.89335
# RMSE for Epoch 764 =1.48975
# RMSE for dev set =1.68649
# RMSE for Epoch 765 =1.33074
# RMSE for dev set =1.71929
# RMSE for Epoch 766 =1.12009
# RMSE for dev set =1.99477
# RMSE for Epoch 767 =1.07503
# RMSE for dev set =1.93862
# RMSE for Epoch 768 =1.54934
# RMSE for dev set =2.2874
# RMSE for Epoch 769 =1.50206
# RMSE for dev set =2.20138
# RMSE for Epoch 770 =2.252
# RMSE for dev set =2.7823
# RMSE for Epoch 771 =1.76649
# RMSE for dev set =2.26302
# RMSE for Epoch 772 =1.84755
# RMSE for dev set =2.18124
# RMSE for Epoch 773 =1.11664
# RMSE for dev set =1.69604
# RMSE for Epoch 774 =1.27643
# RMSE for dev set =1.71373
# RMSE for Epoch 775 =1.10474
# RMSE for dev set =1.72849
# RMSE for Epoch 776 =1.10975
# RMSE for dev set =1.70058
# RMSE for Epoch 777 =1.06378
# RMSE for dev set =1.70377
# RMSE for Epoch 778 =1.33393
# RMSE for dev set =1.69237
# RMSE for Epoch 779 =1.15462
# RMSE for dev set =1.80152
# RMSE for Epoch 780 =1.03914
# RMSE for dev set =1.80434
# RMSE for Epoch 781 =1.47275
# RMSE for dev set =2.11644
# RMSE for Epoch 782 =1.39232
# RMSE for dev set =1.97294
# RMSE for Epoch 783 =1.35161
# RMSE for dev set =1.91583
# RMSE for Epoch 784 =1.07602
# RMSE for dev set =1.70467
# RMSE for Epoch 785 =1.31328
# RMSE for dev set =1.79453
# RMSE for Epoch 786 =1.18234
# RMSE for dev set =1.82097
# RMSE for Epoch 787 =1.33557
# RMSE for dev set =1.76849
# RMSE for Epoch 788 =1.00362
# RMSE for dev set =1.69254
# RMSE for Epoch 789 =1.32471
# RMSE for dev set =1.83733
# RMSE for Epoch 790 =1.0736
# RMSE for dev set =1.70358
# RMSE for Epoch 791 =1.35694
# RMSE for dev set =1.68805
# RMSE for Epoch 792 =0.987982
# RMSE for dev set =1.71767
# RMSE for Epoch 793 =1.14291
# RMSE for dev set =1.69291
# RMSE for Epoch 794 =1.08391
# RMSE for dev set =1.68553
# RMSE for Epoch 795 =1.0504
# RMSE for dev set =1.68729
# RMSE for Epoch 796 =1.04356
# RMSE for dev set =1.77245
# RMSE for Epoch 797 =1.08612
# RMSE for dev set =1.73285
# RMSE for Epoch 798 =1.15904
# RMSE for dev set =1.91218
# RMSE for Epoch 799 =1.06999
# RMSE for dev set =1.68814
# RMSE for Epoch 800 =1.1334
# RMSE for dev set =1.72539
# RMSE for Epoch 801 =1.06543
# RMSE for dev set =1.73122
# RMSE for Epoch 802 =1.0583
# RMSE for dev set =1.73146
# RMSE for Epoch 803 =1.41047
# RMSE for dev set =2.14426
# RMSE for Epoch 804 =1.12845
# RMSE for dev set =2.07092
# RMSE for Epoch 805 =1.23448
# RMSE for dev set =1.80774
# RMSE for Epoch 806 =1.11851
# RMSE for dev set =1.80612
# RMSE for Epoch 807 =1.25753
# RMSE for dev set =1.93114
# RMSE for Epoch 808 =1.06163
# RMSE for dev set =1.80673
# RMSE for Epoch 809 =1.65353
# RMSE for dev set =1.99674
# RMSE for Epoch 810 =1.5333
# RMSE for dev set =1.73265
# RMSE for Epoch 811 =1.33609
# RMSE for dev set =1.69103
# RMSE for Epoch 812 =1.07547
# RMSE for dev set =1.96814
# RMSE for Epoch 813 =1.09475
# RMSE for dev set =1.79917
# RMSE for Epoch 814 =1.14557
# RMSE for dev set =1.75296
# RMSE for Epoch 815 =1.33722
# RMSE for dev set =1.8118
# RMSE for Epoch 816 =1.13487
# RMSE for dev set =1.67152
# RMSE for Epoch 817 =1.11653
# RMSE for dev set =1.86313
# RMSE for Epoch 818 =1.02129
# RMSE for dev set =1.72625
# RMSE for Epoch 819 =1.52159
# RMSE for dev set =1.94677
# RMSE for Epoch 820 =1.39413
# RMSE for dev set =1.69317
# RMSE for Epoch 821 =1.98766
# RMSE for dev set =1.83714
# RMSE for Epoch 822 =1.40747
# RMSE for dev set =1.71843
# RMSE for Epoch 823 =1.36384
# RMSE for dev set =1.70107
# RMSE for Epoch 824 =1.08578
# RMSE for dev set =1.84586
# RMSE for Epoch 825 =1.23741
# RMSE for dev set =1.70039
# RMSE for Epoch 826 =1.2816
# RMSE for dev set =1.88532
# RMSE for Epoch 827 =1.16968
# RMSE for dev set =1.9876
# RMSE for Epoch 828 =1.57323
# RMSE for dev set =2.12369
# RMSE for Epoch 829 =1.1882
# RMSE for dev set =1.77914
# RMSE for Epoch 830 =1.78158
# RMSE for dev set =1.95479
# RMSE for Epoch 831 =1.42421
# RMSE for dev set =1.71865
# RMSE for Epoch 832 =1.45197
# RMSE for dev set =1.72207
# RMSE for Epoch 833 =1.10901
# RMSE for dev set =1.66952
# RMSE for Epoch 834 =1.18291
# RMSE for dev set =1.67563
# RMSE for Epoch 835 =1.00389
# RMSE for dev set =1.83284
# RMSE for Epoch 836 =1.08505
# RMSE for dev set =1.77365
# RMSE for Epoch 837 =1.4449
# RMSE for dev set =1.82616
# RMSE for Epoch 838 =1.04013
# RMSE for dev set =1.72161
# RMSE for Epoch 839 =1.35152
# RMSE for dev set =1.76744
# RMSE for Epoch 840 =1.23231
# RMSE for dev set =1.6872
# RMSE for Epoch 841 =1.29216
# RMSE for dev set =1.69609
# RMSE for Epoch 842 =1.14374
# RMSE for dev set =1.8314
# RMSE for Epoch 843 =1.18561
# RMSE for dev set =1.69059
# RMSE for Epoch 844 =1.48966
# RMSE for dev set =1.89004
# RMSE for Epoch 845 =1.07052
# RMSE for dev set =1.71463
# RMSE for Epoch 846 =1.34586
# RMSE for dev set =1.72307
# RMSE for Epoch 847 =1.17245
# RMSE for dev set =1.81754
# RMSE for Epoch 848 =1.11515
# RMSE for dev set =1.72176
# RMSE for Epoch 849 =1.37453
# RMSE for dev set =1.95648
# RMSE for Epoch 850 =1.08926
# RMSE for dev set =1.6562
# RMSE for Epoch 851 =1.12879
# RMSE for dev set =1.67612
# RMSE for Epoch 852 =1.05551
# RMSE for dev set =1.69709
# RMSE for Epoch 853 =1.07899
# RMSE for dev set =1.72064
# RMSE for Epoch 854 =1.12584
# RMSE for dev set =1.73909
# RMSE for Epoch 855 =1.1003
# RMSE for dev set =1.73206
# RMSE for Epoch 856 =1.1187
# RMSE for dev set =1.78887
# RMSE for Epoch 857 =1.05737
# RMSE for dev set =1.76847
# RMSE for Epoch 858 =1.72444
# RMSE for dev set =1.96004
# RMSE for Epoch 859 =1.13176
# RMSE for dev set =1.73421
# RMSE for Epoch 860 =1.23128
# RMSE for dev set =1.71967
# RMSE for Epoch 861 =1.05133
# RMSE for dev set =1.69754
# RMSE for Epoch 862 =1.16984
# RMSE for dev set =1.66298
# RMSE for Epoch 863 =1.0364
# RMSE for dev set =1.63859
# RMSE for Epoch 864 =0.969167
# RMSE for dev set =1.6669
# RMSE for Epoch 865 =1.1981
# RMSE for dev set =1.82674
# RMSE for Epoch 866 =1.07719
# RMSE for dev set =1.66499
# RMSE for Epoch 867 =0.998642
# RMSE for dev set =1.70297
# RMSE for Epoch 868 =1.44631
# RMSE for dev set =1.79517
# RMSE for Epoch 869 =1.13497
# RMSE for dev set =1.74569
# RMSE for Epoch 870 =1.361
# RMSE for dev set =1.8932
# RMSE for Epoch 871 =1.13448
# RMSE for dev set =1.68949
# RMSE for Epoch 872 =1.33975
# RMSE for dev set =1.77616
# RMSE for Epoch 873 =1.1305
# RMSE for dev set =1.67052
# RMSE for Epoch 874 =1.0745
# RMSE for dev set =1.77303
# RMSE for Epoch 875 =1.14453
# RMSE for dev set =2.0595
# RMSE for Epoch 876 =1.22855
# RMSE for dev set =1.8832
# RMSE for Epoch 877 =1.61729
# RMSE for dev set =2.10646
# RMSE for Epoch 878 =1.24228
# RMSE for dev set =1.71538
# RMSE for Epoch 879 =1.01151
# RMSE for dev set =1.70229
# RMSE for Epoch 880 =1.0299
# RMSE for dev set =1.665
# RMSE for Epoch 881 =0.960444
# RMSE for dev set =1.68549
# RMSE for Epoch 882 =1.11116
# RMSE for dev set =1.64724
# RMSE for Epoch 883 =0.959401
# RMSE for dev set =1.69006
# RMSE for Epoch 884 =1.07181
# RMSE for dev set =1.78418
# RMSE for Epoch 885 =1.11574
# RMSE for dev set =1.6181
# RMSE for Epoch 886 =0.99517
# RMSE for dev set =1.64444
# RMSE for Epoch 887 =1.00459
# RMSE for dev set =1.61715
# RMSE for Epoch 888 =1.20261
# RMSE for dev set =1.70512
# RMSE for Epoch 889 =0.976516
# RMSE for dev set =1.65689
# RMSE for Epoch 890 =1.46183
# RMSE for dev set =1.74319
# RMSE for Epoch 891 =0.979788
# RMSE for dev set =1.63145
# RMSE for Epoch 892 =1.22466
# RMSE for dev set =1.64507
# RMSE for Epoch 893 =1.0198
# RMSE for dev set =1.72811
# RMSE for Epoch 894 =1.06843
# RMSE for dev set =1.72688
# RMSE for Epoch 895 =1.0761
# RMSE for dev set =1.76361
# RMSE for Epoch 896 =1.13162
# RMSE for dev set =1.6989
# RMSE for Epoch 897 =1.03405
# RMSE for dev set =1.73879
# RMSE for Epoch 898 =1.15167
# RMSE for dev set =1.64928
# RMSE for Epoch 899 =1.10484
# RMSE for dev set =1.73322
# RMSE for Epoch 900 =1.17078
# RMSE for dev set =1.69029
# RMSE for Epoch 901 =1.22678
# RMSE for dev set =1.73577
# RMSE for Epoch 902 =1.12279
# RMSE for dev set =1.67184
# RMSE for Epoch 903 =1.2441
# RMSE for dev set =1.67665
# RMSE for Epoch 904 =1.01851
# RMSE for dev set =1.69872
# RMSE for Epoch 905 =1.12517
# RMSE for dev set =1.83241
# RMSE for Epoch 906 =1.14669
# RMSE for dev set =1.88441
# RMSE for Epoch 907 =1.39245
# RMSE for dev set =1.90971
# RMSE for Epoch 908 =1.17252
# RMSE for dev set =1.68007
# RMSE for Epoch 909 =1.05281
# RMSE for dev set =1.76852
# RMSE for Epoch 910 =1.1283
# RMSE for dev set =1.74402
# RMSE for Epoch 911 =1.07346
# RMSE for dev set =1.67965
# RMSE for Epoch 912 =1.06068
# RMSE for dev set =1.80791
# RMSE for Epoch 913 =0.989867
# RMSE for dev set =1.62674
# RMSE for Epoch 914 =1.5983
# RMSE for dev set =1.7751
# RMSE for Epoch 915 =1.1209
# RMSE for dev set =1.67812
# RMSE for Epoch 916 =1.23252
# RMSE for dev set =1.68582
# RMSE for Epoch 917 =1.44131
# RMSE for dev set =1.68736
# RMSE for Epoch 918 =1.04911
# RMSE for dev set =1.65266
# RMSE for Epoch 919 =1.04299
# RMSE for dev set =1.75044
# RMSE for Epoch 920 =1.67553
# RMSE for dev set =2.27174
# RMSE for Epoch 921 =1.65276
# RMSE for dev set =2.22566
# RMSE for Epoch 922 =1.6498
# RMSE for dev set =2.0077
# RMSE for Epoch 923 =1.22063
# RMSE for dev set =1.71375
# RMSE for Epoch 924 =1.74403
# RMSE for dev set =1.68292
# RMSE for Epoch 925 =1.08414
# RMSE for dev set =1.7085
# RMSE for Epoch 926 =1.09104
# RMSE for dev set =1.95374
# RMSE for Epoch 927 =1.21768
# RMSE for dev set =2.47686
# RMSE for Epoch 928 =0.971673
# RMSE for dev set =1.96283
# RMSE for Epoch 929 =1.03196
# RMSE for dev set =2.26815
# RMSE for Epoch 930 =1.223
# RMSE for dev set =2.28103
# RMSE for Epoch 931 =1.19683
# RMSE for dev set =2.16667
# RMSE for Epoch 932 =1.25982
# RMSE for dev set =1.89102
# RMSE for Epoch 933 =1.75448
# RMSE for dev set =1.97802
# RMSE for Epoch 934 =1.1869
# RMSE for dev set =1.7326
# RMSE for Epoch 935 =1.27518
# RMSE for dev set =1.7556
# RMSE for Epoch 936 =1.03321
# RMSE for dev set =1.70033
# RMSE for Epoch 937 =1.14259
# RMSE for dev set =1.89524
# RMSE for Epoch 938 =1.04295
# RMSE for dev set =1.64048
# RMSE for Epoch 939 =1.27688
# RMSE for dev set =1.7223
# RMSE for Epoch 940 =1.13062
# RMSE for dev set =1.64387
# RMSE for Epoch 941 =1.55504
# RMSE for dev set =1.65991
# RMSE for Epoch 942 =1.58897
# RMSE for dev set =1.63403
# RMSE for Epoch 943 =2.11194
# RMSE for dev set =1.68503
# RMSE for Epoch 944 =1.33079
# RMSE for dev set =1.66229
# RMSE for Epoch 945 =1.64311
# RMSE for dev set =1.66965
# RMSE for Epoch 946 =1.01475
# RMSE for dev set =1.85564
# RMSE for Epoch 947 =0.99435
# RMSE for dev set =1.94452
# RMSE for Epoch 948 =1.32688
# RMSE for dev set =1.90595
# RMSE for Epoch 949 =1.03702
# RMSE for dev set =1.68874
# RMSE for Epoch 950 =1.4162
# RMSE for dev set =1.93398
# RMSE for Epoch 951 =1.1663
# RMSE for dev set =1.70197
# RMSE for Epoch 952 =1.26497
# RMSE for dev set =1.80449
# RMSE for Epoch 953 =1.23088
# RMSE for dev set =1.61969
# RMSE for Epoch 954 =1.45182
# RMSE for dev set =1.76478
# RMSE for Epoch 955 =1.12084
# RMSE for dev set =1.68749
# RMSE for Epoch 956 =1.15104
# RMSE for dev set =1.80245
# RMSE for Epoch 957 =1.04821
# RMSE for dev set =1.74041
# RMSE for Epoch 958 =1.00477
# RMSE for dev set =1.68532
# RMSE for Epoch 959 =1.07656
# RMSE for dev set =1.81986
# RMSE for Epoch 960 =1.16008
# RMSE for dev set =1.65017
# RMSE for Epoch 961 =0.992284
# RMSE for dev set =1.71834
# RMSE for Epoch 962 =1.15472
# RMSE for dev set =1.66174
# RMSE for Epoch 963 =0.997306
# RMSE for dev set =1.64279
# RMSE for Epoch 964 =0.970068
# RMSE for dev set =1.81317
# RMSE for Epoch 965 =1.08684
# RMSE for dev set =1.69953
# RMSE for Epoch 966 =0.983249
# RMSE for dev set =1.99017
# RMSE for Epoch 967 =1.04148
# RMSE for dev set =1.80499
# RMSE for Epoch 968 =1.35317
# RMSE for dev set =2.18808
# RMSE for Epoch 969 =1.13159
# RMSE for dev set =1.94945
# RMSE for Epoch 970 =1.24977
# RMSE for dev set =2.19177
# RMSE for Epoch 971 =1.34538
# RMSE for dev set =1.92661
# RMSE for Epoch 972 =1.37783
# RMSE for dev set =2.10024
# RMSE for Epoch 973 =0.980789
# RMSE for dev set =1.67543
# RMSE for Epoch 974 =1.18423
# RMSE for dev set =1.86741
# RMSE for Epoch 975 =1.13339
# RMSE for dev set =1.89124
# RMSE for Epoch 976 =1.30662
# RMSE for dev set =1.86794
# RMSE for Epoch 977 =1.03209
# RMSE for dev set =1.66069
# RMSE for Epoch 978 =1.44727
# RMSE for dev set =1.65552
# RMSE for Epoch 979 =0.989554
# RMSE for dev set =1.68705
# RMSE for Epoch 980 =0.994347
# RMSE for dev set =1.75579
# RMSE for Epoch 981 =1.07467
# RMSE for dev set =2.01964
# RMSE for Epoch 982 =1.12376
# RMSE for dev set =2.02123
# RMSE for Epoch 983 =1.58039
# RMSE for dev set =2.36542
# RMSE for Epoch 984 =1.19433
# RMSE for dev set =1.91333
# RMSE for Epoch 985 =1.23447
# RMSE for dev set =1.74613
# RMSE for Epoch 986 =1.03304
# RMSE for dev set =1.65072
# RMSE for Epoch 987 =1.298
# RMSE for dev set =1.86949
# RMSE for Epoch 988 =1.05207
# RMSE for dev set =1.69465
# RMSE for Epoch 989 =1.14633
# RMSE for dev set =1.759
# RMSE for Epoch 990 =1.13872
# RMSE for dev set =1.6743
# RMSE for Epoch 991 =1.2445
# RMSE for dev set =1.6877
# RMSE for Epoch 992 =1.36963
# RMSE for dev set =1.72641
# RMSE for Epoch 993 =1.24035
# RMSE for dev set =1.6961
# RMSE for Epoch 994 =1.32386
# RMSE for dev set =1.69913
# RMSE for Epoch 995 =1.4465
# RMSE for dev set =1.83857
# RMSE for Epoch 996 =1.00861
# RMSE for dev set =1.64073
# RMSE for Epoch 997 =1.1905
# RMSE for dev set =1.79066
# RMSE for Epoch 998 =1.08961
# RMSE for dev set =1.6727
# RMSE for Epoch 999 =1.10565
# RMSE for dev set =1.78793

# %%
plot_images(5,data =train,result=result,training=False)

# %%
plot_images(5,data =dev,result=result,training=False)

# %%
plt.figure(figsize=(6,6))

plt.scatter(epoch,train_error)

plt.scatter(epoch,dev_error,color="red")



#train_error

# %%
#Add rotates images to the raw dataset
def rotate_images(data,kval):
    data["Image"] = data["Image"].apply(lambda x: np.rot90(x.reshape((96,96))).flatten())
    return data

#Add rotates images to the raw dataset
def flip_images(data):
    data["Image"] = data["Image"].apply(lambda x: np.fliplr(x.reshape((96,96))).flatten())
    return data


raw_updated = pd.concat([raw,rotate_images(raw,1),rotate_images(raw,2),rotate_images(raw,3),flip_images(raw)],axis=0)

raw_updated.sample(frac=1).reset_index(inplace=True)

# %%
dataSize = raw_updated.shape[0]-raw_updated.shape[0]%100
train = raw.loc[0:0.9*dataSize,:]
dev = raw.loc[0.9*dataSize:dataSize,:]
dev.reset_index(inplace=True,drop=True)

# %%
train_data = train["Image"].as_matrix()
train_labels = np.asarray(train[train.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)
dev_data = dev["Image"].as_matrix()
dev_labels = np.asarray(dev[dev.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)
