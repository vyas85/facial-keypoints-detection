# %%
# In this baseline python notebook, we loaded the dataset from Kaggle and attempted training with
# a simple NN with no hidden layers, 2 and 3 and 4 -convolutional-layers with fully connected layer.
# Also did some work to improve the facial keypoint identification such as blurring the image and 
# movement, and reran through NN to see if accuracy improved

# Reference-https://www.tensorflow.org/get_started/mnist/pros

# Loading required libraries
import numpy as np
import pandas as pd
import tensorflow as tf
tf.logging.set_verbosity(tf.logging.INFO)
import matplotlib.pyplot as plt
import scipy.signal



# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

np.random.seed(0)

# %%
# Loading the test and raw training datasets
# Raw is 7049X31.  7049 training examples, 30 columns of facial feature x &y locations, 1 column for list of image pixel values
# Test is 1783X2. 1783 test examples, 1 column for image id, 1 column for list of image pixel values
raw = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')


# Converting image data into numpy arrays and scaling the images
raw["Image"] = raw["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)
test["Image"] = test["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)

# %%
# Dropping training & test cases with na values since they will prevent the model from training correctly.
# Possibly revisit this to come up with a better approach
raw.dropna(inplace=True)
test.dropna(inplace=True)


# After removing the cases with 'na', re-shuffle (the training set) and re-do indexing
raw = raw.sample(frac=1)
raw.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

# %%
# Our training data set has 2140 examples at this point.  
# Allocate 1800 for training and 340 for development.
train_size = 1800
train = raw.iloc[0:train_size,:]
dev = raw.iloc[train_size:raw.shape[0],:]

# Re-index
train.reset_index(inplace=True,drop=True)
dev.reset_index(inplace=True,drop=True)

# %%
# Visualize 5 example images:
def plot_images(num_images,data, result=None,training=True):
    plt.figure(figsize=(12,4))
    for i in range(num_images):
        
        # Every example has 30 facial features and 1 column with a 9216-length list of pixel values of image
        # take the 9216 list of pixels and reshape into 96X96 image for viewing
        img =  np.reshape(data.ix[i:i,"Image"].values[0],(96,96))
        plt.subplot(1,num_images,i+1)
        plt.axis('off')
        
        # Show the facial image
        plt.imshow(img,cmap='Greys_r')

        # Get x & y values for the facial keypoints and overlay on the face
        x_values = np.asarray(data[data.columns.get_level_values(0)[0:30:2]])
        y_values = np.asarray(data[data.columns.get_level_values(0)[1:30:2]])
        plt.scatter(x_values[i],y_values[i])
        
        # If we are not using training data, then show our predicted facial keypoints with red x's
        if training==False:
            rx_values = np.asarray(result[result.columns.get_level_values(0)[0:30:2]])
            ry_values = np.asarray(result[result.columns.get_level_values(0)[1:30:2]])
            plt.scatter(rx_values[i],ry_values[i],marker="x",color='r')
            

plot_images(5,train)

# %%
# Convert the pixel arrays and facial feature locations in train/dev/test into numpy-array representation
train_data = train["Image"].as_matrix()
train_labels = np.asarray(train[train.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

dev_data = dev["Image"].as_matrix()
dev_labels = np.asarray(dev[dev.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

test_data = test["Image"].as_matrix()

# %%
# Create iterator to deliver data & labels in sets of batchSize
def imgs_iterator(data,labels,batchSize):
    startIndex= 0
    totalSize = len(data)
    indices = np.arange(totalSize)
    np.random.shuffle(indices)
    
    for i in range(0,totalSize,batchSize):
            batchIndices = indices[i:i+batchSize]
            yield np.stack(data[batchIndices]),labels[batchIndices],len(batchIndices)

# Same as imgs_iterator but for test data (don't return labels)
def imgs_iterator_predict(data,batchSize):
    startIndex= 0
    totalSize = len(data)
    indices = np.arange(totalSize)
    np.random.shuffle(indices)
    
    for i in range(0,totalSize,batchSize):
        batchIndices = indices[i:i+batchSize]
        
        yield np.stack(data[batchIndices]),len(batchIndices)

# Make predictions according to formula "y = Wx + b" for data set 
# Similar in form to training loop
def make_predictions(data,batch_size):
    predictions_mb=[]
    # Iterate by batch size
    iter_test = imgs_iterator_predict(data,batch_size)
    try:
        next_batch =iter_test.__next__()
        while next_batch!=None:
            
            # Load next batch
            mini_batch,batch_size = next_batch
            
            # Reshape
            mini_batch = np.reshape(mini_batch,(batch_size,9216))
            
            # Make prediction with input data and dropout 
            feed_dict = {x: np.stack(mini_batch), keep_prob: 1.0}
            predictions = y.eval(feed_dict)
            predictions_mb.append(predictions)
            
            next_batch =iter_test.__next__()
    except StopIteration:
        next_batch=None
    results = pd.DataFrame(np.vstack(predictions_mb))
    
    return results

# Generate reports for submission
def generate_results(result):
    submission = pd.read_csv('SampleSubmission.csv')
    IdLookup = pd.read_csv('IdLookupTable.csv')
    IdLookupDict = IdLookup.set_index('RowId').T.to_dict('list')

    
    
    result.columns = dev.columns[0:30]
    output = pd.concat([test["ImageId"],result_test],axis=1)
    
    RowId = np.asarray(submission["RowId"],dtype=int)
    for row in RowId:
        r = IdLookupDict[row][0]-1
        c =IdLookupDict[row][1]
        submission.loc[row-1,"Location"]= min(96,(output.loc[r,c]))
    
    
    submission.to_csv("submission.csv",index=False)

# %%
# Single layer neural network with NO hidden units

# Try running through the entire training data 200 times in batches of 20
batch_size=20
epochs = 200

# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Weights/bias for our simple NN
W = tf.Variable(tf.zeros([9216,30]))
b = tf.Variable(tf.zeros([30]))


# Prediction function "y=Wx+b"
y = tf.matmul(x,W) + b

# Define loss function as RMSE, and minimize by GradientDescent
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.GradientDescentOptimizer(0.01).minimize(error)

# Initialize all tf.Variable instances
sess = tf.InteractiveSession()
sess.run(tf.global_variables_initializer())

for i in range(epochs):
    
    # Move through training data in increments of 20
    iter_ = imgs_iterator(train_data,train_labels,batch_size)
    try:
        next_batch =iter_.__next__()
        while next_batch!=None:
            
            # Load next batch
            train_data_instance,train_label_instance,batch_size = next_batch
            train_instance = np.reshape(train_data_instance,(batch_size,9216))
            train_label_instance = np.reshape(train_label_instance,(batch_size,30))

            # Accuracy (for display)
            train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance})
            
            # Run training with next batch of 20 training examples
            train_step.run(feed_dict={x: train_instance, y_: train_label_instance})
            next_batch =iter_.__next__()
    except StopIteration:
        next_batch=None
    if i%10==0:
        
        # Display our RMSE for every 10th epoch
        print ("RMSE for Epoch "+str(i)+" ="+str(train_accuracy))
# Out:
# RMSE for Epoch 0 =10.0963
# RMSE for Epoch 10 =11.7944
# RMSE for Epoch 20 =12.2585
# RMSE for Epoch 30 =12.4969
# RMSE for Epoch 40 =9.99251
# RMSE for Epoch 50 =8.62311
# RMSE for Epoch 60 =9.03182
# RMSE for Epoch 70 =11.5681
# RMSE for Epoch 80 =10.3874
# RMSE for Epoch 90 =11.2631
# RMSE for Epoch 100 =8.43619
# RMSE for Epoch 110 =10.1187
# RMSE for Epoch 120 =10.3128
# RMSE for Epoch 130 =10.1758
# RMSE for Epoch 140 =10.6923
# RMSE for Epoch 150 =9.65936
# RMSE for Epoch 160 =11.6837
# RMSE for Epoch 170 =6.34234
# RMSE for Epoch 180 =7.54768
# RMSE for Epoch 190 =8.99707

# %%
# Generate predictions
feed_dict = {x: np.stack(train_data)}
predictions = y.eval(feed_dict)
# Plot predictions
result =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))
plot_images(5,data =train,result=result,training=False)

# %%
# Try 2-convolutional-layers, 1 fully connected

mini_batch_size=300
epochs = 40

# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')



# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])


# Weights will be 4D tensor of size 5x5x1x32 from truncated normal, 32-length array bias of constant 0.1
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])


# x_image is in shape [batch, in_height, in_width, in_channels] ~ [-1, 96, 96, 1]
# W_conv1 is in shape [filter_height, filter_width, in_channels, out_channels] ~ [5,5,1,32]
# conv2d flattens the filter to a 2-D matrix with shape [filter_height * filter_width * in_channels, output_channels]
#      ~ [5*5*1, 32] ~ [25, 32]
# Apply rectifier relu function
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)

# Perform reduction.  h_conv1 is [?,96,96,32] with strides [1,2,2,1]
# Returns a 48*48 image with 32 filters
h_pool1 = max_pool_2x2(h_conv1)

# 2nd convolutional layer - will return 24*24 image with 64 filters
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)


# Flatten resulting image to apply relu activation
h_pool2_flat = tf.reshape(h_pool2, [-1, 24*24*64])

# Fully connected layer
W_fc1 = weight_variable([24 * 24 * 64, 1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Apply dropout to prevent overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Determine prediction function "y=Wx+b"
W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])
y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# Define loss function, try minimize with AdamOptimizer (more efficient than gradient descent)
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-4).minimize(error)


with tf.Session() as sess:
    # Initialize global vars
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        
        # Iterate over training data in increments of (mini_batch_size-1)
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape 
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Determine accuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of 20 training examples
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+" ="+str(train_accuracy))
        
    
    # Measure accuracy with trained NN on dev data
    iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
    
    # Get batch of 20 from dev data
    next_batch =iter_dev.__next__()
    dev_data_instance,dev_label_instance,batch_size = next_batch
    
    # Reshape
    dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
    dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
    
    # Calculate accuracy
    dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
    print ("RMSE for dev set ="+str(dev_accuracy))
    
    

    # Generate predictions for display
    feed_dict = {x: np.stack(train_data), keep_prob: 1.0}
    predictions = y.eval(feed_dict)
    result =pd.DataFrame(np.stack(np.transpose(predictions),axis=1))
# Out:
# RMSE for Epoch 0 =15.8035
# RMSE for Epoch 1 =7.04091
# RMSE for Epoch 2 =9.37757
# RMSE for Epoch 3 =8.52094
# RMSE for Epoch 4 =4.82115
# RMSE for Epoch 5 =5.68829
# RMSE for Epoch 6 =8.2525
# RMSE for Epoch 7 =6.24778
# RMSE for Epoch 8 =6.67356
# RMSE for Epoch 9 =6.5096
# RMSE for Epoch 10 =6.50844
# RMSE for Epoch 11 =5.89063
# RMSE for Epoch 12 =5.53389
# RMSE for Epoch 13 =4.77291
# RMSE for Epoch 14 =4.47552
# RMSE for Epoch 15 =4.90083
# RMSE for Epoch 16 =5.43905
# RMSE for Epoch 17 =4.98775
# RMSE for Epoch 18 =4.97487
# RMSE for Epoch 19 =4.59287
# RMSE for Epoch 20 =3.77075
# RMSE for Epoch 21 =5.58009
# RMSE for Epoch 22 =4.56641
# RMSE for Epoch 23 =4.05989
# RMSE for Epoch 24 =3.98838
# RMSE for Epoch 25 =4.99767
# RMSE for Epoch 26 =2.7435
# RMSE for Epoch 27 =4.32667
# RMSE for Epoch 28 =5.02153
# RMSE for Epoch 29 =5.5471
# RMSE for Epoch 30 =3.1036
# RMSE for Epoch 31 =3.91233
# RMSE for Epoch 32 =3.35666
# RMSE for Epoch 33 =3.77494
# RMSE for Epoch 34 =3.29713
# RMSE for Epoch 35 =3.20635
# RMSE for Epoch 36 =3.56831
# RMSE for Epoch 37 =3.92216
# RMSE for Epoch 38 =3.79043
# RMSE for Epoch 39 =3.45325
# RMSE for dev set =3.39862

# %%
# Plot our predictions
plot_images(5,data =train,result=result,training=False)

# %%
# Try 3 convolutional layers, 1 fully connected

mini_batch_size=100
epochs = 50

# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')


# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])

# Same as previous exercize, return a 48*48 image with 32 filters
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# Same as previous exercise, next return a 24*24 image with 64 filters
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# Our third convolutional layer, returns a 12*12 image with 128 filters
W_conv3 = weight_variable([5, 5, 64, 128])
b_conv3 = bias_variable([128])
h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)


# Flatten resulting image to apply relu activation
h_pool3_flat = tf.reshape(h_pool3, [-1, 12*12*128])

# Fully connected layer
W_fc1 = weight_variable([12 * 12 * 128, 1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(h_pool3_flat, W_fc1) + b_fc1)

# Dropout to prevent overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)


# Apply error function with prediction function "y= xW+b" as previously
W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])
y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# Define loss function, try minimize with AdamOptimizer
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-4).minimize(error)

epoch=[i for i in range(epochs)]

# Collect magnitudes of the training and dev errors over epochs for visualization
train_error = []
dev_error = []

with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    # Initialize global vars
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        # Iterate over training data in increments of (mini_batch_size-1)
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Calculate accuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of 20 training examples
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+str(" =")+str(train_accuracy))
        train_error.append(train_accuracy)
        
        # Test accuracy on the unseen (dev) data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        
        # Get batch of 20 from dev
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
        
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        
        # Calculate accuracy & error
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
        dev_error.append(dev_accuracy)
    
    
    # Generate predictions for training and dev for plotting
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
# Out:
# RMSE for Epoch 0 =13.519
# RMSE for dev set =11.5296
# RMSE for Epoch 1 =6.83953
# RMSE for dev set =8.3896
# RMSE for Epoch 2 =7.6685
# RMSE for dev set =7.23421
# RMSE for Epoch 3 =5.75306
# RMSE for dev set =6.40316
# RMSE for Epoch 4 =6.11195
# RMSE for dev set =5.77839
# RMSE for Epoch 5 =4.53007
# RMSE for dev set =6.39642
# RMSE for Epoch 6 =5.26715
# RMSE for dev set =4.00572
# RMSE for Epoch 7 =4.88223
# RMSE for dev set =4.01896
# RMSE for Epoch 8 =4.78986
# RMSE for dev set =5.08306
# RMSE for Epoch 9 =4.01857
# RMSE for dev set =3.13392
# RMSE for Epoch 10 =4.47652
# RMSE for dev set =4.76805
# RMSE for Epoch 11 =3.83944
# RMSE for dev set =3.26205
# RMSE for Epoch 12 =3.75192
# RMSE for dev set =3.83299
# RMSE for Epoch 13 =4.1086
# RMSE for dev set =3.34376
# RMSE for Epoch 14 =3.69594
# RMSE for dev set =3.43425
# RMSE for Epoch 15 =3.8738
# RMSE for dev set =4.60233
# RMSE for Epoch 16 =3.61146
# RMSE for dev set =3.05449
# RMSE for Epoch 17 =3.41113
# RMSE for dev set =3.16155
# RMSE for Epoch 18 =3.87068
# RMSE for dev set =3.44167
# RMSE for Epoch 19 =3.18383
# RMSE for dev set =4.06832
# RMSE for Epoch 20 =3.23954
# RMSE for dev set =4.17669
# RMSE for Epoch 21 =3.13888
# RMSE for dev set =2.96669
# RMSE for Epoch 22 =4.07495
# RMSE for dev set =3.50566
# RMSE for Epoch 23 =3.07745
# RMSE for dev set =3.46296
# RMSE for Epoch 24 =3.26999
# RMSE for dev set =2.92092
# RMSE for Epoch 25 =3.45603
# RMSE for dev set =3.74779
# RMSE for Epoch 26 =3.45378
# RMSE for dev set =3.94931
# RMSE for Epoch 27 =3.42048
# RMSE for dev set =4.39611
# RMSE for Epoch 28 =2.93088
# RMSE for dev set =3.81166
# RMSE for Epoch 29 =3.1133
# RMSE for dev set =4.04993
# RMSE for Epoch 30 =2.52577
# RMSE for dev set =2.42659
# RMSE for Epoch 31 =3.06835
# RMSE for dev set =3.95164
# RMSE for Epoch 32 =2.73689
# RMSE for dev set =2.74926
# RMSE for Epoch 33 =3.15178
# RMSE for dev set =3.09626
# RMSE for Epoch 34 =3.1726
# RMSE for dev set =2.51013
# RMSE for Epoch 35 =2.94432
# RMSE for dev set =3.73708
# RMSE for Epoch 36 =2.41487
# RMSE for dev set =3.33575
# RMSE for Epoch 37 =2.77378
# RMSE for dev set =2.65597
# RMSE for Epoch 38 =2.46435
# RMSE for dev set =2.30551
# RMSE for Epoch 39 =3.46558
# RMSE for dev set =2.47762
# RMSE for Epoch 40 =2.9336
# RMSE for dev set =3.37198
# RMSE for Epoch 41 =3.08621
# RMSE for dev set =2.71253
# RMSE for Epoch 42 =3.19121
# RMSE for dev set =3.02949
# RMSE for Epoch 43 =3.06543
# RMSE for dev set =3.3878
# RMSE for Epoch 44 =2.71231
# RMSE for dev set =2.05456
# RMSE for Epoch 45 =3.5423
# RMSE for dev set =3.36453
# RMSE for Epoch 46 =2.94955
# RMSE for dev set =4.52013
# RMSE for Epoch 47 =2.53188
# RMSE for dev set =3.23808
# RMSE for Epoch 48 =2.32248
# RMSE for dev set =2.57239
# RMSE for Epoch 49 =2.30233
# RMSE for dev set =2.50446

# %%
# Plot predictions from training data (better fit than before)
plot_images(5,data =train,result=result,training=False)

# %%
# Plot predictions from dev data
plot_images(5,data =dev,result=result_dev,training=False)

# %%
# Plot the magnitudes of error magnitudes in dev and training set by epoch
plt.figure(figsize=(6,6))
plt.scatter(epoch,train_error)
plt.scatter(epoch,dev_error,color="red")

# %%
# Try 4 convolutional layers, 1 fully connected

mini_batch_size=100
epochs = 400

# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])

# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])#-1 because we don't know the batch size yet.

# Same as previous exercize, return a 48*48 image with 32 filters
W_conv1 = weight_variable([3, 3, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

# Same as previous exercise, next return a 24*24 image with 64 filters
W_conv2 = weight_variable([3, 3, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

# Same as previous exercise, next return a 12*12 image with 128 filters
W_conv3 = weight_variable([3, 3, 64, 128])
b_conv3 = bias_variable([128])
h_conv3 = tf.nn.relu(conv2d(h_pool2, W_conv3) + b_conv3)
h_pool3 = max_pool_2x2(h_conv3)

# Fourth convolutional layer, returns a 6*6 image with 256 filters
W_conv4 = weight_variable([3, 3, 128, 256])
b_conv4 = bias_variable([256])
h_conv4 = tf.nn.relu(conv2d(h_pool3, W_conv4) + b_conv4)
h_pool4 = max_pool_2x2(h_conv4) #returns a 6*6 image with 256 filters

# Flatten resulting image for matrix multiplication
h_pool4_flat = tf.reshape(h_pool4, [-1, 6*6*256])
# Fully connected layer
W_fc1 = weight_variable([6 * 6 * 256, 1024])
b_fc1 = bias_variable([1024])
h_fc1 = tf.nn.relu(tf.matmul(h_pool4_flat, W_fc1) + b_fc1)

# Dropout to prevent overfitting
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Prediction y=xW+b
W_fc2 = weight_variable([1024, 30])
b_fc2 = bias_variable([30])
y = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

# Define RMSE loss function, minimize with AdamOptimizer
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-3).minimize(error)


epoch=[i for i in range(epochs)]

# Collect train and dev error magnitudes for visualization
train_error = []
dev_error = []

with tf.Session(config=tf.ConfigProto(log_device_placement=True)) as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        
        # Iterate over training data in steps of (mini_batch_size-1)
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Calculate accuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of 20 training examples
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+str(" =")+str(train_accuracy))
        train_error.append(train_accuracy)
        
        # Test accuracy on the unseen (dev) data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        
        # Get batch of 20 from dev
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
        
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        
        # Calculate accuracy & error
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
        dev_error.append(dev_accuracy)
    
    

    # Generate predictions for train/dev/test
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
    result_test =make_predictions(test_data, mini_batch_size-1)
# Out:
# RMSE for Epoch 0 =6.37455
# RMSE for dev set =3.76145
# RMSE for Epoch 1 =4.53869
# RMSE for dev set =4.47585
# RMSE for Epoch 2 =3.36184
# RMSE for dev set =4.39578
# RMSE for Epoch 3 =3.54521
# RMSE for dev set =3.74687
# RMSE for Epoch 4 =4.12031
# RMSE for dev set =3.98102
# RMSE for Epoch 5 =2.61943
# RMSE for dev set =3.60994
# RMSE for Epoch 6 =3.21233
# RMSE for dev set =3.55331
# RMSE for Epoch 7 =3.25587
# RMSE for dev set =2.57262
# RMSE for Epoch 8 =3.48077
# RMSE for dev set =3.88134
# RMSE for Epoch 9 =3.78328
# RMSE for dev set =2.87908
# RMSE for Epoch 10 =3.67231
# RMSE for dev set =2.45481
# RMSE for Epoch 11 =3.47098
# RMSE for dev set =3.13466
# RMSE for Epoch 12 =2.54113
# RMSE for dev set =3.39081
# RMSE for Epoch 13 =2.81402
# RMSE for dev set =2.81703
# RMSE for Epoch 14 =3.1274
# RMSE for dev set =3.02767
# RMSE for Epoch 15 =3.19646
# RMSE for dev set =3.68966
# RMSE for Epoch 16 =2.40194
# RMSE for dev set =2.91503
# RMSE for Epoch 17 =2.82997
# RMSE for dev set =2.74767
# RMSE for Epoch 18 =2.88601
# RMSE for dev set =4.59474
# RMSE for Epoch 19 =3.35548
# RMSE for dev set =3.88935
# RMSE for Epoch 20 =2.45317
# RMSE for dev set =3.11851
# RMSE for Epoch 21 =2.92775
# RMSE for dev set =3.06101
# RMSE for Epoch 22 =2.82683
# RMSE for dev set =4.28151
# RMSE for Epoch 23 =2.90757
# RMSE for dev set =2.23715
# RMSE for Epoch 24 =2.54331
# RMSE for dev set =3.80139
# RMSE for Epoch 25 =3.6109
# RMSE for dev set =3.37077
# RMSE for Epoch 26 =2.56766
# RMSE for dev set =2.72307
# RMSE for Epoch 27 =2.44898
# RMSE for dev set =2.74855
# RMSE for Epoch 28 =3.03003
# RMSE for dev set =3.08579
# RMSE for Epoch 29 =2.51375
# RMSE for dev set =2.25754
# RMSE for Epoch 30 =3.42465
# RMSE for dev set =2.73388
# RMSE for Epoch 31 =2.65256
# RMSE for dev set =2.42911
# RMSE for Epoch 32 =3.89772
# RMSE for dev set =2.69056
# RMSE for Epoch 33 =2.72776
# RMSE for dev set =2.75017
# RMSE for Epoch 34 =2.80126
# RMSE for dev set =3.27694
# RMSE for Epoch 35 =2.26621
# RMSE for dev set =2.92545
# RMSE for Epoch 36 =2.60043
# RMSE for dev set =3.05428
# RMSE for Epoch 37 =2.88852
# RMSE for dev set =2.96285
# RMSE for Epoch 38 =2.09561
# RMSE for dev set =2.31732
# RMSE for Epoch 39 =2.49408
# RMSE for dev set =2.42068
# RMSE for Epoch 40 =2.17099
# RMSE for dev set =2.74979
# RMSE for Epoch 41 =2.32218
# RMSE for dev set =2.71495
# RMSE for Epoch 42 =2.18366
# RMSE for dev set =2.56974
# RMSE for Epoch 43 =2.18575
# RMSE for dev set =2.93832
# RMSE for Epoch 44 =2.81743
# RMSE for dev set =3.13327
# RMSE for Epoch 45 =2.75938
# RMSE for dev set =3.05756
# RMSE for Epoch 46 =2.62495
# RMSE for dev set =3.18036
# RMSE for Epoch 47 =2.29119
# RMSE for dev set =2.90315
# RMSE for Epoch 48 =2.51766
# RMSE for dev set =2.11095
# RMSE for Epoch 49 =2.34071
# RMSE for dev set =3.54262
# RMSE for Epoch 50 =2.61559
# RMSE for dev set =3.01759
# RMSE for Epoch 51 =1.863
# RMSE for dev set =2.31279
# RMSE for Epoch 52 =2.23801
# RMSE for dev set =2.05114
# RMSE for Epoch 53 =2.40937
# RMSE for dev set =2.34788
# RMSE for Epoch 54 =2.31001
# RMSE for dev set =2.11662
# RMSE for Epoch 55 =3.28763
# RMSE for dev set =2.21709
# RMSE for Epoch 56 =1.85173
# RMSE for dev set =2.82738
# RMSE for Epoch 57 =2.72
# RMSE for dev set =2.58111
# RMSE for Epoch 58 =2.67838
# RMSE for dev set =2.71406
# RMSE for Epoch 59 =2.28686
# RMSE for dev set =2.4991
# RMSE for Epoch 60 =2.29094
# RMSE for dev set =2.89174
# RMSE for Epoch 61 =2.20195
# RMSE for dev set =2.47017
# RMSE for Epoch 62 =2.418
# RMSE for dev set =2.68459
# RMSE for Epoch 63 =2.66765
# RMSE for dev set =2.56461
# RMSE for Epoch 64 =2.36512
# RMSE for dev set =2.06272
# RMSE for Epoch 65 =3.02651
# RMSE for dev set =1.82025
# RMSE for Epoch 66 =2.26608
# RMSE for dev set =2.4924
# RMSE for Epoch 67 =2.11246
# RMSE for dev set =2.93109
# RMSE for Epoch 68 =2.47314
# RMSE for dev set =2.01413
# RMSE for Epoch 69 =2.13548
# RMSE for dev set =1.63313
# RMSE for Epoch 70 =2.86326
# RMSE for dev set =3.61122
# RMSE for Epoch 71 =2.17451
# RMSE for dev set =2.28763
# RMSE for Epoch 72 =2.29747
# RMSE for dev set =2.9303
# RMSE for Epoch 73 =2.68519
# RMSE for dev set =2.39846
# RMSE for Epoch 74 =1.79115
# RMSE for dev set =2.88869
# RMSE for Epoch 75 =1.80416
# RMSE for dev set =2.41404
# RMSE for Epoch 76 =2.1896
# RMSE for dev set =2.17485
# RMSE for Epoch 77 =2.90794
# RMSE for dev set =2.08363
# RMSE for Epoch 78 =2.3741
# RMSE for dev set =2.05813
# RMSE for Epoch 79 =1.79542
# RMSE for dev set =3.86964
# RMSE for Epoch 80 =2.38144
# RMSE for dev set =1.7703
# RMSE for Epoch 81 =2.38565
# RMSE for dev set =2.3148
# RMSE for Epoch 82 =1.99308
# RMSE for dev set =1.69588
# RMSE for Epoch 83 =1.67971
# RMSE for dev set =1.5663
# RMSE for Epoch 84 =2.02424
# RMSE for dev set =2.81626
# RMSE for Epoch 85 =2.16777
# RMSE for dev set =2.8106
# RMSE for Epoch 86 =2.40173
# RMSE for dev set =2.32668
# RMSE for Epoch 87 =1.98185
# RMSE for dev set =2.24963
# RMSE for Epoch 88 =2.23989
# RMSE for dev set =2.3382
# RMSE for Epoch 89 =1.9755
# RMSE for dev set =2.81696
# RMSE for Epoch 90 =1.63932
# RMSE for dev set =2.58212
# RMSE for Epoch 91 =2.23606
# RMSE for dev set =2.84121
# RMSE for Epoch 92 =2.39553
# RMSE for dev set =3.5497
# RMSE for Epoch 93 =1.6975
# RMSE for dev set =2.00512
# RMSE for Epoch 94 =1.88638
# RMSE for dev set =1.95752
# RMSE for Epoch 95 =3.13892
# RMSE for dev set =2.81956
# RMSE for Epoch 96 =1.98091
# RMSE for dev set =2.65008
# RMSE for Epoch 97 =2.25673
# RMSE for dev set =2.41756
# RMSE for Epoch 98 =2.24506
# RMSE for dev set =2.60615
# RMSE for Epoch 99 =2.28579
# RMSE for dev set =3.60277
# RMSE for Epoch 100 =2.18638
# RMSE for dev set =2.42324
# RMSE for Epoch 101 =2.17104
# RMSE for dev set =2.90726
# RMSE for Epoch 102 =1.98278
# RMSE for dev set =2.28405
# RMSE for Epoch 103 =1.73331
# RMSE for dev set =2.13398
# RMSE for Epoch 104 =1.81923
# RMSE for dev set =2.36667
# RMSE for Epoch 105 =1.60748
# RMSE for dev set =2.03868
# RMSE for Epoch 106 =2.61662
# RMSE for dev set =2.07565
# RMSE for Epoch 107 =2.20202
# RMSE for dev set =2.22814
# RMSE for Epoch 108 =2.73016
# RMSE for dev set =3.23654
# RMSE for Epoch 109 =1.9537
# RMSE for dev set =1.90878
# RMSE for Epoch 110 =1.82722
# RMSE for dev set =1.68153
# RMSE for Epoch 111 =1.82659
# RMSE for dev set =2.44341
# RMSE for Epoch 112 =2.3528
# RMSE for dev set =2.83425
# RMSE for Epoch 113 =2.0678
# RMSE for dev set =2.33885
# RMSE for Epoch 114 =1.81845
# RMSE for dev set =2.43011
# RMSE for Epoch 115 =1.51563
# RMSE for dev set =2.07674
# RMSE for Epoch 116 =1.97509
# RMSE for dev set =2.31206
# RMSE for Epoch 117 =2.17825
# RMSE for dev set =2.30905
# RMSE for Epoch 118 =1.44044
# RMSE for dev set =2.08071
# RMSE for Epoch 119 =1.6092
# RMSE for dev set =2.27116
# RMSE for Epoch 120 =2.03484
# RMSE for dev set =2.02131
# RMSE for Epoch 121 =2.17164
# RMSE for dev set =2.15166
# RMSE for Epoch 122 =1.72311
# RMSE for dev set =3.30442
# RMSE for Epoch 123 =1.9853
# RMSE for dev set =2.40402
# RMSE for Epoch 124 =2.5054
# RMSE for dev set =1.73988
# RMSE for Epoch 125 =1.9881
# RMSE for dev set =1.94982
# RMSE for Epoch 126 =2.15797
# RMSE for dev set =1.74669
# RMSE for Epoch 127 =1.94466
# RMSE for dev set =2.01324
# RMSE for Epoch 128 =1.55718
# RMSE for dev set =2.39882
# RMSE for Epoch 129 =2.2659
# RMSE for dev set =1.60721
# RMSE for Epoch 130 =1.87183
# RMSE for dev set =2.48663
# RMSE for Epoch 131 =1.84708
# RMSE for dev set =2.28745
# RMSE for Epoch 132 =1.7181
# RMSE for dev set =1.7965
# RMSE for Epoch 133 =1.64069
# RMSE for dev set =1.86585
# RMSE for Epoch 134 =1.9489
# RMSE for dev set =1.86252
# RMSE for Epoch 135 =2.38885
# RMSE for dev set =1.97669
# RMSE for Epoch 136 =2.08542
# RMSE for dev set =1.66881
# RMSE for Epoch 137 =2.18563
# RMSE for dev set =1.9945
# RMSE for Epoch 138 =1.99287
# RMSE for dev set =2.66005
# RMSE for Epoch 139 =1.79273
# RMSE for dev set =1.95641
# RMSE for Epoch 140 =1.70012
# RMSE for dev set =2.22302
# RMSE for Epoch 141 =1.73876
# RMSE for dev set =2.81697
# RMSE for Epoch 142 =2.25088
# RMSE for dev set =3.44801
# RMSE for Epoch 143 =1.87561
# RMSE for dev set =1.74009
# RMSE for Epoch 144 =1.7331
# RMSE for dev set =2.41725
# RMSE for Epoch 145 =2.00814
# RMSE for dev set =1.91787
# RMSE for Epoch 146 =1.58422
# RMSE for dev set =2.70041
# RMSE for Epoch 147 =2.17967
# RMSE for dev set =1.81628
# RMSE for Epoch 148 =1.53496
# RMSE for dev set =1.97851
# RMSE for Epoch 149 =1.47874
# RMSE for dev set =1.68599
# RMSE for Epoch 150 =1.67637
# RMSE for dev set =2.22872
# RMSE for Epoch 151 =1.91352
# RMSE for dev set =2.96362
# RMSE for Epoch 152 =2.02077
# RMSE for dev set =1.80572
# RMSE for Epoch 153 =2.0907
# RMSE for dev set =2.37501
# RMSE for Epoch 154 =1.804
# RMSE for dev set =2.32808
# RMSE for Epoch 155 =1.77094
# RMSE for dev set =1.78595
# RMSE for Epoch 156 =1.74695
# RMSE for dev set =2.12511
# RMSE for Epoch 157 =1.73773
# RMSE for dev set =2.18916
# RMSE for Epoch 158 =2.32159
# RMSE for dev set =1.53115
# RMSE for Epoch 159 =2.28916
# RMSE for dev set =1.46154
# RMSE for Epoch 160 =1.94563
# RMSE for dev set =2.30612
# RMSE for Epoch 161 =1.94616
# RMSE for dev set =1.61797
# RMSE for Epoch 162 =1.77259
# RMSE for dev set =2.02901
# RMSE for Epoch 163 =1.62191
# RMSE for dev set =2.16559
# RMSE for Epoch 164 =1.8405
# RMSE for dev set =2.2123
# RMSE for Epoch 165 =2.18103
# RMSE for dev set =1.95905
# RMSE for Epoch 166 =1.61455
# RMSE for dev set =1.58474
# RMSE for Epoch 167 =1.89216
# RMSE for dev set =2.25552
# RMSE for Epoch 168 =1.41513
# RMSE for dev set =1.8637
# RMSE for Epoch 169 =1.4868
# RMSE for dev set =2.53709
# RMSE for Epoch 170 =1.56102
# RMSE for dev set =2.06415
# RMSE for Epoch 171 =1.83484
# RMSE for dev set =1.98788
# RMSE for Epoch 172 =2.25991
# RMSE for dev set =2.45327
# RMSE for Epoch 173 =1.56035
# RMSE for dev set =2.41532
# RMSE for Epoch 174 =1.79861
# RMSE for dev set =1.93989
# RMSE for Epoch 175 =2.04739
# RMSE for dev set =1.90917
# RMSE for Epoch 176 =1.91184
# RMSE for dev set =2.52052
# RMSE for Epoch 177 =1.52892
# RMSE for dev set =1.83775
# RMSE for Epoch 178 =1.70541
# RMSE for dev set =1.93289
# RMSE for Epoch 179 =1.71729
# RMSE for dev set =2.15567
# RMSE for Epoch 180 =2.43411
# RMSE for dev set =1.94309
# RMSE for Epoch 181 =2.33576
# RMSE for dev set =1.92105
# RMSE for Epoch 182 =2.00807
# RMSE for dev set =2.96807
# RMSE for Epoch 183 =1.60012
# RMSE for dev set =2.02006
# RMSE for Epoch 184 =2.12532
# RMSE for dev set =1.77234
# RMSE for Epoch 185 =2.28796
# RMSE for dev set =2.39624
# RMSE for Epoch 186 =1.7806
# RMSE for dev set =1.60778
# RMSE for Epoch 187 =1.93799
# RMSE for dev set =1.78732
# RMSE for Epoch 188 =1.63613
# RMSE for dev set =2.55609
# RMSE for Epoch 189 =2.02506
# RMSE for dev set =1.73553
# RMSE for Epoch 190 =1.61075
# RMSE for dev set =1.86897
# RMSE for Epoch 191 =1.76287
# RMSE for dev set =2.29454
# RMSE for Epoch 192 =1.51477
# RMSE for dev set =2.37441
# RMSE for Epoch 193 =1.57167
# RMSE for dev set =1.93048
# RMSE for Epoch 194 =1.59814
# RMSE for dev set =2.42845
# RMSE for Epoch 195 =1.54812
# RMSE for dev set =1.51237
# RMSE for Epoch 196 =1.91314
# RMSE for dev set =1.49517
# RMSE for Epoch 197 =1.55524
# RMSE for dev set =2.04488
# RMSE for Epoch 198 =2.12539
# RMSE for dev set =1.71477
# RMSE for Epoch 199 =1.46095
# RMSE for dev set =2.65078
# RMSE for Epoch 200 =1.7996
# RMSE for dev set =2.02212
# RMSE for Epoch 201 =1.68795
# RMSE for dev set =1.95331
# RMSE for Epoch 202 =1.44549
# RMSE for dev set =3.4494
# RMSE for Epoch 203 =2.46105
# RMSE for dev set =1.73893
# RMSE for Epoch 204 =2.28158
# RMSE for dev set =2.08973
# RMSE for Epoch 205 =1.63362
# RMSE for dev set =2.01623
# RMSE for Epoch 206 =1.90961
# RMSE for dev set =1.78318
# RMSE for Epoch 207 =1.63164
# RMSE for dev set =2.07225
# RMSE for Epoch 208 =1.59082
# RMSE for dev set =1.70526
# RMSE for Epoch 209 =1.72502
# RMSE for dev set =2.46054
# RMSE for Epoch 210 =1.86604
# RMSE for dev set =2.12631
# RMSE for Epoch 211 =2.09215
# RMSE for dev set =2.0451
# RMSE for Epoch 212 =1.30579
# RMSE for dev set =1.67048
# RMSE for Epoch 213 =2.15953
# RMSE for dev set =1.94777
# RMSE for Epoch 214 =1.65682
# RMSE for dev set =1.53102
# RMSE for Epoch 215 =1.71365
# RMSE for dev set =2.49134
# RMSE for Epoch 216 =2.27058
# RMSE for dev set =2.20984
# RMSE for Epoch 217 =1.4511
# RMSE for dev set =1.59486
# RMSE for Epoch 218 =1.76049
# RMSE for dev set =2.15573
# RMSE for Epoch 219 =1.65177
# RMSE for dev set =1.85623
# RMSE for Epoch 220 =1.72428
# RMSE for dev set =1.87326
# RMSE for Epoch 221 =1.79554
# RMSE for dev set =1.85479
# RMSE for Epoch 222 =1.31514
# RMSE for dev set =2.14165
# RMSE for Epoch 223 =1.69668
# RMSE for dev set =2.1714
# RMSE for Epoch 224 =1.62021
# RMSE for dev set =1.93902
# RMSE for Epoch 225 =1.69354
# RMSE for dev set =1.57288
# RMSE for Epoch 226 =1.91496
# RMSE for dev set =1.62451
# RMSE for Epoch 227 =1.3505
# RMSE for dev set =1.43494
# RMSE for Epoch 228 =1.51128
# RMSE for dev set =2.09226
# RMSE for Epoch 229 =1.71337
# RMSE for dev set =1.87649
# RMSE for Epoch 230 =1.95326
# RMSE for dev set =2.27907
# RMSE for Epoch 231 =1.63052
# RMSE for dev set =1.80595
# RMSE for Epoch 232 =1.32104
# RMSE for dev set =1.93514
# RMSE for Epoch 233 =2.22555
# RMSE for dev set =1.73713
# RMSE for Epoch 234 =1.91424
# RMSE for dev set =2.52295
# RMSE for Epoch 235 =1.53935
# RMSE for dev set =1.7065
# RMSE for Epoch 236 =1.66581
# RMSE for dev set =2.16809
# RMSE for Epoch 237 =1.66999
# RMSE for dev set =2.29392
# RMSE for Epoch 238 =1.73799
# RMSE for dev set =2.18404
# RMSE for Epoch 239 =2.45394
# RMSE for dev set =1.69053
# RMSE for Epoch 240 =1.54335
# RMSE for dev set =2.0091
# RMSE for Epoch 241 =1.35434
# RMSE for dev set =1.84331
# RMSE for Epoch 242 =1.56722
# RMSE for dev set =2.09107
# RMSE for Epoch 243 =1.47827
# RMSE for dev set =2.72308
# RMSE for Epoch 244 =1.65813
# RMSE for dev set =2.1783
# RMSE for Epoch 245 =1.57432
# RMSE for dev set =2.2994
# RMSE for Epoch 246 =1.73357
# RMSE for dev set =2.36615
# RMSE for Epoch 247 =1.82417
# RMSE for dev set =2.10797
# RMSE for Epoch 248 =1.34679
# RMSE for dev set =1.763
# RMSE for Epoch 249 =1.65034
# RMSE for dev set =1.62404
# RMSE for Epoch 250 =1.43769
# RMSE for dev set =1.91816
# RMSE for Epoch 251 =1.54172
# RMSE for dev set =2.04613
# RMSE for Epoch 252 =1.7157
# RMSE for dev set =1.84131
# RMSE for Epoch 253 =2.10258
# RMSE for dev set =2.20337
# RMSE for Epoch 254 =1.41929
# RMSE for dev set =2.40405
# RMSE for Epoch 255 =1.55712
# RMSE for dev set =1.5588
# RMSE for Epoch 256 =1.84664
# RMSE for dev set =1.78433
# RMSE for Epoch 257 =1.82784
# RMSE for dev set =2.08853
# RMSE for Epoch 258 =1.54849
# RMSE for dev set =2.55821
# RMSE for Epoch 259 =1.73076
# RMSE for dev set =1.7011
# RMSE for Epoch 260 =1.55411
# RMSE for dev set =1.95436
# RMSE for Epoch 261 =1.5445
# RMSE for dev set =2.02729
# RMSE for Epoch 262 =1.95708
# RMSE for dev set =3.12346
# RMSE for Epoch 263 =1.96469
# RMSE for dev set =2.37582
# RMSE for Epoch 264 =1.44084
# RMSE for dev set =1.53556
# RMSE for Epoch 265 =1.42767
# RMSE for dev set =2.25068
# RMSE for Epoch 266 =1.4112
# RMSE for dev set =1.44671
# RMSE for Epoch 267 =1.75792
# RMSE for dev set =2.02843
# RMSE for Epoch 268 =1.35217
# RMSE for dev set =1.85201
# RMSE for Epoch 269 =1.49235
# RMSE for dev set =2.35723
# RMSE for Epoch 270 =1.51214
# RMSE for dev set =1.64252
# RMSE for Epoch 271 =1.36908
# RMSE for dev set =2.06813
# RMSE for Epoch 272 =1.57775
# RMSE for dev set =1.85524
# RMSE for Epoch 273 =1.56053
# RMSE for dev set =1.76848
# RMSE for Epoch 274 =1.39657
# RMSE for dev set =1.62906
# RMSE for Epoch 275 =1.78654
# RMSE for dev set =1.9623
# RMSE for Epoch 276 =1.58133
# RMSE for dev set =1.93239
# RMSE for Epoch 277 =1.53485
# RMSE for dev set =1.75486
# RMSE for Epoch 278 =1.51996
# RMSE for dev set =2.13856
# RMSE for Epoch 279 =1.66995
# RMSE for dev set =1.78705
# RMSE for Epoch 280 =1.43545
# RMSE for dev set =2.16989
# RMSE for Epoch 281 =1.40472
# RMSE for dev set =1.91106
# RMSE for Epoch 282 =1.58408
# RMSE for dev set =2.07844
# RMSE for Epoch 283 =1.48846
# RMSE for dev set =2.39137
# RMSE for Epoch 284 =1.73219
# RMSE for dev set =2.27714
# RMSE for Epoch 285 =1.55541
# RMSE for dev set =1.39143
# RMSE for Epoch 286 =1.72508
# RMSE for dev set =1.57514
# RMSE for Epoch 287 =1.6503
# RMSE for dev set =1.33409
# RMSE for Epoch 288 =1.60369
# RMSE for dev set =1.56097
# RMSE for Epoch 289 =1.61574
# RMSE for dev set =2.26572
# RMSE for Epoch 290 =1.45124
# RMSE for dev set =1.92755
# RMSE for Epoch 291 =1.41918
# RMSE for dev set =1.94719
# RMSE for Epoch 292 =1.74484
# RMSE for dev set =1.63979
# RMSE for Epoch 293 =2.05112
# RMSE for dev set =1.36545
# RMSE for Epoch 294 =1.24074
# RMSE for dev set =1.71315
# RMSE for Epoch 295 =1.68001
# RMSE for dev set =2.0115
# RMSE for Epoch 296 =1.4886
# RMSE for dev set =1.39345
# RMSE for Epoch 297 =1.8518
# RMSE for dev set =1.41352
# RMSE for Epoch 298 =1.74805
# RMSE for dev set =1.46431
# RMSE for Epoch 299 =1.51478
# RMSE for dev set =1.64384
# RMSE for Epoch 300 =2.0626
# RMSE for dev set =1.73273
# RMSE for Epoch 301 =1.57497
# RMSE for dev set =2.13786
# RMSE for Epoch 302 =1.33767
# RMSE for dev set =1.61523
# RMSE for Epoch 303 =1.75953
# RMSE for dev set =2.10175
# RMSE for Epoch 304 =1.44887
# RMSE for dev set =2.13608
# RMSE for Epoch 305 =1.655
# RMSE for dev set =1.74399
# RMSE for Epoch 306 =1.68533
# RMSE for dev set =1.83628
# RMSE for Epoch 307 =1.40601
# RMSE for dev set =1.48583
# RMSE for Epoch 308 =1.5306
# RMSE for dev set =1.97533
# RMSE for Epoch 309 =1.6924
# RMSE for dev set =1.8886
# RMSE for Epoch 310 =1.87191
# RMSE for dev set =2.04863
# RMSE for Epoch 311 =1.53305
# RMSE for dev set =1.77195
# RMSE for Epoch 312 =1.48619
# RMSE for dev set =1.47307
# RMSE for Epoch 313 =1.46821
# RMSE for dev set =1.9882
# RMSE for Epoch 314 =1.54526
# RMSE for dev set =1.68182
# RMSE for Epoch 315 =1.63894
# RMSE for dev set =2.04457
# RMSE for Epoch 316 =1.7933
# RMSE for dev set =2.17193
# RMSE for Epoch 317 =1.98577
# RMSE for dev set =2.65369
# RMSE for Epoch 318 =1.42006
# RMSE for dev set =2.35159
# RMSE for Epoch 319 =1.89053
# RMSE for dev set =1.64806
# RMSE for Epoch 320 =1.45318
# RMSE for dev set =1.87215
# RMSE for Epoch 321 =1.56022
# RMSE for dev set =1.57546
# RMSE for Epoch 322 =1.80327
# RMSE for dev set =1.67169
# RMSE for Epoch 323 =1.91338
# RMSE for dev set =2.20834
# RMSE for Epoch 324 =1.52768
# RMSE for dev set =1.98314
# RMSE for Epoch 325 =1.63803
# RMSE for dev set =2.77067
# RMSE for Epoch 326 =1.40737
# RMSE for dev set =1.95218
# RMSE for Epoch 327 =1.60589
# RMSE for dev set =1.35094
# RMSE for Epoch 328 =1.23147
# RMSE for dev set =1.44652
# RMSE for Epoch 329 =1.87301
# RMSE for dev set =1.75692
# RMSE for Epoch 330 =1.81567
# RMSE for dev set =2.06501
# RMSE for Epoch 331 =1.73444
# RMSE for dev set =1.65818
# RMSE for Epoch 332 =1.57643
# RMSE for dev set =1.62599
# RMSE for Epoch 333 =1.47803
# RMSE for dev set =2.07762
# RMSE for Epoch 334 =1.87893
# RMSE for dev set =1.40396
# RMSE for Epoch 335 =1.37111
# RMSE for dev set =1.67997
# RMSE for Epoch 336 =1.42232
# RMSE for dev set =1.55445
# RMSE for Epoch 337 =1.46079
# RMSE for dev set =1.6967
# RMSE for Epoch 338 =1.56072
# RMSE for dev set =2.48891
# RMSE for Epoch 339 =1.90985
# RMSE for dev set =1.61079
# RMSE for Epoch 340 =1.87276
# RMSE for dev set =1.3844
# RMSE for Epoch 341 =1.6657
# RMSE for dev set =1.94627
# RMSE for Epoch 342 =1.42197
# RMSE for dev set =2.01387
# RMSE for Epoch 343 =1.54437
# RMSE for dev set =1.49164
# RMSE for Epoch 344 =1.82858
# RMSE for dev set =2.36067
# RMSE for Epoch 345 =1.44827
# RMSE for dev set =2.54842
# RMSE for Epoch 346 =1.391
# RMSE for dev set =1.6297
# RMSE for Epoch 347 =2.1015
# RMSE for dev set =2.28819
# RMSE for Epoch 348 =1.33332
# RMSE for dev set =2.03364
# RMSE for Epoch 349 =1.5032
# RMSE for dev set =1.4034
# RMSE for Epoch 350 =1.69872
# RMSE for dev set =1.86447
# RMSE for Epoch 351 =1.53406
# RMSE for dev set =2.02173
# RMSE for Epoch 352 =1.40397
# RMSE for dev set =1.53075
# RMSE for Epoch 353 =1.58769
# RMSE for dev set =1.59008
# RMSE for Epoch 354 =1.60169
# RMSE for dev set =2.2428
# RMSE for Epoch 355 =1.57785
# RMSE for dev set =2.30322
# RMSE for Epoch 356 =1.8577
# RMSE for dev set =1.6731
# RMSE for Epoch 357 =1.53821
# RMSE for dev set =1.80428
# RMSE for Epoch 358 =2.10704
# RMSE for dev set =1.84105
# RMSE for Epoch 359 =1.24388
# RMSE for dev set =1.57193
# RMSE for Epoch 360 =1.64911
# RMSE for dev set =1.61926
# RMSE for Epoch 361 =1.75459
# RMSE for dev set =1.54299
# RMSE for Epoch 362 =1.37982
# RMSE for dev set =1.72076
# RMSE for Epoch 363 =1.48888
# RMSE for dev set =2.09395
# RMSE for Epoch 364 =1.48672
# RMSE for dev set =1.67255
# RMSE for Epoch 365 =1.52256
# RMSE for dev set =1.96125
# RMSE for Epoch 366 =1.48218
# RMSE for dev set =1.59997
# RMSE for Epoch 367 =1.46302
# RMSE for dev set =1.78527
# RMSE for Epoch 368 =1.23564
# RMSE for dev set =1.78591
# RMSE for Epoch 369 =1.23183
# RMSE for dev set =1.58437
# RMSE for Epoch 370 =2.26693
# RMSE for dev set =3.06122
# RMSE for Epoch 371 =1.55697
# RMSE for dev set =1.88068
# RMSE for Epoch 372 =1.27525
# RMSE for dev set =1.33295
# RMSE for Epoch 373 =1.51472
# RMSE for dev set =2.6535
# RMSE for Epoch 374 =1.99493
# RMSE for dev set =1.48023
# RMSE for Epoch 375 =1.34243
# RMSE for dev set =1.63411
# RMSE for Epoch 376 =1.49363
# RMSE for dev set =2.0995
# RMSE for Epoch 377 =1.81621
# RMSE for dev set =1.94281
# RMSE for Epoch 378 =1.65207
# RMSE for dev set =1.78453
# RMSE for Epoch 379 =1.54727
# RMSE for dev set =1.49641
# RMSE for Epoch 380 =1.12947
# RMSE for dev set =1.35693
# RMSE for Epoch 381 =1.64286
# RMSE for dev set =1.72102
# RMSE for Epoch 382 =2.16108
# RMSE for dev set =3.1928
# RMSE for Epoch 383 =1.32239
# RMSE for dev set =1.94117
# RMSE for Epoch 384 =1.33011
# RMSE for dev set =1.70854
# RMSE for Epoch 385 =1.37918
# RMSE for dev set =1.60488
# RMSE for Epoch 386 =1.50796
# RMSE for dev set =1.4225
# RMSE for Epoch 387 =1.65417
# RMSE for dev set =2.15016
# RMSE for Epoch 388 =1.7309
# RMSE for dev set =1.95178
# RMSE for Epoch 389 =1.30265
# RMSE for dev set =1.16776
# RMSE for Epoch 390 =1.69386
# RMSE for dev set =1.51812
# RMSE for Epoch 391 =1.56643
# RMSE for dev set =1.67522
# RMSE for Epoch 392 =1.5401
# RMSE for dev set =2.3007
# RMSE for Epoch 393 =1.78729
# RMSE for dev set =1.85578
# RMSE for Epoch 394 =1.60524
# RMSE for dev set =1.69424
# RMSE for Epoch 395 =1.51978
# RMSE for dev set =2.20757
# RMSE for Epoch 396 =1.42883
# RMSE for dev set =2.07213
# RMSE for Epoch 397 =1.60509
# RMSE for dev set =1.44149
# RMSE for Epoch 398 =1.70915
# RMSE for dev set =1.74272
# RMSE for Epoch 399 =1.48817
# RMSE for dev set =1.54244

# %%
# Plot predictions from train_data
plot_images(5,data =train,result=result,training=False)

# %%
# Plot predictions from dev data
plot_images(5,data =dev,result=result_dev,training=False)

# %%
# Plot train/dev errors by epoch
plt.figure(figsize=(6,6))
plt.scatter(epoch,train_error)
plt.scatter(epoch,dev_error,color="red")

# %%
# Some additional work to improve accuracy: blur images, move images


# Blur input image by applying convolution with array of 1's
def blur_images(inputdata):
    data=inputdata.copy()
    data["Image"] = data["Image"].apply(lambda x: (scipy.signal.convolve2d(x.reshape((96,96)),np.ones((3,3)), mode='same',boundary="fill")/9.0).ravel() )
    return data

# Move images to the right, left, up, or down, by 'pixels' number of pixels
def move_images(inputdata,pixels,orientation):
    #pixels= 5 
    #orientation = 'right'
    data = train.copy()
    (dimx,dimy) = (96,96)
    
    # if orientation is to the right, apply padding to the left side of the image
    if orientation == 'right':
        padding = np.zeros((dimx,pixels))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
                
        data["Image"] = data["Image"].apply(lambda x: np.hstack((padding,x.reshape(96,96)))[:,0:96])
    
        for col in data.columns.get_level_values(0)[0:30:2]:
            data[col]=data[col].apply(lambda x: min(96,x+pixels))
            
    # if orientation is to the left, apply padding to the right side of the image
    elif orientation == 'left':
        padding = np.zeros((dimx,pixels))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
        data["Image"] = data["Image"].apply(lambda x: np.hstack((x.reshape(96,96),padding))[:,pixels:96+pixels])
    
        for col in data.columns.get_level_values(0)[0:30:2]:
            data[col]=data[col].apply(lambda x: max(0,x-pixels))
            
    # if orientation is up, apply padding to bottom
    elif orientation == 'up':
        padding = np.zeros((pixels,dimy))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
                
        data["Image"] = data["Image"].apply(lambda x: np.vstack((x.reshape(96,96),padding))[pixels:96+pixels,:])
    
        for col in data.columns.get_level_values(0)[1:30:2]:
            data[col]=data[col].apply(lambda x: max(0,x-pixels))
            
    # if orientation is down, apply padding to top of image
    elif orientation == 'down':
        padding = np.zeros((pixels,dimy))
        for i in range(padding.shape[0]):
            for j in range(padding.shape[1]):
                random = np.random.normal(0.5,0.1)
                padding[i][j]= min(max(random,0),1)
                
        data["Image"] = data["Image"].apply(lambda x: np.vstack((padding,x.reshape(96,96)))[0:96,:])
    
        for col in data.columns.get_level_values(0)[1:30:2]:
            data[col]=data[col].apply(lambda x: min(96,x+pixels))
    
    data["Image"] = data["Image"].apply(lambda x:x.flatten())
    
    return data

# %%
# Plot a row of the original image
plot_images(5,train)

# Plot a row of blurred image
plot_images(5,blur_images(train))

# Plot rows moving image to all 4 orientations
plot_images(5,move_images(train,15,"right"))
plot_images(5,move_images(train,15,"left"))
plot_images(5,move_images(train,15,"up"))
plot_images(5,move_images(train,15,"down"))

# %%
# We start from the beginning, loading the original training/dev/test data, for the purpose of appending
#   our blurred/moved images to the original dataset to measure accuracy

# Loading the test and raw training datasets
raw = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# Converting image data into numpy arrays and scaling the images
raw["Image"] = raw["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)
test["Image"] = test["Image"].apply(lambda x: np.asarray(x.split(" "),dtype=np.float32)/255)

# Remove rows with 'na', reshuffle, and re-index
raw.dropna(inplace=True)
test.dropna(inplace=True)
raw = raw.sample(frac=1)
raw.reset_index(inplace=True,drop=True)
test.reset_index(inplace=True,drop=True)

# Set first 1800 of the raw data to be training, and the remaining to be dev data
train_size = 1800
train = raw.iloc[0:train_size,:]
dev = raw.iloc[train_size:raw.shape[0],:]
train.reset_index(inplace=True,drop=True)
dev.reset_index(inplace=True,drop=True)

# %%
# Now blur all images in the training set, and append results to our training set
train = pd.concat([train,blur_images(train)],axis=0)

# Re-index
train.reset_index(inplace=True,drop=True)

# %%
# Convert train/dev/test to numpy array representations
train_data = train["Image"].as_matrix()
train_labels = np.asarray(train[train.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

dev_data = dev["Image"].as_matrix()
dev_labels = np.asarray(dev[dev.columns.get_level_values(0)[0:30]]).astype(dtype = np.float32)

test_data = test["Image"].as_matrix()

# %%
print (train_data.shape)
print (train.shape)
print (dev_data.shape)
print (dev.shape)
# Out:
# (3600,)
# (3600, 31)
# (340,)
# (340, 31)

# %%
# Try 2 convolutional layers, 2 fully connected layers

mini_batch_size=300
epochs = 25


# Set weights as 4D array of random values from truncated normal dist (most-common method)
def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

# Set constant bias
def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

# Compute 2D convolution
def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')

# Max pool on the input
def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1],strides=[1, 2, 2, 1], padding='SAME')

# Will contain image pixels as we run the training loop
x = tf.placeholder(tf.float32, shape=[None, 9216])
# Will contain facial feature locations as we run training loop
y_ = tf.placeholder(tf.float32, shape=[None, 30])


# Reshape image to format [batch, in-height, in-width, in_channels] to run conv2d on it
# Batch is -1 since don't know batch size yet
x_image = tf.reshape(x, [-1,96,96,1])

# Same as previous exercize, return a 48*48 image with 32 filters
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)


# Same as previous exercise, next return a 24*24 image with 64 filters
W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2) #returns a 24*24 image with 64 filters


# Fully connected layer
W_fc1 = weight_variable([24 * 24 * 64, 1024])
b_fc1 = bias_variable([1024])
h_pool2_flat = tf.reshape(h_pool2, [-1, 24*24*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

# Dropout to prevent overfit
keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

# Fully connected layer
W_fc2 = weight_variable([1024, 1024])
b_fc2 = bias_variable([1024])
h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)
h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

# Prediction function
W_fc3 = weight_variable([1024, 30])
b_fc3 = bias_variable([30])
y = tf.matmul(h_fc2_drop, W_fc3) + b_fc3

# Define RMSE error, minimize with AdamOptimizer
error = tf.sqrt(tf.reduce_mean(tf.square(tf.subtract(y_,y))))
train_step = tf.train.AdamOptimizer(1e-2).minimize(error)

epoch=[i for i in range(epochs)]

# Track train/dev errors for plotting
train_error = []
dev_error = []

# GPU settings
config = tf.ConfigProto()
config.gpu_options.allow_growth=True


with tf.Session(config=config) as sess:
    
    # Initialize global vars
    sess.run(tf.global_variables_initializer())
    for i in range(epochs):
        
        # Iterate by batch size
        iter_ = imgs_iterator(train_data,train_labels,mini_batch_size-1)
        try:
            next_batch =iter_.__next__()
            while next_batch!=None:
                
                # Load next batch
                train_data_instance,train_label_instance,batch_size = next_batch
                
                # Reshape
                train_instance = np.reshape(train_data_instance,(batch_size,9216))
                train_label_instance = np.reshape(train_label_instance,(batch_size,30))
                
                # Calculate acccuracy
                train_accuracy = error.eval(feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 1.0})

                # Run training with next batch of training data
                sess.run(train_step,feed_dict={x: train_instance, y_: train_label_instance, keep_prob: 0.5})
                next_batch =iter_.__next__()
        except StopIteration:
            next_batch=None
        
        print ("RMSE for Epoch "+str(i)+str(" =")+str(train_accuracy))
        train_error.append(train_accuracy)
        
    
        # Determine accuracy on our dev data
        iter_dev = imgs_iterator(dev_data,dev_labels,batch_size)
        
        # Get batch of 20
        next_batch =iter_dev.__next__()
        dev_data_instance,dev_label_instance,batch_size = next_batch
        
        # Reshape
        dev_instance = np.reshape(dev_data_instance,(batch_size,9216))
        dev_label_instance = np.reshape(dev_label_instance,(batch_size,30))
        
        # Calculate accuracy & error
        dev_accuracy = error.eval(feed_dict={x: dev_instance, y_: dev_label_instance, keep_prob: 1.0})
        print ("RMSE for dev set ="+str(dev_accuracy))
        dev_error.append(dev_accuracy)
    
    

    #Predictions on train/dev/test for plotting
    result =make_predictions(train_data, mini_batch_size-1)
    result_dev =make_predictions(dev_data, mini_batch_size-1)
    result_test =make_predictions(test_data, mini_batch_size-1)
    
    sess.close()
# Out:
# RMSE for Epoch 0 =44.9259
# RMSE for dev set =46.8574
# RMSE for Epoch 1 =15.9717
# RMSE for dev set =13.3416
# RMSE for Epoch 2 =9.03078
# RMSE for dev set =7.71603
# RMSE for Epoch 3 =3.58851
# RMSE for dev set =4.01439
# RMSE for Epoch 4 =3.98377
# RMSE for dev set =2.96415
# RMSE for Epoch 5 =2.42941
# RMSE for dev set =3.53091
# RMSE for Epoch 6 =3.37808
# RMSE for dev set =3.62855
# RMSE for Epoch 7 =2.77882
# RMSE for dev set =4.32308
# RMSE for Epoch 8 =3.10389
# RMSE for dev set =5.68477
# RMSE for Epoch 9 =2.95712
# RMSE for dev set =4.10282
# RMSE for Epoch 10 =4.23536
# RMSE for dev set =3.09247
# RMSE for Epoch 11 =3.53063
# RMSE for dev set =2.71341
# RMSE for Epoch 12 =3.11424
# RMSE for dev set =2.91235
# RMSE for Epoch 13 =2.98678
# RMSE for dev set =3.33234
# RMSE for Epoch 14 =3.21885
# RMSE for dev set =3.90345
# RMSE for Epoch 15 =3.4624
# RMSE for dev set =3.7776
# RMSE for Epoch 16 =2.66418
# RMSE for dev set =3.26109
# RMSE for Epoch 17 =2.90987
# RMSE for dev set =3.62901
# RMSE for Epoch 18 =3.56537
# RMSE for dev set =4.24954
# RMSE for Epoch 19 =4.81695
# RMSE for dev set =3.47563
# RMSE for Epoch 20 =4.33484
# RMSE for dev set =3.66807
# RMSE for Epoch 21 =3.1944
# RMSE for dev set =3.15855
# RMSE for Epoch 22 =3.36427
# RMSE for dev set =3.66434
# RMSE for Epoch 23 =2.8479
# RMSE for dev set =3.56538
# RMSE for Epoch 24 =2.8157
# RMSE for dev set =3.44779

# %%
# Plot training and dev errors by epoch
plt.figure(figsize=(6,6))
plt.scatter(epoch,train_error)
plt.scatter(epoch,dev_error,color="red")

# %%
# Plot predicted facial keypoints from dev_data
plot_images(5,dev,result_dev,False)

# %%
# Plot predicted facial keypoints from test_data
plot_images(5,train,result,False)

# %%
# Submission
generate_results(result_test)
